# %% [markdown]
# # Derivados Financieros

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance
# ## 2) Plots

# %%
### Importo los modulos
import sys
sys.path.append('..')

from Codigo.data_nyse import *

import yfinance as yf
import datetime

# %% [markdown]
# ## API Yahoo finance

# %% [markdown]
# Modulos necesarios
#
# data_nyse (en webcampus) ;
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# yfinance, (yfinance-0.1.63 - tuve que actualizar reicentemente)
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install
#
#
# urllib.requestatexit
# datetime
# dateutil
#
# import tda
# json
# selenium, webdriver

# %% [markdown]
# ## Queremos obtener datos de mercado

# %%
### Metodo para el web scraping
panel_yahoo_GGAL = obtener_opciones_yahoo_finance('GGAL')
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)

# %%
panel_yahoo_GGAL
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0  GGAL220819C00002500 2022-07-29 18:25:01+00:00     2.5       5.40   5.50
# 1  GGAL220819C00005000 2022-08-18 14:38:46+00:00     5.0       3.16   3.00
# 2  GGAL220819C00007500 2022-08-18 16:33:53+00:00     7.5       0.65   0.60
# 3  GGAL220819C00010000 2022-08-15 16:57:53+00:00    10.0       0.05   0.00
# 0  GGAL220916C00005000 2022-08-04 16:37:47+00:00     5.0       2.76   3.10
# 1  GGAL220916C00007500 2022-08-15 19:01:53+00:00     7.5       0.97   0.80
# 2  GGAL220916C00010000 2022-08-16 14:47:27+00:00    10.0       0.05   0.00
# 0  GGAL221021C00005000 2022-07-29 19:03:30+00:00     5.0       3.00   2.90
# 1  GGAL221021C00007500 2022-08-17 18:11:42+00:00     7.5       1.07   1.00
# 2  GGAL221021C00010000 2022-08-12 14:16:19+00:00    10.0       0.15   0.05
# 3  GGAL221021C00012500 2022-07-29 14:46:00+00:00    12.5       0.05   0.00
# 4  GGAL221021C00015000 2022-08-08 15:23:35+00:00    15.0       0.05   0.00
# 5  GGAL221021C00017500 2022-04-04 16:46:19+00:00    17.5       0.34   0.00
# 0  GGAL230120C00002500 2021-11-03 15:23:48+00:00     2.5       8.90   4.50
# 1  GGAL230120C00005000 2022-08-18 15:58:34+00:00     5.0       3.32   3.20
# 2  GGAL230120C00007500 2022-08-18 16:33:53+00:00     7.5       1.35   1.30
# 3  GGAL230120C00010000 2022-08-18 16:53:10+00:00    10.0       0.45   0.40
# 4  GGAL230120C00012500 2022-08-09 15:36:35+00:00    12.5       0.06   0.05
# 5  GGAL230120C00015000 2022-07-27 19:41:31+00:00    15.0       0.08   0.00
# 6  GGAL230120C00017500 2022-07-08 14:32:36+00:00    17.5       0.15   0.00
# 7  GGAL230120C00020000 2022-05-25 16:02:22+00:00    20.0       0.05   0.00
# 8  GGAL230120C00022500 2022-03-09 18:38:57+00:00    22.5       0.20   0.05
# 0  GGAL240119C00002500 2022-06-15 17:32:18+00:00     2.5       5.50   1.50
# 1  GGAL240119C00005000 2022-08-12 18:31:26+00:00     5.0       3.75   3.50
# 2  GGAL240119C00007500 2022-08-15 15:35:55+00:00     7.5       2.40   1.90
# 1        True      REGULAR      USD   GGAL  8.15
# 2        True      REGULAR      USD   GGAL  8.15
# 3       False      REGULAR      USD   GGAL  8.15
# 4       False      REGULAR      USD   GGAL  8.15
# 5       False      REGULAR      USD   GGAL  8.15
# 6       False      REGULAR      USD   GGAL  8.15
# 7       False      REGULAR      USD   GGAL  8.15
# 8       False      REGULAR      USD   GGAL  8.15
# 0        True      REGULAR      USD   GGAL  8.15
# 1        True      REGULAR      USD   GGAL  8.15
# 2        True      REGULAR      USD   GGAL  8.15
# 3       False      REGULAR      USD   GGAL  8.15
# 4       False      REGULAR      USD   GGAL  8.15
# 5       False      REGULAR      USD   GGAL  8.15
# 6       False      REGULAR      USD   GGAL  8.15
# 7       False      REGULAR      USD   GGAL  8.15
# 8       False      REGULAR      USD   GGAL  8.15
# 0       False      REGULAR      USD   GGAL  8.15
# 1       False      REGULAR      USD   GGAL  8.15
# 2        True      REGULAR      USD   GGAL  8.15
# 0       False      REGULAR      USD   GGAL  8.15
# 1       False      REGULAR      USD   GGAL  8.15
# 2        True      REGULAR      USD   GGAL  8.15
# 0       False      REGULAR      USD   GGAL  8.15
# 1       False      REGULAR      USD   GGAL  8.15
# 2        True      REGULAR      USD   GGAL  8.15
# 0       False      REGULAR      USD   GGAL  8.15
# 1       False      REGULAR      USD   GGAL  8.15
# 2       False      REGULAR      USD   GGAL  8.15
# 3        True      REGULAR      USD   GGAL  8.15
# 4        True      REGULAR      USD   GGAL  8.15
# 5        True      REGULAR      USD   GGAL  8.15
# 6        True      REGULAR      USD   GGAL  8.15
# 7        True      REGULAR      USD   GGAL  8.15
# 0       False      REGULAR      USD   GGAL  8.15
# 1       False      REGULAR      USD   GGAL  8.15
# 2        True      REGULAR      USD   GGAL  8.15
# 3        True      REGULAR      USD   GGAL  8.15

# %%
panel_ociones_GGAL_nyse_clean = obtener_panel_opciones_nyse('GGAL', True)
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)

# %%
panel_ociones_GGAL_nyse_clean
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last  Moneyness  \
# 0   GGAL220819C00002500   GGAL  8.15       C     2.5    1   5.40   3.260000
# 1   GGAL220819C00005000   GGAL  8.15       C     5.0    1   3.16   1.630000
# 2   GGAL220819P00005000   GGAL  8.15       P     5.0    1   0.05   1.630000
# 3   GGAL220819C00007500   GGAL  8.15       C     7.5    1   0.65   1.086667
# 4   GGAL220819P00007500   GGAL  8.15       P     7.5    1   0.20   1.086667
# 5   GGAL220819C00010000   GGAL  8.15       C    10.0    1   0.05   0.815000
# 6   GGAL220819P00010000   GGAL  8.15       P    10.0    1   3.50   0.815000
# 7   GGAL220916C00005000   GGAL  8.15       C     5.0   29   2.76   1.630000
# 8   GGAL220916P00005000   GGAL  8.15       P     5.0   29   0.17   1.630000
# 9   GGAL220916C00007500   GGAL  8.15       C     7.5   29   0.97   1.086667
# 10  GGAL220916P00007500   GGAL  8.15       P     7.5   29   0.30   1.086667
# 11  GGAL220916C00010000   GGAL  8.15       C    10.0   29   0.05   0.815000
# 12  GGAL220916P00010000   GGAL  8.15       P    10.0   29   4.00   0.815000
# 49  GGAL240119C00017500   GGAL  8.15       C    17.5  519   0.35   0.465714
# 50  GGAL240119C00020000   GGAL  8.15       C    20.0  519   1.15   0.407500
# 51  GGAL240119C00022500   GGAL  8.15       C    22.5  519   0.75   0.362222
#
#     impliedVolatility    Bid    Ask
# 0            9.250004   5.50   5.70
# 1            4.218755   3.00   3.20
# 2            4.625004   0.00   0.15
# 3            1.093755   0.60   0.80
# 4            0.250007   0.00   0.00
# 5            2.578129   0.00   0.25
# 6            3.828125   1.00   2.20
# 7            1.093755   3.10   3.30
# 8            1.285160   0.00   0.20
# 9            0.570317   0.80   1.00
# 10           0.539067   0.15   0.30
# 11           0.570317   0.00   0.15
# 12           0.621098   1.85   2.05
# 13           0.742190   2.90   3.50
# 14           0.250007   0.00   0.00
# 15           0.736331   1.00   1.65
# 16           0.513677   0.35   0.45
# 17           0.480474   0.05   0.15
# 18           0.582035   1.90   2.10
# 19           0.744143   0.00   0.25
# 20           0.957032   0.00   0.25
# 21           1.281254   0.00   0.45
# 22           3.332033   4.50   9.50
# 23           0.500005   0.00   0.00
# 24           0.630863   3.20   3.40
# 25           0.250007   0.05   0.00
# 26           0.500982   1.30   1.45
# 27           0.513677   0.65   0.75
# 28           0.513677   0.40   0.50
# 29           0.487310   2.15   2.30
# 30           0.525395   0.05   0.30
# 31           1.505862   5.20   7.60
# 32           0.617191   0.00   0.25
# 33           0.644535   6.10   7.00
# 34           0.724612   0.00   0.25
# 35           0.000010   7.40   8.90
# 36           0.814455   0.00   0.25
# 37           0.000010  10.50  11.50
# 38           1.003911   0.05   0.40
# 39           1.376956   1.50   6.50
# 40           0.555180   3.50   3.90
# 41           0.644535   0.05   1.45
# 42           0.513188   1.90   2.55
# 43           0.708987   0.40   2.25
# 44           0.713870   0.35   2.15
# 45           0.714358   1.90   4.00
# 46           0.537114   0.10   0.95
# 47           0.574711   0.25   0.75
# 48           1.080083   4.50   9.50
# 49           0.528813   0.10   0.40
# 50           1.148930   0.05   4.70
# 51           1.157719   0.30   4.10

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance

# %%
ticker = 'TSLA'
data = yf.Ticker(ticker)

#Data es un objeto
# data.info contiene informacion (mucha) del activo

data.info
# Out:
# {'zip': '78725',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 99290,
#  'longBusinessSummary': 'Tesla, Inc. designs, develops, manufactures, leases, and sells electric vehicles, and energy generation and storage systems in the United States, China, and internationally. The company operates in two segments, Automotive, and Energy Generation and Storage. The Automotive segment offers electric vehicles, as well as sells automotive regulatory credits. It provides sedans and sport utility vehicles through direct and used vehicle sales, a network of Tesla Superchargers, and in-app upgrades; and purchase financing and leasing services. This segment is also involved in the provision of non-warranty after-sales vehicle services, sale of used vehicles, retail merchandise, and vehicle insurance, as well as sale of products to third party customers; services for electric vehicles through its company-owned service locations, and Tesla mobile service technicians; and vehicle limited warranties and extended service plans. The Energy Generation and Storage segment engages in the design, manufacture, installation, sale, and leasing of solar energy generation and energy storage products, and related services to residential, commercial, and industrial customers and utilities through its website, stores, and galleries, as well as through a network of channel partners. This segment also offers service and repairs to its energy product customers, including under warranty; and various financing options to its solar customers. The company was formerly known as Tesla Motors, Inc. and changed its name to Tesla, Inc. in February 2017. Tesla, Inc. was incorporated in 2003 and is headquartered in Austin, Texas.',
#  'city': 'Austin',
#  'phone': '(512) 516-8177',
#  'state': 'TX',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.tesla.com',
#  'maxAge': 1,
#  'address1': '13101 Tesla Road',
#  'industry': 'Auto Manufacturers',
#  'ebitdaMargins': 0.20889,
#  'profitMargins': 0.14168,
#  'grossMargins': 0.27099,
#  'operatingCashflow': 14078000128,
#  'revenueGrowth': 0.416,
#  'operatingMargins': 0.16139,
#  'ebitda': 14030000128,
#  'targetLowPrice': 73,
#  'recommendationKey': 'buy',
#  'grossProfits': 13606000000,
#  'freeCashflow': 5962749952,
#  'targetMedianPrice': 950,
#  'currentPrice': 910.8599,
#  'earningsGrowth': 0.907,
#  'currentRatio': 1.431,
#  'returnOnAssets': 0.10957,
#  'numberOfAnalystOpinions': 39,
#  'targetMeanPrice': 884.56,
#  'debtToEquity': 17.699,
#  'returnOnEquity': 0.2989,
#  'targetHighPrice': 1300,
#  'totalCash': 18915000320,
#  'totalDebt': 6664999936,
#  'totalRevenue': 67165999104,
#  'totalCashPerShare': 18.109,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 65.785,
#  'quickRatio': 0.968,
#  'recommendationMean': 2.4,
#  'exchange': 'NMS',
#  'shortName': 'Tesla, Inc.',
#  'longName': 'Tesla, Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'TSLA',
#  'messageBoardId': 'finmb_27444752',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 14.267,
#  'beta3Year': None,
#  'enterpriseToEbitda': 68.302,
#  '52WeekChange': 0.3541658,
#  'morningStarRiskRating': None,
#  'forwardEps': 15.93,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 1044489984,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 34.943,
#  'sharesShort': 25022667,
#  'sharesPercentSharesOut': 0.024,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.44344002,
#  'netIncomeToCommon': 9521000448,
#  'trailingEps': 8.57,
#  'lastDividendValue': None,
#  'SandP52WeekChange': -0.029906034,
#  'priceToBook': 26.06702,
#  'heldPercentInsiders': 0.1719,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1656547200,
#  'shortRatio': 0.86,
#  'sharesShortPreviousMonthDate': 1656547200,
#  'floatShares': 873130983,
#  'beta': 2.176087,
#  'enterpriseValue': 958276960256,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '5:1',
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.978,
#  'priceToSalesTrailing12Months': 14.164668,
#  'dateShortInterest': 1659052800,
#  'pegRatio': None,
#  'ytdReturn': None,
#  'forwardPE': 57.1789,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0292,
#  'sharesShortPriorMonth': 27101597,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 911.99,
#  'regularMarketOpen': 918,
#  'twoHundredDayAverage': 906.8334,
#  'trailingAnnualDividendYield': 0,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 919.5,
#  'navPrice': None,
#  'averageDailyVolume10Day': 28696620,
#  'regularMarketPreviousClose': 911.99,
#  'fiftyDayAverage': 770.474,
#  'trailingAnnualDividendRate': 0,
#  'open': 918,
#  'toCurrency': None,
#  'averageVolume10days': 28696620,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 905.56,
#  'currency': 'USD',
#  'trailingPE': 106.284706,
#  'regularMarketVolume': 13499686,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 951384080384,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 30711504,
#  'dayLow': 905.56,
#  'ask': 908.99,
#  'askSize': 1400,
#  'volume': 13499686,
#  'fiftyTwoWeekHigh': 1243.49,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 620.57,
#  'bid': 908.75,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 1100,
#  'dayHigh': 919.5,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 910.8599,
#  'preMarketPrice': 918.12,
#  'logo_url': 'https://logo.clearbit.com/tesla.com',
#  'trailingPegRatio': 2.1837}

# %%
# Spot price

hist = data.history()

spot = hist.tail(1)['Close'].iloc[0]

hist.tail(10)['Close']
# Out:
# Date
# 2022-08-05    864.510010
# 2022-08-08    871.270020
# 2022-08-09    850.000000
# 2022-08-10    883.070007
# 2022-08-11    859.890015
# 2022-08-12    900.090027
# 2022-08-15    927.960022
# 2022-08-16    919.690002
# 2022-08-17    911.989990
# 2022-08-18    910.500000
# Name: Close, dtype: float64

# %%
# Vencimientos de opciones
vencimientos = data.options

vencimientos
# Out:
# ('2022-08-19',
#  '2022-08-26',
#  '2022-09-02',
#  '2022-09-09',
#  '2022-09-16',
#  '2022-09-23',
#  '2022-09-30',
#  '2022-10-21',
#  '2022-11-18',
#  '2022-12-16',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-04-21',
#  '2023-06-16',
#  '2023-09-15',
#  '2024-01-19',
#  '2024-03-15',
#  '2024-06-21')

# %%
# Calls y puts
calls = data.option_chain(vencimientos[0])[0]
puts = data.option_chain(vencimientos[0])[1]

calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    TSLA220819C00050000 2022-08-18 18:35:51+00:00    50.0     857.80  858.45
# 1    TSLA220819C00100000 2022-08-18 18:35:55+00:00   100.0     807.65  808.40
# 2    TSLA220819C00150000 2022-08-18 18:30:29+00:00   150.0     759.70  758.50
# 3    TSLA220819C00200000 2022-08-18 17:58:24+00:00   200.0     711.80  708.40
# 4    TSLA220819C00250000 2022-08-18 17:24:04+00:00   250.0     663.25  658.55
# ..                   ...                       ...     ...        ...     ...
# 177  TSLA220819C02200000 2022-08-16 16:02:40+00:00  2200.0       0.01    0.00
# 178  TSLA220819C02250000 2022-08-16 13:30:05+00:00  2250.0       0.01    0.00
# 179  TSLA220819C02300000 2022-08-10 13:41:42+00:00  2300.0       0.01    0.00
# 180  TSLA220819C02350000 2022-08-10 14:32:22+00:00  2350.0       0.01    0.00
# 181  TSLA220819C02400000 2022-08-18 18:44:10+00:00  2400.0       0.01    0.00
#
#         ask     change  percentChange  volume  openInterest  \
# 0    859.65 -16.650024      -1.904057     129            31
# 1    809.40  -4.099976      -0.505079     103            75
# 2    759.40   7.350037       0.976944      34            16
# 3    709.35  -9.400024      -1.303387      44            12
# 4    659.40 -14.299988      -2.110543      34            41
# ..      ...        ...            ...     ...           ...
# 177    0.01   0.000000       0.000000      11           627
# 178    0.00   0.000000       0.000000       1           632
# 179    0.01   0.000000       0.000000       7           658
# 180    0.01   0.000000       0.000000       1           672
# 181    0.01   0.000000       0.000000      17          8340
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             0.000010        True      REGULAR      USD
# 1             0.000010        True      REGULAR      USD
# 2             0.000010        True      REGULAR      USD
# 3             0.000010        True      REGULAR      USD
# 4             0.000010        True      REGULAR      USD
# ..                 ...         ...          ...      ...
# 177           3.125002       False      REGULAR      USD
# 178           0.500005       False      REGULAR      USD
# 179           3.250002       False      REGULAR      USD
# 180           3.312502       False      REGULAR      USD
# 181           3.375002       False      REGULAR      USD
#
# [182 rows x 14 columns]

# %% [markdown]
# ### Que hace internamente el metodo??

# %%
#Recorro cada vencimiento disponible y voy tomando calls por un lado y puts por otro
for vencimiento in vencimientos[1:]:
        calls = calls.append(data.option_chain(vencimiento)[0])
        puts = puts.append(data.option_chain(vencimiento)[1])

#Uno los puts y los calls
panel_opciones = calls.append(puts)

# Le agrego dos columnas utiles - Ticker y Spot

panel_opciones['Spot'] = hist.tail(1)['Close'].iloc[0]
panel_opciones['Ticker'] = ticker

panel_opciones.head(10)
# Out:
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\3234569746.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
#         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0  TSLA220819C00050000 2022-08-18 18:35:51+00:00    50.0     857.80  858.45
# 1  TSLA220819C00100000 2022-08-18 18:35:55+00:00   100.0     807.65  808.40
# 2  TSLA220819C00150000 2022-08-18 18:30:29+00:00   150.0     759.70  758.50
# 3  TSLA220819C00200000 2022-08-18 17:58:24+00:00   200.0     711.80  708.40
# 4  TSLA220819C00250000 2022-08-18 17:24:04+00:00   250.0     663.25  658.55
# 3            0.00001        True      REGULAR      USD  910.5   TSLA
# 4            0.00001        True      REGULAR      USD  910.5   TSLA
#
#    Moneyness  TTM CallPut
# 0        0.0    0
# 1        0.0    0
# 2        0.0    0
# 3        0.0    0
# 4        0.0    0

# %% [markdown]
# #### *) Recorro las filas (1ra como ejemplo)

# %%
idx = panel_opciones.index.values[0]

# %%
callput = panel_opciones.contractSymbol.values[idx][10:11]
panel_opciones['CallPut'].values[idx] = callput

# %%
year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
month = int(panel_opciones.contractSymbol.values[idx][6:8])
day = int(panel_opciones.contractSymbol.values[idx][8:10])

hoy = datetime.date.today()
expiry_datetime = datetime.date(year, month, day)
ttm = (expiry_datetime - hoy).days

panel_opciones['TTM'].values[idx] = ttm

# %%
panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(2)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  TSLA220819C00050000 2022-08-18 18:35:51+00:00    50.0     857.80
# 1      1  TSLA220819C00100000 2022-08-18 18:35:55+00:00   100.0     807.65
#
#       bid     ask     change  percentChange  volume  openInterest  \
# 0  858.45  859.65 -16.650024      -1.904057   129.0          31.0
# 1  808.40  809.40  -4.099976      -0.505079   103.0          75.0
#
#    impliedVolatility  inTheMoney contractSize currency   Spot Ticker  \
# 0            0.00001        True      REGULAR      USD  910.5   TSLA
# 1            0.00001        True      REGULAR      USD  910.5   TSLA
#
#    Moneyness  TTM CallPut
# 0      18.21    1       C
# 1       0.00    0

# %% [markdown]
# #### *) Recorro las filas (las restantes como ejemplo)

# %%
for idx in list(panel_opciones.index.values[1:]):
        year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
        month = int(panel_opciones.contractSymbol.values[idx][6:8])
        day = int(panel_opciones.contractSymbol.values[idx][8:10])
        
        hoy = datetime.date.today()
        expiry_datetime = datetime.date(year, month, day)
        ttm = (expiry_datetime - hoy).days

        panel_opciones['TTM'].values[idx] = ttm
        callput = panel_opciones.contractSymbol.values[idx][10:11]
        panel_opciones['CallPut'].values[idx] = callput
        
panel_opciones.Moneyness = panel_opciones.Spot/ panel_opciones.strike

# %%
panel_opciones.head(10)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  TSLA220819C00050000 2022-08-18 18:35:51+00:00    50.0     857.80
# 1      1  TSLA220819C00100000 2022-08-18 18:35:55+00:00   100.0     807.65
# 2      2  TSLA220819C00150000 2022-08-18 18:30:29+00:00   150.0     759.70
# 3      3  TSLA220819C00200000 2022-08-18 17:58:24+00:00   200.0     711.80
# 4      4  TSLA220819C00250000 2022-08-18 17:24:04+00:00   250.0     663.25
# 5      5  TSLA220819C00300000 2022-08-18 15:43:24+00:00   300.0     615.70
# 6      6  TSLA220819C00340000 2022-08-18 18:35:55+00:00   340.0     567.85
# 7      7  TSLA220819C00350000 2022-08-16 18:36:56+00:00   350.0     563.30
# 8      8  TSLA220819C00360000 2022-08-18 14:31:18+00:00   360.0     550.40
# 9      9  TSLA220819C00370000 2022-08-18 14:24:08+00:00   370.0     542.90
#
#       bid     ask     change  percentChange  volume  openInterest  \
# 0  858.45  859.65 -16.650024      -1.904057   129.0          31.0
# 1  808.40  809.40  -4.099976      -0.505079   103.0          75.0
# 2  758.50  759.40   7.350037       0.976944    34.0          16.0
# 3  708.40  709.35  -9.400024      -1.303387    44.0          12.0
# 4  658.55  659.40 -14.299988      -2.110543    34.0          41.0
# 5  608.55  609.40  -6.599976      -1.060578    32.0          61.0
# 6  568.35  569.30  -8.000000      -1.389251     6.0          16.0
# 7  558.35  559.55  -9.750000      -1.701422    23.0          65.0
# 8  548.35  549.65 -13.500000      -2.394041     6.0          22.0
# 9  538.55  539.35 -13.649963      -2.452603    12.0          12.0
#
#    impliedVolatility  inTheMoney contractSize currency   Spot Ticker  \
# 0            0.00001        True      REGULAR      USD  910.5   TSLA
# 1            0.00001        True      REGULAR      USD  910.5   TSLA
# 2            0.00001        True      REGULAR      USD  910.5   TSLA
# 3            0.00001        True      REGULAR      USD  910.5   TSLA
# 4            0.00001        True      REGULAR      USD  910.5   TSLA
# 5            0.00001        True      REGULAR      USD  910.5   TSLA
# 6            0.00001        True      REGULAR      USD  910.5   TSLA
# 7            0.00001        True      REGULAR      USD  910.5   TSLA
# 8            0.00001        True      REGULAR      USD  910.5   TSLA
# 9            0.00001        True      REGULAR      USD  910.5   TSLA
#
#    Moneyness  TTM CallPut
# 0  18.210000    1       C
# 1   9.105000    1       C
# 2   6.070000    1       C
# 3   4.552500    1       C
# 4   3.642000    1       C
# 5   3.035000    1       C
# 6   2.677941    1       C
# 7   2.601429    1       C
# 8   2.529167    1       C
# 9   2.460811    1       C

# %% [markdown]
# #### Panel Limpio

# %%
panel_opciones = panel_opciones.rename(
            columns={'lastTradeDate': 'Last_Date', 'contractSymbol': 'Especie', 'strike': 'Strike', 'bid': 'Bid',
                     'ask': 'Ask', 'lastPrice': 'Last'}, inplace=False)

panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])

panel_opciones = panel_opciones[['Especie', 'Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Bid','Ask','impliedVolatility','Moneyness']]

# %%
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']
panel_opciones
# Out:
#                   Especie Ticker   Spot CallPut  Strike  TTM     Last  \
# 0     TSLA220819C00050000   TSLA  910.5       C    50.0    1   857.80
# 1     TSLA220819P00050000   TSLA  910.5       P    50.0    1     0.01
# 2     TSLA220819C00100000   TSLA  910.5       C   100.0    1   807.65
# 3     TSLA220819P00100000   TSLA  910.5       P   100.0    1     0.01
# 4     TSLA220819C00150000   TSLA  910.5       C   150.0    1   759.70
# ...                   ...    ...    ...     ...     ...  ...      ...
# 4778  TSLA240621P02200000   TSLA  910.5       P  2200.0  673  1300.02
# 4779  TSLA240621C02250000   TSLA  910.5       C  2250.0  673    74.80
# 4780  TSLA240621P02250000   TSLA  910.5       P  2250.0  673  1350.97
# 4781  TSLA240621C02275000   TSLA  910.5       C  2275.0  673    72.00
# 4782  TSLA240621P02275000   TSLA  910.5       P  2275.0  673  1373.35
#
#           Bid      Ask  impliedVolatility  Moneyness
# 0      858.45   859.65           0.000010  18.210000
# 1        0.00     0.00           0.500005  18.210000
# 2      808.40   809.40           0.000010   9.105000
# 3        0.00     0.00           0.500005   9.105000
# 4      758.50   759.40           0.000010   6.070000
# ...       ...      ...                ...        ...
# 4778  1296.25  1307.20           0.408194   0.413864
# 4779    70.65    75.15           0.595974   0.404667
# 4780  1344.50  1355.00           0.404532   0.404667
# 4781    69.25    71.80           0.593872   0.400220
# 4782  1369.70  1378.65           0.400893   0.400220
#
# [4783 rows x 11 columns]

# %% [markdown]
# ## 2) Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# NYSE
panel_opciones_limpio = obtener_panel_opciones_nyse('TSLA', True)
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)

# %%
TTMs = list(set(panel_opciones_limpio.TTM.values))
TTMs.sort()

TTMs
# Out:
# [1, 8, 15, 22, 29, 36, 43, 64, 92, 120, 155, 211, 246, 302, 393, 519, 575, 673]

# %%
TTM = 8
panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == "C")].head(10)
# Out:
#                  Especie Ticker        Spot CallPut  Strike  TTM    Last  \
# 364  TSLA220826C00250000   TSLA  910.700012       C   250.0    8  664.10
# 366  TSLA220826C00300000   TSLA  910.700012       C   300.0    8  615.10
# 368  TSLA220826C00350000   TSLA  910.700012       C   350.0    8  559.90
# 370  TSLA220826C00400000   TSLA  910.700012       C   400.0    8  509.95
# 372  TSLA220826C00420000   TSLA  910.700012       C   420.0    8  493.50
# 374  TSLA220826C00440000   TSLA  910.700012       C   440.0    8  471.50
# 376  TSLA220826C00450000   TSLA  910.700012       C   450.0    8  466.70
# 378  TSLA220826C00460000   TSLA  910.700012       C   460.0    8  467.60
# 380  TSLA220826C00470000   TSLA  910.700012       C   470.0    8  452.90
# 382  TSLA220826C00480000   TSLA  910.700012       C   480.0    8  430.85
#
#      Moneyness  impliedVolatility     Bid     Ask
# 364   3.642800            0.00001  658.50  659.50
# 366   3.035667            0.00001  608.40  609.50
# 368   2.602000            0.00001  558.40  559.55
# 370   2.276750            0.00001  508.40  509.70
# 372   2.168333            0.00001  488.60  490.00
# 374   2.069773            0.00001  468.45  469.80
# 376   2.023778            0.00001  458.45  459.75
# 378   1.979783            0.00001  448.40  449.85
# 380   1.937660            0.00001  438.40  440.30
# 382   1.897292            0.00001  428.65  429.85

# %%
TTMs
# Out:
# [1, 8, 15, 22, 29, 36, 43, 64, 92, 120, 155, 211, 246, 302, 393, 519, 575, 673]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[0:4]:
    Ks = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Last.values
    ## Last VS (B+A)/2
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs[0:3]:
    Ks = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %% [markdown]
# ### Para cada strike, grafico los TTM

# %%
Ks = list(set(panel_opciones_limpio.Strike.values))
Ks.sort()

Ks
# Out:
# [5.0,
#  10.0,
#  15.0,
#  20.0,
#  25.0,
#  30.0,
#  35.0,
#  40.0,
#  45.0,
#  50.0,
#  55.0,
#  60.0,
#  65.0,
#  70.0,
#  75.0,
#  80.0,
#  85.0,
#  90.0,
#  95.0,
#  100.0,
#  120.0,
#  130.0,
#  140.0,
#  150.0,
#  160.0,
#  180.0,
#  190.0,
#  200.0,
#  204.0,
#  208.0,
#  210.0,
#  212.0,
#  216.0,
#  220.0,
#  224.0,
#  228.0,
#  230.0,
#  232.0,
#  236.0,
#  240.0,
#  244.0,
#  248.0,
#  250.0,
#  252.0,
#  256.0,
#  260.0,
#  264.0,
#  268.0,
#  270.0,
#  272.0,
#  276.0,
#  280.0,
#  284.0,
#  288.0,
#  290.0,
#  292.0,
#  296.0,
#  300.0,
#  304.0,
#  308.0,
#  310.0,
#  312.0,
#  316.0,
#  320.0,
#  324.0,
#  325.0,
#  328.0,
#  330.0,
#  332.0,
#  335.0,
#  336.0,
#  340.0,
#  344.0,
#  345.0,
#  348.0,
#  350.0,
#  352.0,
#  355.0,
#  356.0,
#  360.0,
#  364.0,
#  365.0,
#  368.0,
#  370.0,
#  372.0,
#  375.0,
#  376.0,
#  380.0,
#  384.0,
#  385.0,
#  388.0,
#  390.0,
#  392.0,
#  395.0,
#  396.0,
#  400.0,
#  405.0,
#  410.0,
#  420.0,
#  425.0,
#  430.0,
#  440.0,
#  450.0,
#  460.0,
#  470.0,
#  475.0,
#  480.0,
#  490.0,
#  500.0,
#  505.0,
#  510.0,
#  515.0,
#  520.0,
#  525.0,
#  530.0,
#  535.0,
#  540.0,
#  545.0,
#  550.0,
#  555.0,
#  560.0,
#  565.0,
#  570.0,
#  575.0,
#  580.0,
#  585.0,
#  590.0,
#  595.0,
#  600.0,
#  605.0,
#  610.0,
#  615.0,
#  620.0,
#  625.0,
#  630.0,
#  635.0,
#  640.0,
#  645.0,
#  650.0,
#  655.0,
#  660.0,
#  665.0,
#  670.0,
#  675.0,
#  680.0,
#  685.0,
#  690.0,
#  692.5,
#  695.0,
#  697.5,
#  700.0,
#  705.0,
#  710.0,
#  712.5,
#  715.0,
#  717.5,
#  720.0,
#  722.5,
#  725.0,
#  727.5,
#  730.0,
#  732.5,
#  735.0,
#  740.0,
#  745.0,
#  750.0,
#  755.0,
#  760.0,
#  765.0,
#  770.0,
#  775.0,
#  780.0,
#  785.0,
#  790.0,
#  795.0,
#  800.0,
#  805.0,
#  810.0,
#  815.0,
#  820.0,
#  825.0,
#  830.0,
#  835.0,
#  840.0,
#  845.0,
#  850.0,
#  855.0,
#  860.0,
#  865.0,
#  867.5,
#  870.0,
#  872.5,
#  875.0,
#  877.5,
#  880.0,
#  882.5,
#  885.0,
#  887.5,
#  890.0,
#  895.0,
#  900.0,
#  905.0,
#  910.0,
#  912.5,
#  915.0,
#  917.5,
#  920.0,
#  922.5,
#  925.0,
#  930.0,
#  935.0,
#  940.0,
#  945.0,
#  950.0,
#  955.0,
#  960.0,
#  965.0,
#  970.0,
#  975.0,
#  980.0,
#  985.0,
#  990.0,
#  995.0,
#  1000.0,
#  1005.0,
#  1010.0,
#  1015.0,
#  1020.0,
#  1025.0,
#  1030.0,
#  1035.0,
#  1040.0,
#  1045.0,
#  1050.0,
#  1055.0,
#  1060.0,
#  1065.0,
#  1070.0,
#  1075.0,
#  1080.0,
#  1085.0,
#  1090.0,
#  1095.0,
#  1100.0,
#  1105.0,
#  1110.0,
#  1115.0,
#  1120.0,
#  1125.0,
#  1130.0,
#  1135.0,
#  1140.0,
#  1145.0,
#  1150.0,
#  1160.0,
#  1170.0,
#  1175.0,
#  1180.0,
#  1190.0,
#  1200.0,
#  1220.0,
#  1225.0,
#  1240.0,
#  1250.0,
#  1260.0,
#  1275.0,
#  1280.0,
#  1290.0,
#  1300.0,
#  1310.0,
#  1320.0,
#  1325.0,
#  1340.0,
#  1350.0,
#  1360.0,
#  1375.0,
#  1380.0,
#  1400.0,
#  1420.0,
#  1425.0,
#  1440.0,
#  1450.0,
#  1460.0,
#  1475.0,
#  1480.0,
#  1500.0,
#  1520.0,
#  1525.0,
#  1540.0,
#  1550.0,
#  1560.0,
#  1575.0,
#  1580.0,
#  1600.0,
#  1620.0,
#  1625.0,
#  1640.0,
#  1650.0,
#  1660.0,
#  1675.0,
#  1680.0,
#  1700.0,
#  1720.0,
#  1725.0,
#  1740.0,
#  1750.0,
#  1760.0,
#  1775.0,
#  1780.0,
#  1800.0,
#  1820.0,
#  1825.0,
#  1840.0,
#  1850.0,
#  1860.0,
#  1875.0,
#  1880.0,
#  1900.0,
#  1920.0,
#  1925.0,
#  1940.0,
#  1950.0,
#  1960.0,
#  1975.0,
#  1980.0,
#  2000.0,
#  2025.0,
#  2050.0,
#  2075.0,
#  2100.0,
#  2125.0,
#  2150.0,
#  2175.0,
#  2200.0,
#  2225.0,
#  2250.0,
#  2275.0,
#  2300.0,
#  2325.0,
#  2350.0,
#  2375.0,
#  2400.0,
#  2425.0,
#  2450.0,
#  2475.0,
#  2500.0,
#  2550.0,
#  2600.0,
#  2650.0,
#  2700.0,
#  2750.0,
#  2800.0,
#  2850.0,
#  2900.0,
#  2950.0,
#  3000.0,
#  3050.0,
#  3100.0,
#  3200.0,
#  3300.0,
#  3400.0,
#  3500.0,
#  3600.0,
#  3700.0,
#  3800.0,
#  3900.0,
#  4000.0,
#  4100.0,
#  4200.0]

# %%
panel_opciones_limpio.head(10)
# Out:
#                Especie Ticker        Spot CallPut  Strike  TTM    Last  \
# 0  TSLA220819C00050000   TSLA  910.700012       C    50.0    1  857.80
# 1  TSLA220819P00050000   TSLA  910.700012       P    50.0    1    0.01
# 2  TSLA220819C00100000   TSLA  910.700012       C   100.0    1  807.65
# 3  TSLA220819P00100000   TSLA  910.700012       P   100.0    1    0.01
# 4  TSLA220819C00150000   TSLA  910.700012       C   150.0    1  759.70
# 5  TSLA220819P00150000   TSLA  910.700012       P   150.0    1    0.01
# 6  TSLA220819C00200000   TSLA  910.700012       C   200.0    1  711.80
# 7  TSLA220819P00200000   TSLA  910.700012       P   200.0    1    0.01
# 8  TSLA220819C00250000   TSLA  910.700012       C   250.0    1  663.25
# 9  TSLA220819P00250000   TSLA  910.700012       P   250.0    1    0.01
#
#    Moneyness  impliedVolatility     Bid     Ask
# 0  18.214000           0.000010  858.45  859.65
# 1  18.214000           0.500005    0.00    0.00
# 2   9.107000           0.000010  808.40  809.40
# 3   9.107000           0.500005    0.00    0.00
# 4   6.071333           0.000010  758.50  759.40
# 5   6.071333           6.625002    0.00    0.01
# 6   4.553500           0.000010  708.40  709.35
# 7   4.553500           5.625003    0.00    0.01
# 8   3.642800           0.000010  658.10  659.15
# 9   3.642800           4.750004    0.00    0.01

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[275:280]:
    TTMs = panel_opciones_limpio[(panel_opciones_limpio.Strike == K) & (panel_opciones_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_limpio[(panel_opciones_limpio.Strike == K) & (panel_opciones_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Volatilidad implicita

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[0:4]:
    Ks = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Strike.values
    volatilidades = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].impliedVolatility.values
    ## Last VS (B+A)/2
    plt.plot(Ks, volatilidades,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Volatilidad Implicita')
plt.title('Volatilidad Implicita del Call con respecto al strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[0:4]:
    Ks = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Strike.values
    volatilidades = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].impliedVolatility.values
    ## Last VS (B+A)/2
    plt.plot(Ks, volatilidades,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Volatilidad Implicita')
plt.title('Volatilidad Implicita del Put con respecto al strike')
    
plt.show()

# %% [markdown]
# ## Pasar a Excel

# %%
panel_opciones_crudo = obtener_panel_opciones_nyse('GGAL', False)
panel_opciones_crudo.to_excel('Clase_1_panel_opciones_crudo.xls')

panel_opciones_limpio = obtener_panel_opciones_nyse('TSLA', True)
panel_opciones_limpio.to_excel('Clase_1_panel_opciones_limpio.xls')
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# C:\Users\manue\AppData\Local\Temp\ipykernel_22680\4099121486.py:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   panel_opciones_crudo.to_excel('Clase_1_panel_opciones_crudo.xls')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Codigo\Data de Yahoo y graficos.ipynb Cell 49 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Codigo/Data%20de%20Yahoo%20y%20graficos.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> panel_opciones_crudo = obtener_panel_opciones_nyse('GGAL', False)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Codigo/Data%20de%20Yahoo%20y%20graficos.ipynb#X66sZmlsZQ%3D%3D?line=1'>2</a> panel_opciones_crudo.to_excel('Clase_1_panel_opciones_crudo.xls')
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Codigo/Data%20de%20Yahoo%20y%20graficos.ipynb#X66sZmlsZQ%3D%3D?line=3'>4</a> panel_opciones_limpio = obtener_panel_opciones_nyse('TSLA', True)
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Codigo/Data%20de%20Yahoo%20y%20graficos.ipynb#X66sZmlsZQ%3D%3D?line=4'>5</a> panel_opciones_limpio.to_excel('Clase_1_panel_opciones_limpio.xls')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\formats\excel.py:888, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884     need_save = False
#     885 else:
#     886     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888     writer = ExcelWriter(  # type: ignore[abstract]
#     889         writer, engine=engine, storage_options=storage_options
#     890     )
#     891     need_save = True
#     893 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\excel\_xlwt.py:39, in XlwtWriter.__init__(self, path, engine, date_format, datetime_format, encoding, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      25 def __init__(
#      26     self,
#      27     path,
#    (...)
#      37 ):
#      38     # Use the xlwt module as the Excel writer.
# ---> 39     import xlwt
#      41     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      43     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlwt'
