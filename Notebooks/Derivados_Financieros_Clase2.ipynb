# %% [markdown]
# # Derivados Financieros 2022 - Clase 2

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance
# ## 2) Plots
# ## 3) Payoffs - Estraegias

# %%
### Importo los modulos
import sys
sys.path.append('..')
from Codigo.data_nyse import *

import yfinance as yf
import datetime

# %% [markdown]
# ## API Yahoo finance

# %% [markdown]
# Modulos necesarios
#
# data_nyse (en webcampus) ;
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# yfinance, (yfinance-0.1.63 - tuve que actualizar reicentemente)
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install
#
#
# urllib.requestatexit
# datetime
# dateutil
#
# import tda
# json
# selenium, webdriver

# %% [markdown]
# ## Queremos emular lo que hicimos para BYMA

# %%
### Metodo para el web scraping
panel_yahoo_GGAL = obtener_opciones_yahoo_finance('GGAL')
panel_yahoo_GGAL
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
#         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0  GGAL220819C00002500 2022-07-29 18:25:01+00:00     2.5       5.40   5.50
# 1  GGAL220819C00005000 2022-08-18 14:38:46+00:00     5.0       3.16   3.00
# 2  GGAL220819C00007500 2022-08-18 16:33:53+00:00     7.5       0.65   0.60
# 3  GGAL220819C00010000 2022-08-15 16:57:53+00:00    10.0       0.05   0.00
# 0  GGAL220916C00005000 2022-08-04 16:37:47+00:00     5.0       2.76   3.10
# 1  GGAL220916C00007500 2022-08-15 19:01:53+00:00     7.5       0.97   0.80
# 2  GGAL220916C00010000 2022-08-16 14:47:27+00:00    10.0       0.05   0.00
# 0  GGAL221021C00005000 2022-07-29 19:03:30+00:00     5.0       3.00   2.90
# 1  GGAL221021C00007500 2022-08-17 18:11:42+00:00     7.5       1.07   0.95
# 2  GGAL221021C00010000 2022-08-12 14:16:19+00:00    10.0       0.15   0.05
# 3  GGAL221021C00012500 2022-07-29 14:46:00+00:00    12.5       0.05   0.00
# 4  GGAL221021C00015000 2022-08-08 15:23:35+00:00    15.0       0.05   0.00
# 5  GGAL221021C00017500 2022-04-04 16:46:19+00:00    17.5       0.34   0.00
# 0  GGAL230120C00002500 2021-11-03 15:23:48+00:00     2.5       8.90   4.50
# 1  GGAL230120C00005000 2022-08-18 15:58:34+00:00     5.0       3.32   3.20
# 2  GGAL230120C00007500 2022-08-18 16:33:53+00:00     7.5       1.35   1.30
# 3  GGAL230120C00010000 2022-08-18 16:53:10+00:00    10.0       0.45   0.40
# 4  GGAL230120C00012500 2022-08-09 15:36:35+00:00    12.5       0.06   0.05
# 5  GGAL230120C00015000 2022-07-27 19:41:31+00:00    15.0       0.08   0.00
# 6  GGAL230120C00017500 2022-07-08 14:32:36+00:00    17.5       0.15   0.00
# 7  GGAL230120C00020000 2022-05-25 16:02:22+00:00    20.0       0.05   0.00
# 8  GGAL230120C00022500 2022-03-09 18:38:57+00:00    22.5       0.20   0.05
# 0  GGAL240119C00002500 2022-06-15 17:32:18+00:00     2.5       5.50   1.50
# 1  GGAL240119C00005000 2022-08-12 18:31:26+00:00     5.0       3.75   3.50
# 2  GGAL240119C00007500 2022-08-15 15:35:55+00:00     7.5       2.40   1.90
# 3  GGAL240119C00010000 2022-08-11 17:35:43+00:00    10.0       1.40   0.35
# 16  GGAL221021P00007500   GGAL  8.16       P     7.5   64   0.50   1.088000
# 17  GGAL221021C00010000   GGAL  8.16       C    10.0   64   0.15   0.816000
# 18  GGAL221021P00010000   GGAL  8.16       P    10.0   64   3.65   0.816000
# 19  GGAL221021C00012500   GGAL  8.16       C    12.5   64   0.05   0.652800
# 20  GGAL221021C00015000   GGAL  8.16       C    15.0   64   0.05   0.544000
# 21  GGAL221021C00017500   GGAL  8.16       C    17.5   64   0.34   0.466286
# 22  GGAL230120C00002500   GGAL  8.16       C     2.5  155   8.90   3.264000
# 23  GGAL230120P00002500   GGAL  8.16       P     2.5  155   0.10   3.264000
# 24  GGAL230120C00005000   GGAL  8.16       C     5.0  155   3.32   1.632000
# 25  GGAL230120P00005000   GGAL  8.16       P     5.0  155   0.15   1.632000
# 26  GGAL230120C00007500   GGAL  8.16       C     7.5  155   1.35   1.088000
# 27  GGAL230120P00007500   GGAL  8.16       P     7.5  155   0.75   1.088000
# 28  GGAL230120C00010000   GGAL  8.16       C    10.0  155   0.45   0.816000
# 29  GGAL230120P00010000   GGAL  8.16       P    10.0  155   2.50   0.816000
# 30  GGAL230120C00012500   GGAL  8.16       C    12.5  155   0.06   0.652800
# 31  GGAL230120P00012500   GGAL  8.16       P    12.5  155   5.50   0.652800
# 32  GGAL230120C00015000   GGAL  8.16       C    15.0  155   0.08   0.544000
# 33  GGAL230120P00015000   GGAL  8.16       P    15.0  155   6.51   0.544000
# 34  GGAL230120C00017500   GGAL  8.16       C    17.5  155   0.15   0.466286
# 35  GGAL230120P00017500   GGAL  8.16       P    17.5  155   7.80   0.466286
# 36  GGAL230120C00020000   GGAL  8.16       C    20.0  155   0.05   0.408000
# 37  GGAL230120P00020000   GGAL  8.16       P    20.0  155  13.93   0.408000
# 38  GGAL230120C00022500   GGAL  8.16       C    22.5  155   0.20   0.362667
# 39  GGAL240119C00002500   GGAL  8.16       C     2.5  519   5.50   3.264000
# 40  GGAL240119C00005000   GGAL  8.16       C     5.0  519   3.75   1.632000
# 41  GGAL240119P00005000   GGAL  8.16       P     5.0  519   0.75   1.632000
# 42  GGAL240119C00007500   GGAL  8.16       C     7.5  519   2.40   1.088000
# 43  GGAL240119P00007500   GGAL  8.16       P     7.5  519   1.60   1.088000
# 44  GGAL240119C00010000   GGAL  8.16       C    10.0  519   1.40   0.816000
# 45  GGAL240119P00010000   GGAL  8.16       P    10.0  519   3.60   0.816000
# 46  GGAL240119C00012500   GGAL  8.16       C    12.5  519   0.94   0.652800
# 47  GGAL240119C00015000   GGAL  8.16       C    15.0  519   0.60   0.544000
# 48  GGAL240119P00015000   GGAL  8.16       P    15.0  519   8.30   0.544000
# 49  GGAL240119C00017500   GGAL  8.16       C    17.5  519   0.35   0.466286
# 50  GGAL240119C00020000   GGAL  8.16       C    20.0  519   1.15   0.408000
# 51  GGAL240119C00022500   GGAL  8.16       C    22.5  519   0.75   0.362667
#
#     impliedVolatility    Bid    Ask
# 0            8.875004   5.50   5.70
# 1            4.031255   3.00   3.20
# 2            4.625004   0.00   0.15
# 3            1.031255   0.60   0.70
# 4            0.250007   0.00   0.00
# 5            2.570316   0.00   0.25
# 6            3.859375   1.00   2.20
# 7            1.046880   3.10   3.30
# 8            1.289066   0.00   0.20
# 9            0.562504   0.80   1.00
# 10           0.542973   0.15   0.30
# 11           0.570317   0.00   0.15
# 12           0.636722   1.85   2.05
# 13           0.710940   2.90   3.50
# 14           0.250007   0.00   0.00
# 15           0.548833   0.95   1.10
# 16           0.517583   0.35   0.45
# 17           0.478521   0.05   0.15
# 18           0.589848   1.90   2.10
# 19           0.742190   0.00   0.25
# 20           0.953125   0.00   0.25
# 21           1.281254   0.00   0.45
# 22           3.312502   4.50   9.50
# 23           0.500005   0.00   0.00
# 24           0.619144   3.20   3.40
# 25           0.250007   0.05   0.00
# 26           0.536137   1.30   1.45
# 27           0.515630   0.65   0.75
# 28           0.511724   0.40   0.50
# 29           0.491216   2.15   2.30
# 30           0.523442   0.05   0.30
# 31           1.508792   5.20   7.60
# 32           0.615238   0.00   0.25
# 33           0.652347   6.10   7.00
# 34           0.722659   0.00   0.25
# 35           0.000010   7.40   8.90
# 36           0.812502   0.00   0.25
# 37           0.000010  10.50  11.50
# 38           1.003911   0.05   0.40
# 39           1.369144   1.50   6.50
# 40           0.550786   3.50   3.90
# 41           0.666019   0.05   1.55
# 42           0.511235   1.90   2.55
# 43           0.709476   0.40   2.25
# 44           0.712405   0.35   2.15
# 45           0.715335   1.90   4.00
# 46           0.536137   0.10   0.95
# 47           0.574223   0.25   0.75
# 48           1.081059   4.50   9.50
# 49           0.528325   0.10   0.40
# 50           1.147465   0.05   4.70
# 51           1.156254   0.30   4.10

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance

# %%
ticker = 'GGAL'
data = yf.Ticker(ticker)

#Data es un objeto
# data.info contiene informacion (mucha) del activo

data.info
# Out:
# {'zip': '1038',
#  'sector': 'Financial Services',
#  'longBusinessSummary': "Grupo Financiero Galicia S.A., a financial service holding company, provides various financial products and services to individuals and companies in Argentina. The company operates through Banks, NaranjaX, Insurance, and Other Businesses segments. The company's products and services cover savings, current, and checking accounts; personal loans; express and mortgage loans; pledge and credit card loans; credit and debit cards; and online banking services. It also offers financing products and services; consumer finance services; electronic check; global custody services; Fima funds; financial and stock market services to individuals, companies, and financial institutions; foreign trade services; and capital market and investment banking products that include debt securities, short-term securities, bills, and financial trusts. In addition, the company provides robbery, personal accident, life collective, home, life, integral pyme, pet, surety, various risks, and technical insurance products. Further, it offers private banking services to high net worth individuals; and operates digital investment platform. As of December 31, 2021, it had 312 full service banking branches; and 1,991 ATMs and self-service terminals. Grupo Financiero Galicia S.A. was founded in 1905 and is based in Buenos Aires, Argentina.",
#  'city': 'Buenos Aires',
#  'phone': '54 11 4343 7528',
#  'country': 'Argentina',
#  'companyOfficers': [],
#  'website': 'https://www.gfgsa.com',
#  'maxAge': 1,
#  'address1': 'Teniente General Juan D. PerOn 430',
#  'fax': '54 11 4331 9183',
#  'industry': 'Banks—Regional',
#  'address2': '25th Floor',
#  'ebitdaMargins': 0,
#  'profitMargins': 0.11454,
#  'grossMargins': 0,
#  'operatingCashflow': 116351680512,
#  'revenueGrowth': 0.176,
#  'operatingMargins': 0.17093,
#  'ebitda': None,
#  'targetLowPrice': 5,
#  'recommendationKey': 'hold',
#  'grossProfits': 282178293000,
#  'freeCashflow': None,
#  'targetMedianPrice': 8.3,
#  'currentPrice': 8.16,
#  'earningsGrowth': 0.559,
#  'currentRatio': None,
#  'returnOnAssets': 0.02318,
#  'numberOfAnalystOpinions': 4,
#  'targetMeanPrice': 10.73,
#  'debtToEquity': None,
#  'returnOnEquity': 0.123859994,
#  'targetHighPrice': 21.3,
#  'totalCash': 408549457920,
#  'totalDebt': 229529108480,
#  'totalRevenue': 303785869312,
#  'totalCashPerShare': 2770.405,
#  'financialCurrency': 'ARS',
#  'revenuePerShare': 2060,
#  'quickRatio': None,
#  'recommendationMean': 3.5,
#  'exchange': 'NCM',
#  'shortName': 'Grupo Financiero Galicia S.A.',
#  'longName': 'Grupo Financiero Galicia S.A.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'GGAL',
#  'messageBoardId': 'finmb_1532718',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': -0.585,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': -0.022891581,
#  'morningStarRiskRating': None,
#  'forwardEps': 3.49,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 147468992,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 2417.23,
#  'sharesShort': 1782689,
#  'sharesPercentSharesOut': 0.0121,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.09887,
#  'netIncomeToCommon': 34796187648,
#  'trailingEps': 1.55,
#  'lastDividendValue': 0.36,
#  'SandP52WeekChange': -0.029906034,
#  'priceToBook': 0.0033757647,
#  'heldPercentInsiders': 0.12866999,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1648684800,
#  'shortRatio': 2.17,
#  'sharesShortPreviousMonthDate': 1656547200,
#  'floatShares': 81296826,
#  'beta': 2.580341,
#  'enterpriseValue': -177824366592,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': 1652400000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.561,
#  'priceToSalesTrailing12Months': 0.003961168,
#  'dateShortInterest': 1659052800,
#  'pegRatio': -0.06,
#  'ytdReturn': None,
#  'forwardPE': 2.3381088,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 1065502,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 8.11,
#  'regularMarketOpen': 8.12,
#  'twoHundredDayAverage': 9.09805,
#  'trailingAnnualDividendYield': 0.91972876,
#  'payoutRatio': 0.028900001,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 8.23,
#  'navPrice': None,
#  'averageDailyVolume10Day': 545110,
#  'regularMarketPreviousClose': 8.11,
#  'fiftyDayAverage': 7.245,
#  'trailingAnnualDividendRate': 7.459,
#  'open': 8.12,
#  'toCurrency': None,
#  'averageVolume10days': 545110,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': 1620950400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 8.041,
#  'currency': 'USD',
#  'trailingPE': 5.2645164,
#  'regularMarketVolume': 418518,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1203346944,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 685650,
#  'dayLow': 8.041,
#  'ask': 8.15,
#  'askSize': 900,
#  'volume': 418518,
#  'fiftyTwoWeekHigh': 12.75,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 5.75,
#  'bid': 8.14,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 900,
#  'dayHigh': 8.23,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 8.16,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/gfgsa.com'}

# %%
# Spot price

hist = data.history()

spot = hist.tail(1)['Close'].iloc[0]
spot
# Out:
# 8.15999984741211

# %%
# Vencimientos de opciones
vencimientos = data.options

vencimientos
# Out:
# ('2022-08-19', '2022-09-16', '2022-10-21', '2023-01-20', '2024-01-19')

# %%
# Calls y puts
calls = data.option_chain(vencimientos[0])[0]
puts = data.option_chain(vencimientos[0])[1]

puts
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0  GGAL220819P00005000 2022-07-20 18:51:38+00:00     5.0       0.05  0.0
# 1  GGAL220819P00007500 2022-08-10 19:49:51+00:00     7.5       0.20  0.0
# 2  GGAL220819P00010000 2022-07-18 17:34:46+00:00    10.0       3.50  1.0
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  0.15     0.0            0.0     4.0            44           4.625004
# 1  0.00     0.0            0.0    15.0           153           0.250007
# 2  2.20     0.0            0.0     NaN             0           3.859375
#
#    inTheMoney contractSize currency
# 0       False      REGULAR      USD
# 1       False      REGULAR      USD
# 2        True      REGULAR      USD

# %% [markdown]
# ### Que hace internamente el metodo??

# %%
#Recorro cada vencimiento disponible y voy tomando calls por un lado y puts por otro
for vencimiento in vencimientos[1:]:
        calls = calls.append(data.option_chain(vencimiento)[0])
        puts = puts.append(data.option_chain(vencimiento)[1])

#Uno los puts y los calls
panel_opciones = calls.append(puts)

# Le agrego dos columnas utiles - Ticker y Spot

panel_opciones['Spot'] = hist.tail(1)['Close'].iloc[0]
panel_opciones['Ticker'] = ticker

panel_opciones.head(10)
# Out:
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\3234569746.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0  GGAL220819C00002500 2022-07-29 18:25:01+00:00     2.5       5.40  5.50
# 1  GGAL220819C00005000 2022-08-18 14:38:46+00:00     5.0       3.16  3.00
# 2  GGAL220819C00007500 2022-08-18 16:33:53+00:00     7.5       0.65  0.60
# 3  GGAL220819C00010000 2022-08-15 16:57:53+00:00    10.0       0.05  0.00
# 0  GGAL220916C00005000 2022-08-04 16:37:47+00:00     5.0       2.76  3.10
# 1  GGAL220916C00007500 2022-08-15 19:01:53+00:00     7.5       0.97  0.80
# 2  GGAL220916C00010000 2022-08-16 14:47:27+00:00    10.0       0.05  0.00
# 0  GGAL221021C00005000 2022-07-29 19:03:30+00:00     5.0       3.00  2.90
# 1  GGAL221021C00007500 2022-08-17 18:11:42+00:00     7.5       1.07  0.95
# 2  GGAL221021C00010000 2022-08-12 14:16:19+00:00    10.0       0.15  0.05
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  5.70    0.00       0.000000     1.0             1           8.875004
# 1  3.20    0.06       1.935490     1.0           130           4.031255
# 2  0.70   -0.06      -8.450705    20.0          1076           1.031255
# 3  0.25    0.00       0.000000    10.0           272           2.570316
# 0  3.30    0.00       0.000000     8.0            10           1.046880
# 1  1.00    0.00       0.000000    24.0           115           0.562504
# 2  0.15    0.00       0.000000     3.0            73           0.570317
# 0  3.50    0.00       0.000000     2.0             1           0.710940
# 1  1.10    0.00       0.000000     2.0           386           0.548833
# 2  0.15    0.00       0.000000     2.0           388           0.478521
#
#    inTheMoney contractSize currency  Spot Ticker
# 0        True      REGULAR      USD  8.16   GGAL
# 1        True      REGULAR      USD  8.16   GGAL
# 2        True      REGULAR      USD  8.16   GGAL
# 3       False      REGULAR      USD  8.16   GGAL
# 0        True      REGULAR      USD  8.16   GGAL
# 1        True      REGULAR      USD  8.16   GGAL
# 2       False      REGULAR      USD  8.16   GGAL
# 0        True      REGULAR      USD  8.16   GGAL
# 1        True      REGULAR      USD  8.16   GGAL
# 2       False      REGULAR      USD  8.16   GGAL

# %% [markdown]
# ## Del panel de Yahoo crudo a otro con informacion customizada (igual que antes)

# %% [markdown]
# #### *) Agrego columnas utiles

# %%
panel_opciones['Moneyness'] = 0.0
panel_opciones['TTM'] = 0
panel_opciones['CallPut'] = ''
panel_opciones = panel_opciones.reset_index()

panel_opciones.head(5)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220819C00002500 2022-07-29 18:25:01+00:00     2.5       5.40
# 1      1  GGAL220819C00005000 2022-08-18 14:38:46+00:00     5.0       3.16
# 2      2  GGAL220819C00007500 2022-08-18 16:33:53+00:00     7.5       0.65
# 3      3  GGAL220819C00010000 2022-08-15 16:57:53+00:00    10.0       0.05
# 4      0  GGAL220916C00005000 2022-08-04 16:37:47+00:00     5.0       2.76
#
#    bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  5.5  5.70    0.00       0.000000     1.0             1           8.875004
# 1  3.0  3.20    0.06       1.935490     1.0           130           4.031255
# 2  0.6  0.70   -0.06      -8.450705    20.0          1076           1.031255
# 3  0.0  0.25    0.00       0.000000    10.0           272           2.570316
# 4  3.1  3.30    0.00       0.000000     8.0            10           1.046880
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.16   GGAL        0.0    0
# 1        True      REGULAR      USD  8.16   GGAL        0.0    0
# 2        True      REGULAR      USD  8.16   GGAL        0.0    0
# 3       False      REGULAR      USD  8.16   GGAL        0.0    0
# 4        True      REGULAR      USD  8.16   GGAL        0.0    0

# %% [markdown]
# #### *) Recorro las filas (1ra como ejemplo)

# %%
idx = panel_opciones.index.values[0]

# %%
callput = panel_opciones.contractSymbol.values[idx][10:11]
panel_opciones['CallPut'].values[idx] = callput

# %%
year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
month = int(panel_opciones.contractSymbol.values[idx][6:8])
day = int(panel_opciones.contractSymbol.values[idx][8:10])

hoy = datetime.date.today()
expiry_datetime = datetime.date(year, month, day)
ttm = (expiry_datetime - hoy).days

panel_opciones['TTM'].values[idx] = ttm

# %%
panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(2)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220819C00002500 2022-07-29 18:25:01+00:00     2.5       5.40
# 1      1  GGAL220819C00005000 2022-08-18 14:38:46+00:00     5.0       3.16
#
#    bid  ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  5.5  5.7    0.00        0.00000     1.0             1           8.875004
# 1  3.0  3.2    0.06        1.93549     1.0           130           4.031255
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.16   GGAL      3.264    1       C
# 1        True      REGULAR      USD  8.16   GGAL      0.000    0

# %% [markdown]
# #### *) Recorro las filas (las restantes como ejemplo)

# %%
for idx in list(panel_opciones.index.values[1:]):
        year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
        month = int(panel_opciones.contractSymbol.values[idx][6:8])
        day = int(panel_opciones.contractSymbol.values[idx][8:10])
        
        hoy = datetime.date.today()
        expiry_datetime = datetime.date(year, month, day)
        ttm = (expiry_datetime - hoy).days

        panel_opciones['TTM'].values[idx] = ttm
        callput = panel_opciones.contractSymbol.values[idx][10:11]
        panel_opciones['CallPut'].values[idx] = callput
        
panel_opciones.Moneyness = panel_opciones.Spot/ panel_opciones.strike

# %%
panel_opciones.head(10)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220819C00002500 2022-07-29 18:25:01+00:00     2.5       5.40
# 1      1  GGAL220819C00005000 2022-08-18 14:38:46+00:00     5.0       3.16
# 2      2  GGAL220819C00007500 2022-08-18 16:33:53+00:00     7.5       0.65
# 3      3  GGAL220819C00010000 2022-08-15 16:57:53+00:00    10.0       0.05
# 4      0  GGAL220916C00005000 2022-08-04 16:37:47+00:00     5.0       2.76
# 5      1  GGAL220916C00007500 2022-08-15 19:01:53+00:00     7.5       0.97
# 6      2  GGAL220916C00010000 2022-08-16 14:47:27+00:00    10.0       0.05
# 7      0  GGAL221021C00005000 2022-07-29 19:03:30+00:00     5.0       3.00
# 8      1  GGAL221021C00007500 2022-08-17 18:11:42+00:00     7.5       1.07
# 9      2  GGAL221021C00010000 2022-08-12 14:16:19+00:00    10.0       0.15
#
#     bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  5.50  5.70    0.00       0.000000     1.0             1           8.875004
# 1  3.00  3.20    0.06       1.935490     1.0           130           4.031255
# 2  0.60  0.70   -0.06      -8.450705    20.0          1076           1.031255
# 3  0.00  0.25    0.00       0.000000    10.0           272           2.570316
# 4  3.10  3.30    0.00       0.000000     8.0            10           1.046880
# 5  0.80  1.00    0.00       0.000000    24.0           115           0.562504
# 6  0.00  0.15    0.00       0.000000     3.0            73           0.570317
# 7  2.90  3.50    0.00       0.000000     2.0             1           0.710940
# 8  0.95  1.10    0.00       0.000000     2.0           386           0.548833
# 9  0.05  0.15    0.00       0.000000     2.0           388           0.478521
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.16   GGAL      3.264    1       C
# 1        True      REGULAR      USD  8.16   GGAL      1.632    1       C
# 2        True      REGULAR      USD  8.16   GGAL      1.088    1       C
# 3       False      REGULAR      USD  8.16   GGAL      0.816    1       C
# 4        True      REGULAR      USD  8.16   GGAL      1.632   29       C
# 5        True      REGULAR      USD  8.16   GGAL      1.088   29       C
# 6       False      REGULAR      USD  8.16   GGAL      0.816   29       C
# 7        True      REGULAR      USD  8.16   GGAL      1.632   64       C
# 8        True      REGULAR      USD  8.16   GGAL      1.088   64       C
# 9       False      REGULAR      USD  8.16   GGAL      0.816   64       C

# %% [markdown]
# #### Panel Limpio

# %%
panel_opciones = panel_opciones.rename(
            columns={'lastTradeDate': 'Last_Date', 'contractSymbol': 'Especie', 'strike': 'Strike', 'bid': 'Bid',
                     'ask': 'Ask', 'lastPrice': 'Last'}, inplace=False)

panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])

panel_opciones = panel_opciones[['Especie', 'Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Bid','Ask','impliedVolatility','Moneyness']]

# %%
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']
panel_opciones
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last    Bid  \
# 0   GGAL220819C00002500   GGAL  8.16       C     2.5    1   5.40   5.50
# 1   GGAL220819C00005000   GGAL  8.16       C     5.0    1   3.16   3.00
# 2   GGAL220819P00005000   GGAL  8.16       P     5.0    1   0.05   0.00
# 3   GGAL220819C00007500   GGAL  8.16       C     7.5    1   0.65   0.60
# 4   GGAL220819P00007500   GGAL  8.16       P     7.5    1   0.20   0.00
# 5   GGAL220819C00010000   GGAL  8.16       C    10.0    1   0.05   0.00
# 6   GGAL220819P00010000   GGAL  8.16       P    10.0    1   3.50   1.00
# 7   GGAL220916C00005000   GGAL  8.16       C     5.0   29   2.76   3.10
# 8   GGAL220916P00005000   GGAL  8.16       P     5.0   29   0.17   0.00
# 9   GGAL220916C00007500   GGAL  8.16       C     7.5   29   0.97   0.80
# 10  GGAL220916P00007500   GGAL  8.16       P     7.5   29   0.30   0.15
# 11  GGAL220916C00010000   GGAL  8.16       C    10.0   29   0.05   0.00
# 12  GGAL220916P00010000   GGAL  8.16       P    10.0   29   4.00   1.85
# 13  GGAL221021C00005000   GGAL  8.16       C     5.0   64   3.00   2.90
# 14  GGAL221021P00005000   GGAL  8.16       P     5.0   64   0.10   0.00
# 15  GGAL221021C00007500   GGAL  8.16       C     7.5   64   1.07   0.95
# 16  GGAL221021P00007500   GGAL  8.16       P     7.5   64   0.50   0.35
# 17  GGAL221021C00010000   GGAL  8.16       C    10.0   64   0.15   0.05
# 18  GGAL221021P00010000   GGAL  8.16       P    10.0   64   3.65   1.90
# 19  GGAL221021C00012500   GGAL  8.16       C    12.5   64   0.05   0.00
# 20  GGAL221021C00015000   GGAL  8.16       C    15.0   64   0.05   0.00
# 21  GGAL221021C00017500   GGAL  8.16       C    17.5   64   0.34   0.00
# 22  GGAL230120C00002500   GGAL  8.16       C     2.5  155   8.90   4.50
# 23  GGAL230120P00002500   GGAL  8.16       P     2.5  155   0.10   0.00
# 24  GGAL230120C00005000   GGAL  8.16       C     5.0  155   3.32   3.20
# 25  GGAL230120P00005000   GGAL  8.16       P     5.0  155   0.15   0.05
# 26  GGAL230120C00007500   GGAL  8.16       C     7.5  155   1.35   1.30
# 27  GGAL230120P00007500   GGAL  8.16       P     7.5  155   0.75   0.65
# 28  GGAL230120C00010000   GGAL  8.16       C    10.0  155   0.45   0.40
# 29  GGAL230120P00010000   GGAL  8.16       P    10.0  155   2.50   2.15
# 30  GGAL230120C00012500   GGAL  8.16       C    12.5  155   0.06   0.05
# 31  GGAL230120P00012500   GGAL  8.16       P    12.5  155   5.50   5.20
# 32  GGAL230120C00015000   GGAL  8.16       C    15.0  155   0.08   0.00
# 33  GGAL230120P00015000   GGAL  8.16       P    15.0  155   6.51   6.10
# 34  GGAL230120C00017500   GGAL  8.16       C    17.5  155   0.15   0.00
# 35  GGAL230120P00017500   GGAL  8.16       P    17.5  155   7.80   7.40
# 36  GGAL230120C00020000   GGAL  8.16       C    20.0  155   0.05   0.00
# 37  GGAL230120P00020000   GGAL  8.16       P    20.0  155  13.93  10.50
# 38  GGAL230120C00022500   GGAL  8.16       C    22.5  155   0.20   0.05
# 39  GGAL240119C00002500   GGAL  8.16       C     2.5  519   5.50   1.50
# 40  GGAL240119C00005000   GGAL  8.16       C     5.0  519   3.75   3.50
# 41  GGAL240119P00005000   GGAL  8.16       P     5.0  519   0.75   0.05
# 42  GGAL240119C00007500   GGAL  8.16       C     7.5  519   2.40   1.90
# 43  GGAL240119P00007500   GGAL  8.16       P     7.5  519   1.60   0.40
# 44  GGAL240119C00010000   GGAL  8.16       C    10.0  519   1.40   0.35
# 45  GGAL240119P00010000   GGAL  8.16       P    10.0  519   3.60   1.90
# 46  GGAL240119C00012500   GGAL  8.16       C    12.5  519   0.94   0.10
# 47  GGAL240119C00015000   GGAL  8.16       C    15.0  519   0.60   0.25
# 48  GGAL240119P00015000   GGAL  8.16       P    15.0  519   8.30   4.50
# 49  GGAL240119C00017500   GGAL  8.16       C    17.5  519   0.35   0.10
# 50  GGAL240119C00020000   GGAL  8.16       C    20.0  519   1.15   0.05
# 51  GGAL240119C00022500   GGAL  8.16       C    22.5  519   0.75   0.30
#
#       Ask  impliedVolatility  Moneyness
# 0    5.70           8.875004   3.264000
# 1    3.20           4.031255   1.632000
# 2    0.15           4.625004   1.632000
# 3    0.70           1.031255   1.088000
# 4    0.00           0.250007   1.088000
# 5    0.25           2.570316   0.816000
# 6    2.20           3.859375   0.816000
# 7    3.30           1.046880   1.632000
# 8    0.20           1.289066   1.632000
# 9    1.00           0.562504   1.088000
# 10   0.30           0.542973   1.088000
# 11   0.15           0.570317   0.816000
# 12   2.05           0.636722   0.816000
# 13   3.50           0.710940   1.632000
# 14   0.00           0.250007   1.632000
# 15   1.10           0.548833   1.088000
# 16   0.45           0.517583   1.088000
# 17   0.15           0.478521   0.816000
# 18   2.10           0.589848   0.816000
# 19   0.25           0.742190   0.652800
# 20   0.25           0.953125   0.544000
# 21   0.45           1.281254   0.466286
# 22   9.50           3.312502   3.264000
# 23   0.00           0.500005   3.264000
# 24   3.40           0.619144   1.632000
# 25   0.00           0.250007   1.632000
# 26   1.45           0.536137   1.088000
# 27   0.75           0.515630   1.088000
# 28   0.50           0.511724   0.816000
# 29   2.30           0.491216   0.816000
# 30   0.30           0.523442   0.652800
# 31   7.60           1.508792   0.652800
# 32   0.25           0.615238   0.544000
# 33   7.00           0.652347   0.544000
# 34   0.25           0.722659   0.466286
# 35   8.90           0.000010   0.466286
# 36   0.25           0.812502   0.408000
# 37  11.50           0.000010   0.408000
# 38   0.40           1.003911   0.362667
# 39   6.50           1.369144   3.264000
# 40   3.90           0.550786   1.632000
# 41   1.55           0.666019   1.632000
# 42   2.55           0.511235   1.088000
# 43   2.25           0.709476   1.088000
# 44   2.15           0.712405   0.816000
# 45   4.00           0.715335   0.816000
# 46   0.95           0.536137   0.652800
# 47   0.75           0.574223   0.544000
# 48   9.50           1.081059   0.544000
# 49   0.40           0.528325   0.466286
# 50   4.70           1.147465   0.408000
# 51   4.10           1.156254   0.362667

# %% [markdown]
# ## 2) Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# NYSE
panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)

TTMs = list(set(panel_opciones_ggal_nyse_limpio.TTM.values))
TTMs
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# [64, 1, 519, 155, 29]

# %%
TTM = 8
panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == "C")].head(10)
# Out:
# Empty DataFrame
# Columns: [Especie, Ticker, Spot, CallPut, Strike, TTM, Last, Moneyness, impliedVolatility, Bid, Ask]
# Index: []

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    ## Last VS (B+A)/2
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %% [markdown]
# ### Para cada strike, grafico los TTM

# %%
Ks = list(set(panel_opciones_ggal_nyse_limpio.Strike.values))

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks:
    TTMs = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Ploteando los datos con un ticker mega liquido

# %%
# NYSE AAPL
ticker = 'TSLA'
panel_opciones_nyse_limpio = obtener_panel_opciones_nyse(ticker, True)

TTMs = list(set(panel_opciones_nyse_limpio.TTM.values))
TTMs.sort()
TTMs
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# [1, 8, 15, 22, 29, 36, 43, 64, 92, 120, 155, 211, 246, 302, 393, 519, 575, 673]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[8:11]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[3:6]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[10:15]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[11:17]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
Ks = list(set(panel_opciones_nyse_limpio.Strike.values))
Ks.sort()
len(Ks)
# Out:
# 369

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[45:55]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for K in Ks[100:]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Pasar a Excel

# %%
panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')

panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')


panel_opciones_aapl_nyse_limpio = obtener_panel_opciones_nyse('AAPL', True)
panel_opciones_aapl_nyse_limpio.to_excel('Clase_2_panel_opciones_aapl_nyse_limpio.xls')
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\891834467.py:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase2.ipynb Cell 54 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y102sZmlsZQ%3D%3D?line=3'>4</a> panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y102sZmlsZQ%3D%3D?line=4'>5</a> panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\formats\excel.py:888, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884     need_save = False
#     885 else:
#     886     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888     writer = ExcelWriter(  # type: ignore[abstract]
#     889         writer, engine=engine, storage_options=storage_options
#     890     )
#     891     need_save = True
#     893 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\excel\_xlwt.py:39, in XlwtWriter.__init__(self, path, engine, date_format, datetime_format, encoding, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      25 def __init__(
#      26     self,
#      27     path,
#    (...)
#      37 ):
#      38     # Use the xlwt module as the Excel writer.
# ---> 39     import xlwt
#      41     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      43     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlwt'

# %% [markdown]
# ## 3) Payoffs y Estrategias

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Vanilla Call y Put

# %%
def payoff_call(S,K):
    return np.maximum(S-K,0)

def payoff_put(S,K):
    return np.maximum(K-S,0)

# %%
K=50
S = np.linspace(0,100,50)

# %%
#Grafico la call

plt.plot(S,payoff_call(S, K))
plt.show()

# %%
#Grafico la put
plt.plot(S,payoff_put(S, K))
plt.show()

# %% [markdown]
# ### Forward sintetico y Combo

# %%
def payoff_forwardSintetico(S,K):
    return payoff_call(S,K)-payoff_put(S, K)

def payoff_combo(S,K1,K2):
    return payoff_call(S,K2)-payoff_put(S, K1)

# %%
#Grafico el forward sintetico
plt.plot(S,payoff_forwardSintetico(S, K))
plt.show()

# %%
K1 = 35
K2 = 65

# %%
#Grafico el combo
plt.plot(S,payoff_combo(S, K1,K2))
plt.show()

# %% [markdown]
# ### Spreads

# %%
def payoff_BullCS(S,K1,K2):
    return payoff_call(S,K1)-payoff_call(S, K2)

def payoff_BearCS(S,K1,K2):
    return payoff_call(S,K2)-payoff_call(S, K1)

def payoff_BullPS(S,K1,K2):
    return payoff_put(S,K1)-payoff_put(S, K2)


def payoff_BearPS(S,K1,K2):
    return payoff_put(S,K2)-payoff_put(S, K1)

# %%
#Grafico el Bull Call Spread
plt.plot(S,payoff_BullCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Call Spread
plt.plot(S,payoff_BearCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bull Put Spread
plt.plot(S,payoff_BullPS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Put Spread
plt.plot(S,payoff_BearPS(S, K1, K2))
plt.show()

# %% [markdown]
# ### Butterfly spreads

# %%
def payoff_CButterflyS(S,K1,K2,K3):
    return payoff_call(S,K1)-2*payoff_call(S, K2)+payoff_call(S, K3)

def payoff_PButterflyS(S,K1,K2,K3):
    return payoff_put(S,K1)-2*payoff_put(S, K2)+payoff_put(S, K3)

# %%
K1=35
K2=50
K3=65

# %%
#Grafico el Call Buterfly Spread
plt.plot(S,payoff_CButterflyS(S, K1, K2,K3))
plt.show()

# %%
#Grafico el Put Buterfly Spread
plt.plot(S,payoff_PButterflyS(S, K1, K2,K3))
plt.show()

# %% [markdown]
# ### Straddle y Strangle

# %%
def payoff_straddle(S,K):
    return payoff_call(S,K)+payoff_put(S, K)


def payoff_strangle(S,K1,K2):
    return payoff_call(S,K1)+payoff_put(S, K2)

# %%
K1 = 35
K2 = 65

# %%
#Grafico el Strangle
plt.plot(S,payoff_strangle(S, K1,K2))
plt.show()

# %%
#Grafico el Straddle

plt.plot(S,payoff_straddle(S, K))
plt.show()

# %% [markdown]
# ### Estrategia AD hoc - Iron Condor

# %%
def payoff_iron_condor(S,K1,K2,K3,K4):
    return payoff_put(S,K1)-payoff_put(S, K2)-payoff_call(S,K3)+payoff_call(S,K4)

# %%
K1 = 30
K2 = 45
K3 = 55
K4 = 70

# %%
plt.plot(S,payoff_iron_condor(S, K1,K2,K3,K4))
plt.show()

# %%
#usando el script con los metodos
import payoffs
payoffs.payoff_call(120,50)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase2.ipynb Cell 87 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y150sZmlsZQ%3D%3D?line=0'>1</a> #usando el script con los metodos
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y150sZmlsZQ%3D%3D?line=1'>2</a> import payoffs
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y150sZmlsZQ%3D%3D?line=2'>3</a> payoffs.payoff_call(120,50)
#
# ModuleNotFoundError: No module named 'payoffs'
