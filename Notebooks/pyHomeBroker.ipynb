# %% [markdown]
# # Derivados Financieros 2022 - Clase 1
# ## PyHomeBroker

# %% [markdown]
# ### Importo los modulos

# %%
import sys

sys.path.append('..')
from Codigo.data_byma_homebroker import *
import pickle

# %% [markdown]
# ## (3) pyhomebroker

# %% [markdown]
# ### pyhomebroker es una a API para conectar a un programa/script/notebook de python al mercado a traves de AlyCs que usen la plataforma homebroker (Estudio Gallo). Se usa para recibir precios y datos de mercado en tiempo real. Permite tambien obtener data historica.
#
#
# Mas info e instrucciones de instalacion en https://pypi.org/project/pyhomebroker/
#
# Estudio Gallo: http://www.estudiogallo.com.ar/
#
# Home Broker: https://www.youtube.com/watch?v=ippFga_hKSg

# %% [markdown]
# ### por obvias razones, no revelo mis datos personales :) Pero aqui habria que crear un diccionario con sus datos

# %%
#TO SAVE
#personal_data = {'ByMA_id' : BymaId,
#                 'dni'     : dni, 
#                 'user'    : user,
#                 'password': password}
#pickle.dump(personal_data, open("personal_data.info", "wb"))

#TO LOAD
personal_data = pickle.load(open("personal_data.info", "rb"))

# %% [markdown]
# ### Metodos disponibles

# %%
panel_opciones_homebroker_all_raw = panel_opciones_homebroker(personal_data,
                                                              ticker = '', 
                                                              clean_flag=False)
panel_opciones_homebroker_all_raw
# Out:
#          symbol  last  change  open  high   low  previous_close  turnover  \
# 0    ALUC10179O  53.0    3.92  53.0  53.0  53.0           51.00    5300.0
# 1    ALUC115.DI  55.0   17.02  55.0  55.0  55.0           47.00    5500.0
# 2    ALUC12679O  35.0   12.90  35.0  35.0  35.0           31.00    7000.0
# 3    ALUC130.DI   NaN     NaN   NaN   NaN   NaN             NaN       NaN
# 4    ALUC145.OC   NaN     NaN   NaN   NaN   NaN           14.00       NaN
# ..          ...   ...     ...   ...   ...   ...             ...       ...
# 352  YPFV840.OC   NaN     NaN   NaN   NaN   NaN           10.27       NaN
# 353  YPFV880.OC   NaN     NaN   NaN   NaN   NaN           28.00       NaN
# 354  YPFV920.DI   NaN     NaN   NaN   NaN   NaN            8.75       NaN
# 355  YPFV920.OC   1.5   30.43   1.5   1.5   1.5            1.15     300.0
# 356  YPFV960.OC   NaN     NaN   NaN   NaN   NaN            3.00       NaN
#
#      volume  operations            datetime expiration  strike  kind  \
# 0       1.0         1.0 2022-08-24 12:27:36 2022-10-21  101.79  CALL
# 1       1.0         1.0 2022-08-24 16:07:18 2022-12-16  115.00  CALL
# 2       2.0         1.0 2022-08-24 13:44:35 2022-10-21  126.79  CALL
# 3       NaN         NaN                 NaT 2022-12-16  130.00  CALL
# 4       NaN         NaN                 NaT 2022-10-21  145.00  CALL
# ..      ...         ...                 ...        ...     ...   ...
# 352     NaN         NaN                 NaT 2022-10-21  840.00   PUT
# 353     NaN         NaN                 NaT 2022-10-21  880.00   PUT
# 354     NaN         NaN                 NaT 2022-12-16  920.00   PUT
# 355     2.0         1.0 2022-08-24 16:19:28 2022-10-21  920.00   PUT
# 356     NaN         NaN                 NaT 2022-10-21  960.00   PUT
#
#     underlying_asset
# 0               ALUA
# 1               ALUA
# 2               ALUA
# 3               ALUA
# 4               ALUA
# ..               ...
# 352             YPFD
# 353             YPFD
# 354             YPFD
# 355             YPFD
# 356             YPFD
#
# [357 rows x 15 columns]

# %%
panel_opciones_homebroker_all_clean = panel_opciones_homebroker(personal_data, 
                                                                ticker = '', 
                                                                clean_flag=True)
panel_opciones_homebroker_all_clean
# Out:
#         Especie Ticker    Spot CallPut  Strike  TTM    Last   Close  Moneyness
# 0    GFGC240.SE   GGAL  254.30       C  240.00   23  15.500  13.200   1.059583
# 1    GFGC280.SE   GGAL  254.30       C  280.00   23   6.000     NaN   0.908214
# 2    ALUC63.79O   ALUA  145.00       C   63.79   58  89.990  81.000   2.273084
# 3    ALUC69.79O   ALUA  145.00       C   69.79   58  84.000  81.739   2.077662
# 4    ALUC79.79O   ALUA  145.00       C   79.79   58  75.900  75.000   1.817270
# ..          ...    ...     ...     ...     ...  ...     ...     ...        ...
# 154  TRAC82.0DI   TRAN   94.00       C   82.00  114  32.000   2.000   1.146341
# 155  TXAC180.DI   TXAR  176.50       C  180.00  114  23.000   8.850   0.980556
# 156  BOLC5.60FE   BOLT    6.24       C    5.60  177   2.400     NaN   1.114286
# 157  GFGC360.FE   GGAL  254.30       C  360.00  177  10.238   9.000   0.706389
# 158  TXAV155.FE   TXAR  176.50       P  155.00  177  10.000     NaN   1.138710
#
# [159 rows x 9 columns]

# %%
panel_opciones_homebroker_GGAL_clean = panel_opciones_homebroker(personal_data, 'GGAL', True)
panel_opciones_homebroker_GGAL_clean
# Out:
#        Especie Ticker   Spot CallPut  Strike  TTM     Last    Close  Moneyness
# 0   GFGC240.SE   GGAL  254.3       C  240.00   23   15.500   13.200   1.059583
# 1   GFGC280.SE   GGAL  254.3       C  280.00   23    6.000      NaN   0.908214
# 2   GFGC132.OC   GGAL  254.3       C  132.00   58  124.000  127.584   1.926515
# 3   GFGV132.OC   GGAL  254.3       P  132.00   58    0.100    0.157   1.926515
# 4   GFGC135.OC   GGAL  254.3       C  135.00   58  122.000  120.000   1.883704
# 5   GFGV135.OC   GGAL  254.3       P  135.00   58    0.112    0.022   1.883704
# 6   GFGV140.OC   GGAL  254.3       P  140.00   58    0.101    0.011   1.816429
# 7   GFGV145.OC   GGAL  254.3       P  145.00   58    0.110    0.187   1.753793
# 8   GFGV150.OC   GGAL  254.3       P  150.00   58    0.200    0.128   1.695333
# 9   GFGV155.OC   GGAL  254.3       P  155.00   58    0.285    0.244   1.640645
# 10  GFGV160.OC   GGAL  254.3       P  160.00   58    0.230    0.269   1.589375
# 11  GFGV165.OC   GGAL  254.3       P  165.00   58    0.350    0.234   1.541212
# 12  GFGV170.OC   GGAL  254.3       P  170.00   58    0.400    0.309   1.495882
# 13  GFGC175.OC   GGAL  254.3       C  175.00   58   89.000   85.000   1.453143
# 14  GFGV175.OC   GGAL  254.3       P  175.00   58    0.450    0.282   1.453143
# 15  GFGC180.OC   GGAL  254.3       C  180.00   58   82.100   79.048   1.412778
# 51  GFGC260.DI   GGAL  254.3       C  260.00  114   38.700   35.000   0.978077
# 52  GFGC280.DI   GGAL  254.3       C  280.00  114   28.700   23.100   0.908214
# 53  GFGC290.DI   GGAL  254.3       C  290.00  114   18.000   19.100   0.876897
# 54  GFGC300.DI   GGAL  254.3       C  300.00  114   13.500   13.000   0.847667
# 55  GFGC330.DI   GGAL  254.3       C  330.00  114    6.600    6.864   0.770606
# 56  GFGC360.DI   GGAL  254.3       C  360.00  114    4.999    3.500   0.706389
# 57  GFGC360.FE   GGAL  254.3       C  360.00  177   10.238    9.000   0.706389

# %% [markdown]
# ### Que hace el metodo internamente?

# %% [markdown]
# #### a) Recupero la informacion del picke (esto es personal!)

# %%
# Recupero la informacion del pickle

ByMA_id = personal_data['ByMA_id']
dni = personal_data['dni']
user = personal_data['user']
password = personal_data['password']

# %% [markdown]
# #### b) Conecto con el cliente

# %%
hb = HomeBroker(ByMA_id)
hb.auth.login(dni, user, password, raise_exception=True)
# Connect to the server
hb.online.connect()

# %% [markdown]
# #### c) Obtengo una 'foto'-snapshot del mercado [diccionario]

# %%
snapshot = hb.online.get_market_snapshot()
snapshot
# Out:
# {'bluechips':                      last  change     open     high      low  previous_close  \
#  symbol settlement
#  ALUA   spot         145.0    1.39   143.00   147.25   142.50          143.00
#         24hs         145.0    0.69   145.00   145.00   145.00          144.00
#         48hs         145.0    0.86   143.75   147.50   141.00          143.75
#  BBAR   spot         307.0    6.22   292.45   315.00   292.45          289.00
#         24hs           NaN     NaN      NaN      NaN      NaN          260.00
#  ...                   ...     ...      ...      ...      ...             ...
#  VALO   24hs           NaN     NaN      NaN      NaN      NaN           37.19
#         48hs          63.1    0.79    63.20    64.00    62.80           62.60
#  YPFD   spot        1551.1    1.00  1580.00  1628.85  1500.00         1535.60
#         24hs        1575.0    3.07  1580.00  1580.00  1570.00         1528.00
#         48hs        1585.0    2.97  1540.00  1590.00  1523.50         1539.15
#
#                        turnover    volume  operations            datetime
#  symbol settlement
#  ALUA   spot           984002.0    6769.0        64.0 2022-08-24 16:00:39
#         24hs            29000.0     200.0         1.0 2022-08-24 12:20:03
#         48hs        108155857.0  744066.0      1068.0 2022-08-24 16:59:54
#  BBAR   spot           833366.0    2712.0        31.0 2022-08-24 16:18:45
#         24hs                NaN       NaN         NaN                 NaT
#  ...                        ...       ...         ...                 ...
#  VALO   24hs                NaN       NaN         NaN                 NaT
#         48hs         15313827.0  241938.0       287.0 2022-08-24 16:58:04
#  YPFD   spot          5914098.0    3794.0       129.0 2022-08-24 16:29:08
#         24hs            45765.0      29.0         5.0 2022-08-24 16:49:55
#         48hs        708443174.0  451515.0      2172.0 2022-08-24 16:59:34
#
#  [66 rows x 10 columns],
#  'general_board':                    last  change  open  high   low  previous_close   turnover  \
#  symbol settlement
#  AGRO   spot        71.0     NaN  71.0  71.0  71.0           71.00    98051.0
#         24hs        70.0   -0.84  70.0  70.0  70.0           70.60  2940000.0
#         48hs        70.0    0.50  69.7  71.7  68.1           69.65  7246906.0
#  AUSO   spot         NaN     NaN   NaN   NaN   NaN          241.50        NaN
#         24hs         NaN     NaN   NaN   NaN   NaN          133.50        NaN
#  ...                 ...     ...   ...   ...   ...             ...        ...
#  YPFDB  spot         NaN     NaN   NaN   NaN   NaN         1375.00        NaN
#         48hs         NaN     NaN   NaN   NaN   NaN         1387.00        NaN
#  YPFDD  spot         NaN     NaN   NaN   NaN   NaN            5.83        NaN
#         24hs         NaN     NaN   NaN   NaN   NaN            4.01        NaN
#         48hs         NaN     NaN   NaN   NaN   NaN            4.87        NaN
#
#                       volume  operations            datetime
#  symbol settlement
#  AGRO   spot          1381.0         4.0 2022-08-24 15:16:46
#         24hs         42000.0         3.0 2022-08-24 16:18:26
#         48hs        102357.0       152.0 2022-08-24 16:59:21
#  AUSO   spot             NaN         NaN                 NaT
#         24hs             NaN         NaN                 NaT
#  ...                     ...         ...                 ...
#  YPFDB  spot             NaN         NaN                 NaT
#         48hs             NaN         NaN                 NaT
#  YPFDD  spot             NaN         NaN                 NaT
#         24hs             NaN         NaN                 NaT
#         48hs             NaN         NaN                 NaT
#
#  [134 rows x 10 columns],
#  'cedears':                      last  change     open    high      low  previous_close  \
#  symbol settlement
#  AAL    spot        2162.0    5.02  2162.00  2162.0  2162.00         2058.50
#         24hs           NaN     NaN      NaN     NaN      NaN         2062.00
#         48hs        2091.0    1.06  2060.50  2114.0  2054.50         2069.00
#  AALC   spot           NaN     NaN      NaN     NaN      NaN             NaN
#         24hs           NaN     NaN      NaN     NaN      NaN             NaN
#  ...                   ...     ...      ...     ...      ...             ...
#  ZMC    24hs           NaN     NaN      NaN     NaN      NaN             NaN
#         48hs           NaN     NaN      NaN     NaN      NaN            6.15
#  ZMD    spot           NaN     NaN      NaN     NaN      NaN            2.29
#         24hs           NaN     NaN      NaN     NaN      NaN             NaN
#         48hs           1.9    5.55     1.81     1.9     1.81            1.80
#
#                      turnover  volume  operations            datetime
#  symbol settlement
#  AAL    spot          10810.0     5.0         1.0 2022-08-24 11:39:46
#         24hs              NaN     NaN         NaN                 NaT
#         48hs        1319664.0   632.0        92.0 2022-08-24 16:50:21
#  AALC   spot              NaN     NaN         NaN                 NaT
#         24hs              NaN     NaN         NaN                 NaT
#  ...                      ...     ...         ...                 ...
#  ZMC    24hs              NaN     NaN         NaN                 NaT
#         48hs              NaN     NaN         NaN                 NaT
#  ZMD    spot              NaN     NaN         NaN                 NaT
#         24hs              NaN     NaN         NaN                 NaT
#         48hs            280.0   152.0         4.0 2022-08-24 16:06:21
#
#  [2012 rows x 10 columns],
#  'government_bonds':                      last  change    open    high     low  previous_close  \
#  symbol settlement
#  AC11A  spot           NaN     NaN     NaN     NaN     NaN             NaN
#         24hs           NaN     NaN     NaN     NaN     NaN             NaN
#         48hs           NaN     NaN     NaN     NaN     NaN             NaN
#  AE38   spot        7899.0    3.25  7663.0  8000.0  7662.0         7650.00
#         24hs           NaN     NaN     NaN     NaN     NaN         7200.00
#  ...                   ...     ...     ...     ...     ...             ...
#  TX28D  24hs           NaN     NaN     NaN     NaN     NaN             NaN
#         48hs           NaN     NaN     NaN     NaN     NaN            0.01
#  TY27P  spot           NaN     NaN     NaN     NaN     NaN             NaN
#         24hs           NaN     NaN     NaN     NaN     NaN             NaN
#         48hs           NaN     NaN     NaN     NaN     NaN          108.00
#
#                      turnover   volume  operations            datetime
#  symbol settlement
#  AC11A  spot              NaN      NaN         NaN                 NaT
#         24hs              NaN      NaN         NaN                 NaT
#         48hs              NaN      NaN         NaN                 NaT
#  AE38   spot        7555095.0  95939.0        67.0 2022-08-24 15:47:56
#         24hs              NaN      NaN         NaN                 NaT
#  ...                      ...      ...         ...                 ...
#  TX28D  24hs              NaN      NaN         NaN                 NaT
#         48hs              NaN      NaN         NaN                 NaT
#  TY27P  spot              NaN      NaN         NaN                 NaT
#         24hs              NaN      NaN         NaN                 NaT
#         48hs              NaN      NaN         NaN                 NaT
#
#  [979 rows x 10 columns],
#  'short_term_government_bonds':                    last  change  open  high  low  previous_close  turnover  \
#  symbol settlement
#  S28A3  spot         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN          77.510       NaN
#  S30D2  spot         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#  ...                 ...     ...   ...   ...  ...             ...       ...
#  XY3C   24hs         NaN     NaN   NaN   NaN  NaN           0.420       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#  XY3D   spot         NaN     NaN   NaN   NaN  NaN           0.425       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#
#                     volume  operations datetime
#  symbol settlement
#  S28A3  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  S30D2  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#  ...                   ...         ...      ...
#  XY3C   24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  XY3D   spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#
#  [111 rows x 10 columns],
#  'corporate_bonds':                    last  change  open  high  low  previous_close  turnover  \
#  symbol settlement
#  AECAC  spot         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#  AECAD  spot         NaN     NaN   NaN   NaN  NaN          53.640       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#  ...                 ...     ...   ...   ...  ...             ...       ...
#  YPUOX  spot         NaN     NaN   NaN   NaN  NaN          99.720       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN       13490.000       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN       15587.000       NaN
#  YPUOY  48hs         NaN     NaN   NaN   NaN  NaN          65.544       NaN
#  YPUOZ  48hs         NaN     NaN   NaN   NaN  NaN          57.924       NaN
#
#                     volume  operations datetime
#  symbol settlement
#  AECAC  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  AECAD  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#  ...                   ...         ...      ...
#  YPUOX  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  YPUOY  48hs           NaN         NaN      NaT
#  YPUOZ  48hs           NaN         NaN      NaT
#
#  [2076 rows x 10 columns],
#  'options':             last  change  open  high   low  previous_close  turnover  volume  \
#  symbol
#  ALUC10179O  53.0    3.92  53.0  53.0  53.0           51.00    5300.0     1.0
#  ALUC115.DI  55.0   17.02  55.0  55.0  55.0           47.00    5500.0     1.0
#  ALUC12679O  35.0   12.90  35.0  35.0  35.0           31.00    7000.0     2.0
#  ALUC130.DI   NaN     NaN   NaN   NaN   NaN             NaN       NaN     NaN
#  ALUC145.OC   NaN     NaN   NaN   NaN   NaN           14.00       NaN     NaN
#  ...          ...     ...   ...   ...   ...             ...       ...     ...
#  YPFV840.OC   NaN     NaN   NaN   NaN   NaN           10.27       NaN     NaN
#  YPFV880.OC   NaN     NaN   NaN   NaN   NaN           28.00       NaN     NaN
#  YPFV920.DI   NaN     NaN   NaN   NaN   NaN            8.75       NaN     NaN
#  YPFV920.OC   1.5   30.43   1.5   1.5   1.5            1.15     300.0     2.0
#  YPFV960.OC   NaN     NaN   NaN   NaN   NaN            3.00       NaN     NaN
#
#              operations            datetime expiration  strike  kind  \
#  symbol
#  ALUC10179O         1.0 2022-08-24 12:27:36 2022-10-21  101.79  CALL
#  ALUC115.DI         1.0 2022-08-24 16:07:18 2022-12-16  115.00  CALL
#  ALUC12679O         1.0 2022-08-24 13:44:35 2022-10-21  126.79  CALL
#  ALUC130.DI         NaN                 NaT 2022-12-16  130.00  CALL
#  ALUC145.OC         NaN                 NaT 2022-10-21  145.00  CALL
#  ...                ...                 ...        ...     ...   ...
#  YPFV840.OC         NaN                 NaT 2022-10-21  840.00   PUT
#  YPFV880.OC         NaN                 NaT 2022-10-21  880.00   PUT
#  YPFV920.DI         NaN                 NaT 2022-12-16  920.00   PUT
#  YPFV920.OC         1.0 2022-08-24 16:19:28 2022-10-21  920.00   PUT
#  YPFV960.OC         NaN                 NaT 2022-10-21  960.00   PUT
#
#             underlying_asset
#  symbol
#  ALUC10179O             ALUA
#  ALUC115.DI             ALUA
#  ALUC12679O             ALUA
#  ALUC130.DI             ALUA
#  ALUC145.OC             ALUA
#  ...                     ...
#  YPFV840.OC             YPFD
#  YPFV880.OC             YPFD
#  YPFV920.DI             YPFD
#  YPFV920.OC             YPFD
#  YPFV960.OC             YPFD
#
#  [357 rows x 14 columns]}

# %%
panel_opciones = snapshot['options']
panel_merval = snapshot['bluechips']
panel_general = snapshot['general_board']
panel_cedears = snapshot['cedears']

# %%
panel_cedears
# Out:
#                      last  change     open    high      low  previous_close  \
# symbol settlement
# AAL    spot        2162.0    5.02  2162.00  2162.0  2162.00         2058.50
#        24hs           NaN     NaN      NaN     NaN      NaN         2062.00
#        48hs        2091.0    1.06  2060.50  2114.0  2054.50         2069.00
# AALC   spot           NaN     NaN      NaN     NaN      NaN             NaN
#        24hs           NaN     NaN      NaN     NaN      NaN             NaN
# ...                   ...     ...      ...     ...      ...             ...
# ZMC    24hs           NaN     NaN      NaN     NaN      NaN             NaN
#        48hs           NaN     NaN      NaN     NaN      NaN            6.15
# ZMD    spot           NaN     NaN      NaN     NaN      NaN            2.29
#        24hs           NaN     NaN      NaN     NaN      NaN             NaN
#        48hs           1.9    5.55     1.81     1.9     1.81            1.80
#
#                     turnover  volume  operations            datetime
# symbol settlement
# AAL    spot          10810.0     5.0         1.0 2022-08-24 11:39:46
#        24hs              NaN     NaN         NaN                 NaT
#        48hs        1319664.0   632.0        92.0 2022-08-24 16:50:21
# AALC   spot              NaN     NaN         NaN                 NaT
#        24hs              NaN     NaN         NaN                 NaT
# ...                      ...     ...         ...                 ...
# ZMC    24hs              NaN     NaN         NaN                 NaT
#        48hs              NaN     NaN         NaN                 NaT
# ZMD    spot              NaN     NaN         NaN                 NaT
#        24hs              NaN     NaN         NaN                 NaT
#        48hs            280.0   152.0         4.0 2022-08-24 16:06:21
#
# [2012 rows x 10 columns]

# %%
panel_opciones
# Out:
#             last  change  open  high   low  previous_close  turnover  volume  \
# symbol
# ALUC10179O  53.0    3.92  53.0  53.0  53.0           51.00    5300.0     1.0
# ALUC115.DI  55.0   17.02  55.0  55.0  55.0           47.00    5500.0     1.0
# ALUC12679O  35.0   12.90  35.0  35.0  35.0           31.00    7000.0     2.0
# ALUC130.DI   NaN     NaN   NaN   NaN   NaN             NaN       NaN     NaN
# ALUC145.OC   NaN     NaN   NaN   NaN   NaN           14.00       NaN     NaN
# ...          ...     ...   ...   ...   ...             ...       ...     ...
# YPFV840.OC   NaN     NaN   NaN   NaN   NaN           10.27       NaN     NaN
# YPFV880.OC   NaN     NaN   NaN   NaN   NaN           28.00       NaN     NaN
# YPFV920.DI   NaN     NaN   NaN   NaN   NaN            8.75       NaN     NaN
# YPFV920.OC   1.5   30.43   1.5   1.5   1.5            1.15     300.0     2.0
# YPFV960.OC   NaN     NaN   NaN   NaN   NaN            3.00       NaN     NaN
#
#             operations            datetime expiration  strike  kind  \
# symbol
# ALUC10179O         1.0 2022-08-24 12:27:36 2022-10-21  101.79  CALL
# ALUC115.DI         1.0 2022-08-24 16:07:18 2022-12-16  115.00  CALL
# ALUC12679O         1.0 2022-08-24 13:44:35 2022-10-21  126.79  CALL
# ALUC130.DI         NaN                 NaT 2022-12-16  130.00  CALL
# ALUC145.OC         NaN                 NaT 2022-10-21  145.00  CALL
# ...                ...                 ...        ...     ...   ...
# YPFV840.OC         NaN                 NaT 2022-10-21  840.00   PUT
# YPFV880.OC         NaN                 NaT 2022-10-21  880.00   PUT
# YPFV920.DI         NaN                 NaT 2022-12-16  920.00   PUT
# YPFV920.OC         1.0 2022-08-24 16:19:28 2022-10-21  920.00   PUT
# YPFV960.OC         NaN                 NaT 2022-10-21  960.00   PUT
#
#            underlying_asset
# symbol
# ALUC10179O             ALUA
# ALUC115.DI             ALUA
# ALUC12679O             ALUA
# ALUC130.DI             ALUA
# ALUC145.OC             ALUA
# ...                     ...
# YPFV840.OC             YPFD
# YPFV880.OC             YPFD
# YPFV920.DI             YPFD
# YPFV920.OC             YPFD
# YPFV960.OC             YPFD
#
# [357 rows x 14 columns]

# %% [markdown]
# #### d) Limpiando el dataset

# %%
# Le agrego columnas nuevas
panel_opciones['Spot'] = 0.0 
panel_opciones['TTM']=0
panel_opciones['Moneyness']=0.0

# %%
#Genero la columna TTM
hoy = datetime.datetime.today()
      
#Codigo para obtener el TTM
x= (panel_opciones['expiration'] - hoy).values        
days = x.astype('timedelta64[D]')
ttm_f = (days+1) / np.timedelta64(1, 'D')
       
panel_opciones['TTM'] = ttm_f.astype(np.int64)

panel_opciones
# Out:
#             last  change  open  high   low  previous_close  turnover  volume  \
# symbol
# ALUC10179O  53.0    3.92  53.0  53.0  53.0           51.00    5300.0     1.0
# ALUC115.DI  55.0   17.02  55.0  55.0  55.0           47.00    5500.0     1.0
# ALUC12679O  35.0   12.90  35.0  35.0  35.0           31.00    7000.0     2.0
# ALUC130.DI   NaN     NaN   NaN   NaN   NaN             NaN       NaN     NaN
# ALUC145.OC   NaN     NaN   NaN   NaN   NaN           14.00       NaN     NaN
# ...          ...     ...   ...   ...   ...             ...       ...     ...
# YPFV840.OC   NaN     NaN   NaN   NaN   NaN           10.27       NaN     NaN
# YPFV880.OC   NaN     NaN   NaN   NaN   NaN           28.00       NaN     NaN
# YPFV920.DI   NaN     NaN   NaN   NaN   NaN            8.75       NaN     NaN
# YPFV920.OC   1.5   30.43   1.5   1.5   1.5            1.15     300.0     2.0
# YPFV960.OC   NaN     NaN   NaN   NaN   NaN            3.00       NaN     NaN
#
#             operations            datetime expiration  strike  kind  \
# symbol
# ALUC10179O         1.0 2022-08-24 12:27:36 2022-10-21  101.79  CALL
# ALUC115.DI         1.0 2022-08-24 16:07:18 2022-12-16  115.00  CALL
# ALUC12679O         1.0 2022-08-24 13:44:35 2022-10-21  126.79  CALL
# ALUC130.DI         NaN                 NaT 2022-12-16  130.00  CALL
# ALUC145.OC         NaN                 NaT 2022-10-21  145.00  CALL
# ...                ...                 ...        ...     ...   ...
# YPFV840.OC         NaN                 NaT 2022-10-21  840.00   PUT
# YPFV880.OC         NaN                 NaT 2022-10-21  880.00   PUT
# YPFV920.DI         NaN                 NaT 2022-12-16  920.00   PUT
# YPFV920.OC         1.0 2022-08-24 16:19:28 2022-10-21  920.00   PUT
# YPFV960.OC         NaN                 NaT 2022-10-21  960.00   PUT
#
#            underlying_asset  Spot  TTM  Moneyness
# symbol
# ALUC10179O             ALUA   0.0   58        0.0
# ALUC115.DI             ALUA   0.0  114        0.0
# ALUC12679O             ALUA   0.0   58        0.0
# ALUC130.DI             ALUA   0.0  114        0.0
# ALUC145.OC             ALUA   0.0   58        0.0
# ...                     ...   ...  ...        ...
# YPFV840.OC             YPFD   0.0   58        0.0
# YPFV880.OC             YPFD   0.0   58        0.0
# YPFV920.DI             YPFD   0.0  114        0.0
# YPFV920.OC             YPFD   0.0   58        0.0
# YPFV960.OC             YPFD   0.0   58        0.0
#
# [357 rows x 17 columns]

# %%
# Renombro las columnas, renombro el tipo Call/Put, reordeno y me quedo solo con las columnas que quiero
panel_opciones = panel_opciones.reset_index()
panel_opciones = panel_opciones.rename(
            columns={'symbol':'Especie','underlying_asset':'Ticker', 'kind': 'CallPut', 'last': 'Last', 'strike': 'Strike','previous_close':'Close'}, inplace=False)
       
panel_opciones['CallPut'] = pd.Series(panel_opciones['CallPut']).str.replace('CALL', 'C', regex=True)
panel_opciones['CallPut'] = pd.Series(panel_opciones['CallPut']).str.replace('PUT', 'P', regex=True)
       
panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])
panel_opciones = panel_opciones[
            ['Especie','Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Close','Moneyness']]

# %%
#Limpieza final
#Saco las Nan
panel_opciones = panel_opciones[pd.notna(panel_opciones.Last)]
# saco la columna indice vieja
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']

# %%
# Agrego el spot y el moneyness
# get_spot_from_ticker es un metodo propio

for fila in range(len(panel_opciones.Especie.values)):
    ticker_ = panel_opciones.Ticker.values[fila]
    panel_opciones['Spot'].values[fila] = get_spot_from_ticker(ticker_,snapshot)
        
panel_opciones['Moneyness']= panel_opciones['Spot'] / panel_opciones['Strike']

panel_opciones
# Out:
#         Especie Ticker    Spot CallPut  Strike  TTM    Last   Close  Moneyness
# 0    GFGC240.SE   GGAL  254.30       C  240.00   23  15.500  13.200   1.059583
# 1    GFGC280.SE   GGAL  254.30       C  280.00   23   6.000     NaN   0.908214
# 2    ALUC63.79O   ALUA  145.00       C   63.79   58  89.990  81.000   2.273084
# 3    ALUC69.79O   ALUA  145.00       C   69.79   58  84.000  81.739   2.077662
# 4    ALUC79.79O   ALUA  145.00       C   79.79   58  75.900  75.000   1.817270
# ..          ...    ...     ...     ...     ...  ...     ...     ...        ...
# 154  TRAC82.0DI   TRAN   94.00       C   82.00  114  32.000   2.000   1.146341
# 155  TXAC180.DI   TXAR  176.50       C  180.00  114  23.000   8.850   0.980556
# 156  BOLC5.60FE   BOLT    6.24       C    5.60  177   2.400     NaN   1.114286
# 157  GFGC360.FE   GGAL  254.30       C  360.00  177  10.238   9.000   0.706389
# 158  TXAV155.FE   TXAR  176.50       P  155.00  177  10.000     NaN   1.138710
#
# [159 rows x 9 columns]

# %%
#Limpieza final
#Saco las Nan
panel_opciones = panel_opciones[pd.notna(panel_opciones.Last)]
# saco la columna indice vieja
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']

# %%
panel_opciones
# Out:
#         Especie Ticker    Spot CallPut  Strike  TTM    Last   Close  Moneyness
# 0    GFGC240.SE   GGAL  254.30       C  240.00   23  15.500  13.200   1.059583
# 1    GFGC280.SE   GGAL  254.30       C  280.00   23   6.000     NaN   0.908214
# 2    ALUC63.79O   ALUA  145.00       C   63.79   58  89.990  81.000   2.273084
# 3    ALUC69.79O   ALUA  145.00       C   69.79   58  84.000  81.739   2.077662
# 4    ALUC79.79O   ALUA  145.00       C   79.79   58  75.900  75.000   1.817270
# ..          ...    ...     ...     ...     ...  ...     ...     ...        ...
# 154  TRAC82.0DI   TRAN   94.00       C   82.00  114  32.000   2.000   1.146341
# 155  TXAC180.DI   TXAR  176.50       C  180.00  114  23.000   8.850   0.980556
# 156  BOLC5.60FE   BOLT    6.24       C    5.60  177   2.400     NaN   1.114286
# 157  GFGC360.FE   GGAL  254.30       C  360.00  177  10.238   9.000   0.706389
# 158  TXAV155.FE   TXAR  176.50       P  155.00  177  10.000     NaN   1.138710
#
# [159 rows x 9 columns]

# 42  GFGC310.OC   GGAL  254.3       C  310.00   58    4.390    4.073   0.820323
# 43  GFGC320.OC   GGAL  254.3       C  320.00   58    3.508    3.111   0.794687
# 44  GFGC330.OC   GGAL  254.3       C  330.00   58    2.650    2.363   0.770606
# 45  GFGC340.OC   GGAL  254.3       C  340.00   58    2.050    1.936   0.747941
# 46  GFGC350.OC   GGAL  254.3       C  350.00   58    1.500    1.526   0.726571
# 47  GFGC360.OC   GGAL  254.3       C  360.00   58    1.399    1.272   0.706389
# 48  GFGV360.OC   GGAL  254.3       P  360.00   58  109.662      NaN   0.706389

# %% [markdown]
# ### Me quedo con las Calls

# %%
panel_opciones_ggal = panel_opciones_ggal[panel_opciones_ggal.CallPut == 'C']
panel_opciones_ggal
# Out:
#        Especie Ticker   Spot CallPut  Strike  TTM     Last    Close  Moneyness
# 2   GFGC132.OC   GGAL  254.3       C   132.0   58  124.000  127.584   1.926515
# 4   GFGC135.OC   GGAL  254.3       C   135.0   58  122.000  120.000   1.883704
# 13  GFGC175.OC   GGAL  254.3       C   175.0   58   89.000   85.000   1.453143
# 15  GFGC180.OC   GGAL  254.3       C   180.0   58   82.100   79.048   1.412778
# 18  GFGC185.OC   GGAL  254.3       C   185.0   58   80.000   74.000   1.374595
# 20  GFGC195.OC   GGAL  254.3       C   195.0   58   72.698   68.000   1.304103
# 22  GFGC200.OC   GGAL  254.3       C   200.0   58   66.000   62.633   1.271500
# 24  GFGC210.OC   GGAL  254.3       C   210.0   58   58.000   54.355   1.210952
# 26  GFGC220.OC   GGAL  254.3       C   220.0   58   49.500   45.814   1.155909
# 28  GFGC230.OC   GGAL  254.3       C   230.0   58   41.500   38.121   1.105652
# 30  GFGC240.OC   GGAL  254.3       C   240.0   58   33.440   30.002   1.059583
# 32  GFGC250.OC   GGAL  254.3       C   250.0   58   26.300   23.073   1.017200
# 34  GFGC260.OC   GGAL  254.3       C   260.0   58   20.000   17.878   0.978077
# 36  GFGC270.OC   GGAL  254.3       C   270.0   58   15.200   13.490   0.941852
# 38  GFGC280.OC   GGAL  254.3       C   280.0   58   10.510   10.035   0.908214
# 40  GFGC290.OC   GGAL  254.3       C   290.0   58    8.000    7.303   0.876897
# 41  GFGC300.OC   GGAL  254.3       C   300.0   58    5.801    5.202   0.847667
# 42  GFGC310.OC   GGAL  254.3       C   310.0   58    4.390    4.073   0.820323
# 43  GFGC320.OC   GGAL  254.3       C   320.0   58    3.508    3.111   0.794687
# 44  GFGC330.OC   GGAL  254.3       C   330.0   58    2.650    2.363   0.770606
# 45  GFGC340.OC   GGAL  254.3       C   340.0   58    2.050    1.936   0.747941
# 46  GFGC350.OC   GGAL  254.3       C   350.0   58    1.500    1.526   0.726571
# 47  GFGC360.OC   GGAL  254.3       C   360.0   58    1.399    1.272   0.706389

# %%
from matplotlib import pyplot as plt
Ks = list(set(panel_opciones_ggal.Strike.values))
precios = []
for K in Ks:
    precios.append(panel_opciones_ggal[(panel_opciones_ggal.Strike == K)].Close.values)
precios
plt.plot(Ks, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()
