# %% [markdown]
# # Derivados Financieros 2022 - Clase 1

# %% [markdown]
# ## Menu del dia:
#
#     - (1) Web scraping de rava
#     - (2) Limpieza y generacion de dataframe ad-hoc para futuros usos
#     - (3) pyhomebroker (requiere acceso a ALyC que use HomeBroker)
#     - (4) algunos plots de market data de opciones
#     - (5) exportar a exel/csv
#     - (6) Comparar paneles (rava-hb)

# %% [markdown]
# ## (1) Web Scraping de la pagina de RAVA

# %% [markdown]
# Modulos necesarios
#
# data_byma (en webcampus) ;
#
# utils_opciones_byma (en webcampus)
#
# bs4,
#
# requests,
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# calendar,
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install

# %% [markdown]
# ### Importo los modulos

# %%
import sys

sys.path.append('..')
from Codigo.data_byma import *
from Codigo.utils_opciones_byma import *

# %% [markdown]
# ### Metodo para el web scraping

# %%
panel_opciones = web_scraping_opciones_iol()
panel_opciones.head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase1.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> panel_opciones = web_scraping_opciones_iol()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> panel_opciones.head(20)
#
# File c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_byma.py:22, in web_scraping_opciones_iol()
#      20 soup = BeautifulSoup(page.text, 'lxml')
#      21 opciones = soup.find('table', {'id': 'cotizaciones'})
# ---> 22 filas = opciones.find_all('tr')
#      24 l = []
#      25 tr = filas[0]
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# ### Que hace internamente el metodo??

# %% [markdown]
# #### Beautiful Soup /requests
#
#
# Mas sobre BS4: https://j2logo.com/python/web-scraping-con-python-guia-inicio-beautifulsoup/
#
# Mas sobre requests: https://www.digitalocean.com/community/tutorials/how-to-get-started-with-the-requests-library-in-python-es

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# #### Como usamos BeautifulSoup y requests

# %%
#url = 'http://www.rava.com/precios/panel.php?m=OPC'
#url = 'http://clasico.rava.com/precios/panel.php?m=OPC'
#url = 'http://datos.rava.com/cotizaciones/opciones'
url = 'https://iol.invertironline.com/mercado/cotizaciones/argentina/opciones/todas'


page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
# En soup voy a encontrar el codigo html de la pagina

soup = BeautifulSoup(page.text, 'lxml')
soup
# Out:
# <html>
# <head>
# <meta content="noindex,nofollow" name="robots"/>
# <script src="/_Incapsula_Resource?SWJIYLWA=5074a744e2e3d891814e9a2dace20bd4,719d34d31c8e3a6e6fffd425f7e032f3">
# </script>
# </head><body>
# </body></html>

# %% [markdown]
# #### El arte del scraping
#
# Aqui es donde uno tiene que meterse en el codigo interno de la pagina e 'identificar' la informacion que necesita. En este caso la tabla de informacion de opciones
# Se puede hacer una inspeccion en modo dev del navegador

# %%
# En opciones tengo el contenido de la tabla correspondiente





opciones = soup.find('table', {'id': 'cotizaciones'})
opciones

# %% [markdown]
# #### Aqui continua el detalle. Se identifican las filas de la tabla. *tr* sera el separador que va empezando y cerrando las filas

# %%
# Filas ya va ordenando cada una de las opciones


filas = opciones.find_all('tr')
filas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase1.ipynb Cell 19 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # Filas ya va ordenando cada una de las opciones
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> filas = opciones.find_all('tr')
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> filas
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# #### Identifico la primera linea, la de los -headers- de la tabla

# %%
tr = filas[0]
tr
# Out:
# <tr class="text-center dthead">
# <td>Símbolo</td>
# <td>Último<br/>Operado</td>
# <td>Variación<br/>Diaria</td>
# <td>Cantidad<br/>Compra</td>
# <td>Precio<br/>Compra</td>
# <td>Precio<br/>Venta</td>
# <td>Cantidad<br/>Venta</td>
# <td>Apertura</td>
# <td>Mínimo</td>
# <td>Máximo</td>
# <td>Último<br/>Cierre</td>
# <td>Monto<br/>Operado</td>
# <td class="noarrow"></td>
# </tr>

# %% [markdown]
# #### Identifico cada columna dentro de la fila con el marcador td

# %%
td = tr.find_all('td')
td
# Out:
# [<td>Símbolo</td>,
#  <td>Último<br/>Operado</td>,
#  <td>Variación<br/>Diaria</td>,
#  <td>Cantidad<br/>Compra</td>,
#  <td>Precio<br/>Compra</td>,
#  <td>Precio<br/>Venta</td>,
#  <td>Cantidad<br/>Venta</td>,
#  <td>Apertura</td>,
#  <td>Mínimo</td>,
#  <td>Máximo</td>,
#  <td>Último<br/>Cierre</td>,
#  <td>Monto<br/>Operado</td>,
#  <td class="noarrow"></td>]

# %% [markdown]
# #### generamos una lista (ya un terreno mas conocido :)

# %%
row = [tr.text for tr in td]
row
# Out:
# ['Símbolo',
#  'ÚltimoOperado',
#  'VariaciónDiaria',
#  'CantidadCompra',
#  'PrecioCompra',
#  'PrecioVenta',
#  'CantidadVenta',
#  'Apertura',
#  'Mínimo',
#  'Máximo',
#  'ÚltimoCierre',
#  'MontoOperado',
#  '']

# %% [markdown]
# #### Proceso de ir almacenando las filas en una lista d elistas (eventualmente terminara siendo un dataframe)

# %%
# inicializo una lista vacia, alli voy a ir poniendo el contenido de cada fila
l = []
l.append(row)

l
# Out:
# [['Símbolo',
#   'ÚltimoOperado',
#   'VariaciónDiaria',
#   'CantidadCompra',
#   'PrecioCompra',
#   'PrecioVenta',
#   'CantidadVenta',
#   'Apertura',
#   'Mínimo',
#   'Máximo',
#   'ÚltimoCierre',
#   'MontoOperado',
#   '']]

# %% [markdown]
# #### fila por fila

# %%
tr = filas[1]
tr
# Out:
# <tr data-cantidad="1" data-tituloid="115385-">
# <td class="tal links neutral mw145" data-field="IDTitulo" data-quotestyle='{"ValueChange": false, "flash":"no", "CssChange":true }'>
# <i class="icono-simbolo mr10 fl aigc1800di" data-placement="top" data-toggle="tooltip"></i>
# <a data-placement="top" data-symbol="AIGC1800DI" data-toggle="tooltip" data-url="/Titulo/Index/115385" href="/Titulo/Index/115385">
# <b>
#                                 AIGC1800DI
#                             </b>
# <br/>
# <span style="font-size: 11px;">
# </span>
# </a>
# </td>
# <td class="right tar" data-field="UltimoPrecio" data-order="0" data-quotestyle='{"flash":"yes", "ElementToFlash": "115385-" }'>
#                         0,000
#                     </td>
# <td class="neutral text-right" data-field="Variacion" data-order="0" data-quotestyle='{"ValueChange": false, "flash":"no", "CssChange":true}'>
# <i class="sprite-inline sprite-arrow mr5"></i><span class="ml15" data-field="Variacion">0</span>%
#                     </td>
# <td class="highlightcompra tar pr15">-</td>
# <td class="highlightcompra tar pr15" data-order="-">-</td>
# <td class="highlightventa tar pr15" data-order="-">-</td>
# <td class="highlightventa tar pr15">-</td>
# <td class="tar" data-field="Apertura" data-order="0">
#                         0,000
#                     </td>
# <td class="tar" data-field="Minimo" data-order="0" data-quotestyle='{"flash":"onchange"}'>
#                         0,000
#                     </td>
# <td class="tar" data-field="Maximo" data-order="0" data-quotestyle='{"flash":"onchange"}'>
#                         0,000
#                     </td>
# <td class="tar" data-field="UltimoCierre" data-order="0">
#                         0,000
#                     </td>
# <td class="tar">
#                         0
#                     </td>
# <td>
# <span class="flags star-empty" data-idtitulo="115385" onclick="ToogleFavorito(this)"></span>
# </td>
# </tr>

# %%
td = tr.find_all('td')
row = [tr.text for tr in td]
row
# Out:
# ['\n\n\n\r\n                                AIGC1800DI\r\n                            \n\n\n\n\n',
#  '\r\n                        0,000\r\n                    ',
#  '\n0%\r\n                    ',
#  '-',
#  '-',
#  '-',
#  '-',
#  '\r\n                        0,000\r\n                    ',
#  '\r\n                        0,000\r\n                    ',
#  '\r\n                        0,000\r\n                    ',
#  '\r\n                        0,000\r\n                    ',
#  '\r\n                        0\r\n                    ',
#  '\n\n']

# %% [markdown]
# ####  Aca las primeras intervenciones sobre la data que viene del html para que sea mas facil manipularla

# %%
#Reemplazo ',' por '.' y paso el string a float
for index in [1,2,3,4,5,6,8,9]:
    row[index] = row[index].replace('.', '')
    row[index] = row[index].replace(',', '.')
    try:
        row[index] = float(row[index])
    except:
        #Si no encuentra valor pone -99.99
        row[index] = -99.99

l.append(row)
    
l
# Out:
# [['Símbolo',
#   'ÚltimoOperado',
#   'VariaciónDiaria',
#   'CantidadCompra',
#   'PrecioCompra',
#   'PrecioVenta',
#   'CantidadVenta',
#   'Apertura',
#   'Mínimo',
#   'Máximo',
#   'ÚltimoCierre',
#   'MontoOperado',
#   ''],
#  ['\n\n\n\r\n                                AIGC1800DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n']]

# %%
#Ahora si, todas las filas
for tr in filas[2:]:
    td = tr.find_all('td')
    row = [tr.text for tr in td]

    #Reemplazo ',' por '.' y paso el string a float
    for index in [1,2,3,4,5,6,8,9]:
        row[index] = row[index].replace('.', '')
        row[index] = row[index].replace(',', '.')
        try:
            row[index] = float(row[index])
        except:
            #Si no encuentra valor pone -99.99
            row[index] = -99.99

    l.append(row)

# %%
# Como se ve l despues del ciclo?
l
# Out:
# [['Símbolo',
#   'ÚltimoOperado',
#   'VariaciónDiaria',
#   'CantidadCompra',
#   'PrecioCompra',
#   'PrecioVenta',
#   'CantidadVenta',
#   'Apertura',
#   'Mínimo',
#   'Máximo',
#   'ÚltimoCierre',
#   'MontoOperado',
#   ''],
#  ['\n\n\n\r\n                                AIGC1800DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC1800OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2000DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2000OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2200DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2200OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2400DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2400OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2400SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2600DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2600OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2600SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2800DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2800OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC2800SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3000DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3000OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3000SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3200DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3200OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3200SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3400DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3400OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3400SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3600DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3600OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3600SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3800DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3800OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                AIGC3800SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC100.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC100.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC10179O\r\n                            \n\n\n\n\n',
#   50.136,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        57,100\r\n                    ',
#   50.0,
#   57.1,
#   '\r\n                        50,136\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC105.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC105.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC110.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC110.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC110.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC11179O\r\n                            \n\n\n\n\n',
#   38.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        38,000\r\n                    ',
#   38.0,
#   38.0,
#   '\r\n                        38,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC115.DI\r\n                            \n\n\n\n\n',
#   47.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        48,000\r\n                    ',
#   47.0,
#   48.0,
#   '\r\n                        47,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC115.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC120.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC120.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC120.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC125.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC125.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC125.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC12679O\r\n                            \n\n\n\n\n',
#   31.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        31,000\r\n                    ',
#   31.0,
#   31.0,
#   '\r\n                        31,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC130.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC130.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC135.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC135.FE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC135.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC135.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC140.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC140.FE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC140.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC140.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC145.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC145.FE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC145.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC145.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC150.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC150.FE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC150.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC150.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC155.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC155.FE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC155.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC155.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC160.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC160.FE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC160.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC160.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC63.79O\r\n                            \n\n\n\n\n',
#   81.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        81,000\r\n                    ',
#   80.0,
#   81.0,
#   '\r\n                        81,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC65.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC65.0OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC67.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC67.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC69.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC69.0OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC69.79D\r\n                            \n\n\n\n\n',
#   15.5,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        15,500\r\n                    ',
#   15.5,
#   15.5,
#   '\r\n                        15,500\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC69.79O\r\n                            \n\n\n\n\n',
#   80.327,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        82,000\r\n                    ',
#   76.0,
#   82.0,
#   '\r\n                        80,327\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC71.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC71.0OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC71.79D\r\n                            \n\n\n\n\n',
#   84.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        85,000\r\n                    ',
#   84.0,
#   85.0,
#   '\r\n                        84,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC73.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC73.79O\r\n                            \n\n\n\n\n',
#   82.4,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        82,400\r\n                    ',
#   82.4,
#   82.4,
#   '\r\n                        82,400\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC75.0OC\r\n                            \n\n\n\n\n',
#   73.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        73,000\r\n                    ',
#   73.0,
#   73.0,
#   '\r\n                        73,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC75.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC75.79O\r\n                            \n\n\n\n\n',
#   21.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        21,000\r\n                    ',
#   21.0,
#   21.0,
#   '\r\n                        21,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC77.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC77.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC79.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC79.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC79.79O\r\n                            \n\n\n\n\n',
#   71.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        71,000\r\n                    ',
#   70.0,
#   71.0,
#   '\r\n                        71,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC83.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC83.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC83.79O\r\n                            \n\n\n\n\n',
#   28.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        28,000\r\n                    ',
#   28.0,
#   28.0,
#   '\r\n                        28,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC87.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC87.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC87.79O\r\n                            \n\n\n\n\n',
#   37.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        37,000\r\n                    ',
#   37.0,
#   37.0,
#   '\r\n                        37,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC91.0DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC91.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC91.79D\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC91.79O\r\n                            \n\n\n\n\n',
#   60.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        60,000\r\n                    ',
#   60.0,
#   60.0,
#   '\r\n                        60,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC95.0SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUC96.79O\r\n                            \n\n\n\n\n',
#   50.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        50,000\r\n                    ',
#   49.5,
#   50.0,
#   '\r\n                        50,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV100.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV100.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV10179O\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV105.DI\r\n                            \n\n\n\n\n',
#   0.205,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,300\r\n                    ',
#   0.205,
#   0.3,
#   '\r\n                        0,205\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV105.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV110.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV110.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV110.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV11179O\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV115.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV115.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV120.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV120.OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV120.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV125.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV125.OC\r\n                            \n\n\n\n\n',
#   2.8,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        2,800\r\n                    ',
#   2.8,
#   2.8,
#   '\r\n                        2,800\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV125.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV12679O\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV130.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV130.SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV135.DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                ALUV135.FE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
# ...
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMC9.75OC\r\n                            \n\n\n\n\n',
#   7.24,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        7,240\r\n                    ',
#   7.24,
#   7.24,
#   '\r\n                        7,240\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV10.25D\r\n                            \n\n\n\n\n',
#   0.125,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,125\r\n                    ',
#   0.125,
#   0.125,
#   '\r\n                        0,125\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV10.25O\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV10.25S\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV10.75D\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV10.75O\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV10.75S\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV11.2DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV11.2OC\r\n                            \n\n\n\n\n',
#   0.06,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,060\r\n                    ',
#   0.058,
#   0.06,
#   '\r\n                        0,060\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV11.2SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV11.7DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV11.7OC\r\n                            \n\n\n\n\n',
#   0.132,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,132\r\n                    ',
#   0.132,
#   0.132,
#   '\r\n                        0,132\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV11.7SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV12.2DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV12.2OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV12.2SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV12.7DI\r\n                            \n\n\n\n\n',
#   0.093,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,093\r\n                    ',
#   0.093,
#   0.093,
#   '\r\n                        0,093\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV12.7OC\r\n                            \n\n\n\n\n',
#   0.037,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,037\r\n                    ',
#   0.037,
#   0.037,
#   '\r\n                        0,037\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV12.7SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV13.2DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV13.2OC\r\n                            \n\n\n\n\n',
#   0.21,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,210\r\n                    ',
#   0.18,
#   0.21,
#   '\r\n                        0,210\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV13.2SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV13.7DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV13.7OC\r\n                            \n\n\n\n\n',
#   0.18,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,200\r\n                    ',
#   0.107,
#   0.2,
#   '\r\n                        0,180\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV13.7SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV14.2DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV14.2OC\r\n                            \n\n\n\n\n',
#   0.35,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,350\r\n                    ',
#   0.35,
#   0.35,
#   '\r\n                        0,350\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV14.2SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV14.7DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV14.7OC\r\n                            \n\n\n\n\n',
#   0.45,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,500\r\n                    ',
#   0.309,
#   0.5,
#   '\r\n                        0,450\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV14.7SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV15.2DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV15.2OC\r\n                            \n\n\n\n\n',
#   0.462,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,530\r\n                    ',
#   0.45,
#   0.53,
#   '\r\n                        0,462\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV15.2SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV15.7DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV15.7OC\r\n                            \n\n\n\n\n',
#   0.68,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,680\r\n                    ',
#   0.68,
#   0.68,
#   '\r\n                        0,680\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV15.7SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV16.2DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV16.2OC\r\n                            \n\n\n\n\n',
#   0.85,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,850\r\n                    ',
#   0.85,
#   0.85,
#   '\r\n                        0,850\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV16.2SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV16.7DI\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV16.7OC\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ['\n\n\n\r\n                                COMV16.7SE\r\n                            \n\n\n\n\n',
#   0.0,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   -99.99,
#   '\r\n                        0,000\r\n                    ',
#   0.0,
#   0.0,
#   '\r\n                        0,000\r\n                    ',
#   '\r\n                        0\r\n                    ',
#   '\n\n'],
#  ...]

# %% [markdown]
# #### Lo convierto en un DataFrame

# %%
panel = pd.DataFrame(l[1:], columns=l[0])

panel
# Out:
#                                                 Símbolo  ÚltimoOperado  \
# 0     \n\n\n\r\n                                AIGC...          0.000
# 1     \n\n\n\r\n                                AIGC...          0.000
# 2     \n\n\n\r\n                                AIGC...          0.000
# 3     \n\n\n\r\n                                AIGC...          0.000
# 4     \n\n\n\r\n                                AIGC...          0.000
# ...                                                 ...            ...
# 2689  \n\n\n\r\n                                YPFV...          2.755
# 2690  \n\n\n\r\n                                YPFV...          0.000
# 2691  \n\n\n\r\n                                YPFV...          0.000
# 2692  \n\n\n\r\n                                YPFV...          3.000
# 2693  \n\n\n\r\n                                YPFV...          0.000
#
#       VariaciónDiaria  CantidadCompra  PrecioCompra  PrecioVenta  \
# 0              -99.99          -99.99        -99.99       -99.99
# 1              -99.99          -99.99        -99.99       -99.99
# 2              -99.99          -99.99        -99.99       -99.99
# 3              -99.99          -99.99        -99.99       -99.99
# 4              -99.99          -99.99        -99.99       -99.99
# ...               ...             ...           ...          ...
# 2689           -99.99          -99.99        -99.99       -99.99
# 2690           -99.99          -99.99        -99.99       -99.99
# 2691           -99.99          -99.99        -99.99       -99.99
# 2692           -99.99          -99.99        -99.99       -99.99
# 2693           -99.99          -99.99        -99.99       -99.99
#
#       CantidadVenta                                           Apertura  \
# 0            -99.99  \r\n                        0,000\r\n         ...
# 1            -99.99  \r\n                        0,000\r\n         ...
# 2            -99.99  \r\n                        0,000\r\n         ...
# 3            -99.99  \r\n                        0,000\r\n         ...
# 4            -99.99  \r\n                        0,000\r\n         ...
# ...             ...                                                ...
# 2689         -99.99  \r\n                        3,000\r\n         ...
# 2690         -99.99  \r\n                        0,000\r\n         ...
# 2691         -99.99  \r\n                        0,000\r\n         ...
# 2692         -99.99  \r\n                        3,000\r\n         ...
# 2693         -99.99  \r\n                        0,000\r\n         ...
#
#       Mínimo  Máximo                                       ÚltimoCierre  \
# 0       0.00     0.0  \r\n                        0,000\r\n         ...
# 1       0.00     0.0  \r\n                        0,000\r\n         ...
# 2       0.00     0.0  \r\n                        0,000\r\n         ...
# 3       0.00     0.0  \r\n                        0,000\r\n         ...
# 4       0.00     0.0  \r\n                        0,000\r\n         ...
# ...      ...     ...                                                ...
# 2689    2.51     3.0  \r\n                        2,755\r\n         ...
# 2690    0.00     0.0  \r\n                        0,000\r\n         ...
# 2691    0.00     0.0  \r\n                        0,000\r\n         ...
# 2692    3.00     3.0  \r\n                        3,000\r\n         ...
# 2693    0.00     0.0  \r\n                        0,000\r\n         ...
#
#                                            MontoOperado
# 0     \r\n                        0\r\n             ...  \n\n
# 1     \r\n                        0\r\n             ...  \n\n
# 2     \r\n                        0\r\n             ...  \n\n
# 3     \r\n                        0\r\n             ...  \n\n
# 4     \r\n                        0\r\n             ...  \n\n
# ...                                                 ...   ...
# 2689  \r\n                        0\r\n             ...  \n\n
# 2690  \r\n                        0\r\n             ...  \n\n
# 2691  \r\n                        0\r\n             ...  \n\n
# 2692  \r\n                        0\r\n             ...  \n\n
# 2693  \r\n                        0\r\n             ...  \n\n
#
# [2694 rows x 13 columns]

# %% [markdown]
#     ### lo mandamos a un csv

# %%
#panel.to_csv('panel_opciones_iol.csv')

# %% [markdown]
# ### Panel acciones (bonus)

# %%
panel_acciones = obtener_panel_acciones()
panel_acciones
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase1.ipynb Cell 42 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> panel_acciones = obtener_panel_acciones()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a> panel_acciones
#
# File c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_byma.py:376, in obtener_panel_acciones()
#     374 soup = BeautifulSoup(page.text, 'lxml')
#     375 precios = soup.find('table', {'class': 'tablapanel'})
# --> 376 filas = precios.find_all('tr')
#     378 tr = filas[2]
#     379 td = tr.find_all('td')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# ## (2) Del panel de Iol crudo a otro con informacion customizada

# %% [markdown]
# ### Metodo para generar el panel customizado
#
# a) Panel crudo mas informacion masticada (columnas de la derecha)

# %%
panel_opciones_byma_all_raw = obtener_panel_opciones_byma(ticker = '', clean_flag = False)
panel_opciones_byma_all_raw
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase1.ipynb Cell 44 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> panel_opciones_byma_all_raw = obtener_panel_opciones_byma(ticker = '', clean_flag = False)
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a> panel_opciones_byma_all_raw
#
# File c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_byma.py:95, in obtener_panel_opciones_byma(ticker, clean_flag)
#      93 panel_rava = web_scraping_opciones_iol()
#      94 #Obtengo el panel crudo de acciones (para el spot)
# ---> 95 panel_acciones = obtener_panel_acciones()
#      97 #Genero el nuevo panel
#      98 panel_opciones = panel_rava.copy()
#
# File c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_byma.py:376, in obtener_panel_acciones()
#     374 soup = BeautifulSoup(page.text, 'lxml')
#     375 precios = soup.find('table', {'class': 'tablapanel'})
# --> 376 filas = precios.find_all('tr')
#     378 tr = filas[2]
#     379 td = tr.find_all('td')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# b) Panel limpiotodos los tickers

# %%
panel_opciones_byma_all_clean = obtener_panel_opciones_byma(ticker = '', clean_flag = True)
panel_opciones_byma_all_clean
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase1.ipynb Cell 46 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> panel_opciones_byma_all_clean = obtener_panel_opciones_byma(ticker = '', clean_flag = True)
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase1.ipynb#X61sZmlsZQ%3D%3D?line=1'>2</a> panel_opciones_byma_all_clean
#
# File c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_byma.py:95, in obtener_panel_opciones_byma(ticker, clean_flag)
#      93 panel_rava = web_scraping_opciones_iol()
#      94 #Obtengo el panel crudo de acciones (para el spot)
# ---> 95 panel_acciones = obtener_panel_acciones()
#      97 #Genero el nuevo panel
#      98 panel_opciones = panel_rava.copy()
#
# File c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_byma.py:376, in obtener_panel_acciones()
#     374 soup = BeautifulSoup(page.text, 'lxml')
#     375 precios = soup.find('table', {'class': 'tablapanel'})
# --> 376 filas = precios.find_all('tr')
#     378 tr = filas[2]
#     379 td = tr.find_all('td')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# b) Panel limpio paa un ticker en particular

# %%
panel_opciones_byma_GGAL_clean = obtener_panel_opciones_byma('GGAL', True)
panel_opciones_byma_GGAL_clean

# %% [markdown]
# ### Que hace el metodo internamente?

# %% [markdown]
# #### 1) Levanta los paneles de opciones y de acciones y genera una copia del de opciones

# %%
panel_rava = web_scraping_opciones_rava()
#Obtengo el panel crudo de acciones (para el spot)
panel_acciones = obtener_panel_acciones()

#Genero el nuevo panel
panel_opciones = panel_rava.copy()

# %% [markdown]
# #### 2) Inicializo las columnas nuevas a agregar del Dataframe

# %%
#Le agrego las nuevas columnas (ojo con los tipos string, float, int, datetime)
panel_opciones['Ticker_Opcion'] = ''
panel_opciones['Ticker_Stock'] = ''
panel_opciones['Tipo'] = ''
panel_opciones['Strike'] = 0.0
panel_opciones['ExpiryMonthName'] = ''
panel_opciones['ExpiryMonthNumber'] = 0
panel_opciones['ExpiryDate'] = datetime.date.today()
panel_opciones['Spot'] = 0.0
panel_opciones['TTM'] = 0
panel_opciones['Moneyness'] = 0.0

panel_opciones

# %% [markdown]
# #### 3) Recorro fila por fila para llenar las nuevas columnas (1 ejemplo)

# %% [markdown]
# ##### *) Desgloso la especie en ticker, strike, vencimiento y tipo

# %%
fila = 0


panel_opciones.Ticker_Opcion.values[fila] = panel_opciones.Especie.values[fila][0:3]

panel_opciones.Tipo.values[fila] = panel_opciones.Especie.values[fila][3:4]
panel_opciones.Strike.values[fila] = panel_opciones.Especie.values[fila][4:8]
panel_opciones.ExpiryMonthName.values[fila] = panel_opciones.Especie.values[fila][8:10]

panel_opciones.head(2)

# %% [markdown]
# ##### *) Uno a uno voy generando lo necesario

# %%
panel_opciones.Ticker_Stock.values[fila] = conversor_ticker(panel_opciones.Ticker_Opcion.values[fila])

panel_opciones.Tipo.values[fila] = panel_opciones.Tipo.values[fila].replace('V', 'P')

panel_opciones.head(2)

# %%
# Artilugio que lo tuve que usar NO RECUERDO POR QUE! :)

try:
    int(panel_opciones.ExpiryMonthName.values[fila][0])
    panel_opciones.Strike.values[fila] = float(panel_opciones.Strike.values[fila] + int(panel_opciones.ExpiryMonthName.values[fila][0]))
    panel_opciones.ExpiryMonthName.values[fila] = panel_opciones.ExpiryMonthName.values[fila][1]
except:
    panel_opciones.Strike.values[fila] = float(panel_opciones.Strike.values[fila])

# %%
#conversor_ticker('AGR')

#panel_opciones.Especie.values[fila][0:3]

#panel_opciones.Ticker_Opcion.values[fila]\

#conversor_ticker(panel_opciones.Ticker_Opcion.values[fila])

#panel_opciones.Ticker_Stock.values[fila]

# %% [markdown]
# ##### *) Obtengo el precio spot del ticker con un metodo interno y aprovechando el panel de acciones

# %%
panel_opciones.Spot.values[fila] = obtener_spot_ticker(panel_acciones, panel_opciones.Ticker_Stock.values[fila])

# %% [markdown]
# ##### *) Obtengo el Time to maturity (en dias)

# %%
try:
    panel_opciones.ExpiryMonthNumber.values[fila] = mes_nombre_a_numero(panel_opciones.ExpiryMonthName.values[fila])
except:
    panel_opciones.ExpiryMonthNumber.values[fila] = 0

panel_opciones.ExpiryDate.values[fila] = fecha_expiracion(panel_opciones.ExpiryMonthNumber.values[fila])
hoy = datetime.date.today()
panel_opciones.TTM.values[fila] = (panel_opciones.ExpiryDate.values[fila] - hoy).days

panel_opciones

# %% [markdown]
# ##### *) Por ultimo calculo el moneyness de valor informativo importante

# %%
panel_opciones.Moneyness.values[fila] = panel_opciones.Spot.values[fila] / panel_opciones.Strike.values[fila]

# %%
panel_opciones.head(2)

# %% [markdown]
# #### 3bis) Recorro fila por fila para llenar las nuevas columnas

# %%
for fila in range(1,len(panel_opciones.Especie.values)):
    panel_opciones.Ticker_Opcion.values[fila] = panel_opciones.Especie.values[fila][0:3]

    panel_opciones.Ticker_Stock.values[fila] = conversor_ticker(panel_opciones.Ticker_Opcion.values[fila])

    panel_opciones.Tipo.values[fila] = panel_opciones.Especie.values[fila][3:4]
    panel_opciones.Tipo.values[fila] = panel_opciones.Tipo.values[fila].replace('V', 'P')

    panel_opciones.Strike.values[fila] = panel_opciones.Especie.values[fila][4:8]

    panel_opciones.ExpiryMonthName.values[fila] = panel_opciones.Especie.values[fila][8:10]

    try:
        int(panel_opciones.ExpiryMonthName.values[fila][0])
        panel_opciones.Strike.values[fila] = float(panel_opciones.Strike.values[fila] + int(panel_opciones.ExpiryMonthName.values[fila][0]))
        panel_opciones.ExpiryMonthName.values[fila] = panel_opciones.ExpiryMonthName.values[fila][1]
    except:
        panel_opciones.Strike.values[fila] = float(panel_opciones.Strike.values[fila])

    try:
        panel_opciones.ExpiryMonthNumber.values[fila] = mes_nombre_a_numero(panel_opciones.ExpiryMonthName.values[fila])
    except:
        panel_opciones.ExpiryMonthNumber.values[fila] = 0

    panel_opciones.ExpiryDate.values[fila] = fecha_expiracion(panel_opciones.ExpiryMonthNumber.values[fila])


    panel_opciones.Spot.values[fila] = obtener_spot_ticker(panel_acciones, panel_opciones.Ticker_Stock.values[fila])


    hoy = datetime.date.today()
    panel_opciones.TTM.values[fila] = (panel_opciones.ExpiryDate.values[fila] - hoy).days

    panel_opciones.Moneyness.values[fila] = panel_opciones.Spot.values[fila] / panel_opciones.Strike.values[fila]

# %%
#Asi queda entonces el panel
panel_opciones

# %% [markdown]
# #### 4) Filtro por ticker

# %%
#Si se provee un ticker, se filtra por ticker, si no, se provee el panel completo

ticker = 'ALUA'

if ticker == '':
    pass
else:
    panel_opciones = panel_opciones[panel_opciones.Ticker_Stock == ticker]
    
panel_opciones

# %% [markdown]
# #### 5) Panel limpio

# %%
panel_limpio = panel_opciones.copy()

clean_flag = True

# Panel limpio: cambio de nombre, reordenamiento y limpieza minima del panel
if clean_flag == True:
    # Sacar opciones sobre bonos
    panel_limpio = panel_limpio[~panel_limpio.Especie.str.contains('A24')]

    panel_limpio = panel_limpio[
            ['Especie', 'Ticker_Stock', 'Spot', 'Tipo', 'Strike', 'TTM', 'Último', 'Moneyness']]

    panel_limpio = panel_limpio.rename(
            columns={'Ticker_Stock': 'Ticker', 'Tipo': 'CallPut', 'Último': 'Last'}, inplace=False)

    panel_limpio = panel_limpio.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])

    # Remover TTMs mayores de un año o negativos (por algun error)
    panel_limpio = panel_limpio[panel_limpio.TTM < 364]
    panel_limpio = panel_limpio[panel_limpio.TTM > 0]

    panel_limpio = panel_limpio.reset_index()
    del panel_limpio['index']
    
panel_limpio

# %% [markdown]
# ## (3) pyhomebroker

# %% [markdown]
# ### pyhomebroker es una a API para conectar a un programa/script/notebook de python al mercado a traves de AlyCs que usen la plataforma homebroker (Estudio Gallo). Se usa para recibir precios y datos de mercado en tiempo real. Permite tambien obtener data historica.
#
#
# Mas info e instrucciones de instalacion en https://pypi.org/project/pyhomebroker/
#
# Estudio Gallo: http://www.estudiogallo.com.ar/
#
# Home Broker: https://www.youtube.com/watch?v=ippFga_hKSg

# %% [markdown]
# ### por obvias razones, no revelo mis datos personales :) Pero aqui habria que crear un diccionario con sus datos

# %%
from data_byma_homebroker import *
import pickle
#TO SAVE
#personal_data = {'ByMA_id' : BymaId,
#                 'dni'     : dni, 
#                 'user'    : user,
#                 'password': password}
#pickle.dump(personal_data, open("personal_data.info", "wb"))

#TO LOAD
personal_data = pickle.load(open("personal_data.info", "rb"))

# %% [markdown]
# ### Metodos disponibles

# %%
panel_opciones_homebroker_all_raw = panel_opciones_homebroker(personal_data,
                                                              ticker = '', 
                                                              clean_flag=False)
panel_opciones_homebroker_all_raw

# %%
panel_opciones_homebroker_all_clean = panel_opciones_homebroker(personal_data, 
                                                                ticker = '', 
                                                                clean_flag=True)
panel_opciones_homebroker_all_clean

# %%
panel_opciones_homebroker_GGAL_clean = panel_opciones_homebroker(personal_data, 'GGAL', True)
panel_opciones_homebroker_GGAL_clean

# %% [markdown]
# ### Que hace el metodo internamente?

# %% [markdown]
# #### a) Recupero la informacion del picke (esto es personal!)

# %%
# Recupero la informacion del pickle

ByMA_id = personal_data['ByMA_id']
dni = personal_data['dni']
user = personal_data['user']
password = personal_data['password']

# %% [markdown]
# #### b) Conecto con el cliente

# %%
hb = HomeBroker(ByMA_id)
hb.auth.login(dni, user, password, raise_exception=True)
# Connect to the server
hb.online.connect()

# %% [markdown]
# #### c) Obtengo una 'foto'-snapshot del mercado [diccionario]

# %%
snapshot = hb.online.get_market_snapshot()
snapshot

# %%
panel_opciones = snapshot['options']
panel_merval = snapshot['bluechips']
panel_general = snapshot['general_board']
panel_cedears = snapshot['cedears']

# %%
panel_cedears

# %%
panel_opciones

# %% [markdown]
# #### d) Limpiando el dataset

# %%
# Le agrego columnas nuevas
panel_opciones['Spot'] = 0.0 
panel_opciones['TTM']=0
panel_opciones['Moneyness']=0.0

# %%
#Genero la columna TTM
hoy = datetime.datetime.today()
      
#Codigo para obtener el TTM
x= (panel_opciones['expiration'] - hoy).values        
days = x.astype('timedelta64[D]')
ttm_f = (days+1) / np.timedelta64(1, 'D')
       
panel_opciones['TTM'] = ttm_f.astype(np.int64)

panel_opciones

# %%
# Renombro las columnas, renombro el tipo Call/Put, reordeno y me quedo solo con las columnas que quiero
panel_opciones = panel_opciones.reset_index()
panel_opciones = panel_opciones.rename(
            columns={'symbol':'Especie','underlying_asset':'Ticker', 'kind': 'CallPut', 'last': 'Last', 'strike': 'Strike','previous_close':'Close'}, inplace=False)
       
panel_opciones['CallPut'] = pd.Series(panel_opciones['CallPut']).str.replace('CALL', 'C', regex=True)
panel_opciones['CallPut'] = pd.Series(panel_opciones['CallPut']).str.replace('PUT', 'P', regex=True)
       
panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])
panel_opciones = panel_opciones[
            ['Especie','Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Close','Moneyness']]

# %%
#Limpieza final
#Saco las Nan
panel_opciones = panel_opciones[pd.notna(panel_opciones.Last)]
# saco la columna indice vieja
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']

# %%
# Agrego el spot y el moneyness
# get_spot_from_ticker es un metodo propio

for fila in range(len(panel_opciones.Especie.values)):
    ticker_ = panel_opciones.Ticker.values[fila]
    panel_opciones['Spot'].values[fila] = get_spot_from_ticker(ticker_,snapshot)
        
panel_opciones['Moneyness']= panel_opciones['Spot'] / panel_opciones['Strike']

panel_opciones

# %%
#Limpieza final
#Saco las Nan
panel_opciones = panel_opciones[pd.notna(panel_opciones.Last)]
# saco la columna indice vieja
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']

# %%
panel_opciones

# %%
# SI solamente quiero un ticker

panel_opciones_ggal = panel_opciones[panel_opciones.Ticker == 'GGAL']

panel_opciones_ggal = panel_opciones_ggal.reset_index()
del panel_opciones_ggal['index']
panel_opciones_ggal

# %% [markdown]
# ## (4) Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# BYMA


panel_opciones_ggal_byma_limpio = obtener_panel_opciones_byma('GGAL', True)

TTMs = list(set(panel_opciones_ggal_byma_limpio.TTM.values))
TTMs

# %%
# El vencimiento mas liquido
TTM = TTMs[1]

panel_opciones_ggal_byma_limpio[(panel_opciones_ggal_byma_limpio.TTM == TTM)].head(20)

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs:
    Ks = panel_opciones_ggal_byma_limpio[(panel_opciones_ggal_byma_limpio.TTM == TTM) & (panel_opciones_ggal_byma_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_byma_limpio[(panel_opciones_ggal_byma_limpio.TTM == TTM) & (panel_opciones_ggal_byma_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs:
    Ks = panel_opciones_ggal_byma_limpio[(panel_opciones_ggal_byma_limpio.TTM == TTM) & (panel_opciones_ggal_byma_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_byma_limpio[(panel_opciones_ggal_byma_limpio.TTM == TTM) & (panel_opciones_ggal_byma_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
Ks = list(set(panel_opciones_ggal_byma_limpio.Strike.values))

Ks[0:2]

# %%
CP = "C"
for K in Ks:
    TTMs = panel_opciones_ggal_byma_limpio[(panel_opciones_ggal_byma_limpio.Strike == K) & (panel_opciones_ggal_byma_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_ggal_byma_limpio[(panel_opciones_ggal_byma_limpio.Strike == K) & (panel_opciones_ggal_byma_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()
panel_opciones_ggal_byma_limpio[(panel_opciones_ggal_byma_limpio.Strike == K) & (panel_opciones_ggal_byma_limpio.CallPut == CP)].Last.values

# %% [markdown]
# ## (5) Pasar a Excel/CSV

# %%
panel_opciones_byma_crudo = web_scraping_opciones_rava()
panel_opciones_byma_crudo.to_excel('Clase_1_panel_opciones_byma_crudo.xls')

panel_acciones_byma = obtener_panel_acciones()
panel_acciones_byma.to_excel('Clase_1_panel_acciones.xls')

panel_opciones_byma = obtener_panel_opciones_byma('', False)
panel_opciones_byma.to_excel('Clase_1_panel_opciones_byma.xls')

panel_opciones_byma_limpio = obtener_panel_opciones_byma('', True)
panel_opciones_byma_limpio.to_excel('Clase_1_panel_opciones_byma_limpio.xls')
panel_opciones_byma_limpio = obtener_panel_opciones_byma('', True)
panel_opciones_byma.to_excel('Clase_1_panel_opciones_byma.xls')
panel_opciones_byma_limpio.to_excel('Clase_1_panel_opciones_byma_limpio.xls')

# %% [markdown]
# ## (6) Comparando los paneles

# %%
panel_opciones_ggal_rava_limpio = obtener_panel_opciones_byma('GGAL',True)

# %%
panel_opciones_ggal_homebroker_limpio = panel_opciones_homebroker(personal_data, 'GGAL', True)

# %%
panel_opciones_ggal_rava_limpio

# %%
panel_opciones_ggal_homebroker_limpio

# %%
# Inner es la interseccion
# Outer es la union

merged = pd.merge(panel_opciones_ggal_rava_limpio, panel_opciones_ggal_homebroker_limpio, on=["Especie", "Ticker", "CallPut", "Strike", "TTM"], how='inner')

merged = merged.rename(
            columns={'Spot_x':'Spot_rava','Spot_y':'Spot_HB', 'Last_x': 'Last_rava', 'Last_y': 'Last_HB', 'Close_x': 'Close_rava', 'Close_y': 'Close_HB','previous_close':'Close'}, inplace=False)
       
merged = merged[
            ['Especie','Ticker', 'Spot_rava', 'Spot_HB', 'CallPut', 'Strike', 'TTM', 'Last_rava', 'Last_HB','Close_rava','Close_HB']]


merged

# %% [markdown]
# Genero algunas columnas de diferencias

# %%
merged['Dif_spot']=merged['Spot_rava']-merged['Spot_HB']
merged['Dif_last']=merged['Last_rava']-merged['Last_HB']
merged['Dif_close']=merged['Close_rava']-merged['Close_HB']

merged
