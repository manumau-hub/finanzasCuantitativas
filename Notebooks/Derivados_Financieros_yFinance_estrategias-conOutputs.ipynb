# %% [markdown]
# # Derivados Financieros 2023 [previa a la clase 3]

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance
# ## 2) Plots
# ## 3) Payoffs - Estraegias

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.27-py2.py3-none-any.whl (63 kB)
#      -------------------------------------- 63.2/63.2 kB 242.8 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in c:\users\manue\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\manue\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\manue\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Collecting pytz>=2022.5
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      -------------------------------------- 502.3/502.3 kB 1.2 MB/s eta 0:00:00
# Collecting html5lib>=1.1
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.8-cp39-cp39-win_amd64.whl (35 kB)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\manue\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\manue\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Collecting requests>=2.31
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.6/62.6 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in c:\users\manue\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\manue\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\manue\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\manue\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manue\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2022.9.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\manue\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manue\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manue\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.11)
# Installing collected packages: pytz, multitasking, requests, html5lib, frozendict, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# Successfully installed frozendict-2.3.8 html5lib-1.1 multitasking-0.0.11 pytz-2023.3 requests-2.31.0 yfinance-0.2.27
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.20 requires requests==2.28.1, but you have requests 2.31.0 which is incompatible.

# %%
### Importo los modulos
import sys
sys.path.append('..')
from Codigo.data_nyse import *

import yfinance as yf
import datetime

# %% [markdown]
# ## API Yahoo finance

# %% [markdown]
# Modulos necesarios
#
# data_nyse (en webcampus) ;
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# yfinance, (yfinance-0.1.63 - tuve que actualizar reicentemente)
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install
#
#
# urllib.requestatexit
# datetime
# dateutil
#
# import tda
# json
# selenium, webdriver

# %% [markdown]
# ## Queremos emular lo que hicimos para BYMA

# %%
### Metodo para el web scraping
panel_yahoo_GGAL = obtener_opciones_yahoo_finance('GGAL')
panel_yahoo_GGAL
# Out:
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
#          contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0   GGAL230818C00012500 2023-07-28 18:45:49+00:00    12.5       4.60  4.00
# 1   GGAL230818C00015000 2023-08-03 16:11:25+00:00    15.0       1.90  2.05
# 2   GGAL230818C00017500 2023-08-04 17:06:41+00:00    17.5       1.15  0.95
# 3   GGAL230818C00020000 2023-08-04 18:55:41+00:00    20.0       0.40  0.35
# 4   GGAL230818C00022500 2023-08-03 14:34:06+00:00    22.5       0.19  0.05
# ..                  ...                       ...     ...        ...   ...
# 5   GGAL240119P00017500 2023-07-17 16:55:25+00:00    17.5       3.50  3.70
# 6   GGAL240119P00020000 2023-08-01 15:24:02+00:00    20.0       5.20  5.30
# 7   GGAL240119P00022500 2023-08-03 14:30:27+00:00    22.5       7.70  7.00
# 0   GGAL240719P00015000 2023-08-01 13:52:32+00:00    15.0       3.00  2.95
# 1   GGAL240719P00017500 2023-07-17 16:58:55+00:00    17.5       4.00  4.30
#
#      ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0   5.70    0.00       0.000000     1.0            17           2.212895
# 1   2.35    0.00       0.000000     6.0           281           1.166020
# 2   1.20    0.35      43.749992    42.0           508           1.201176
# 3   0.55    0.03       8.108109   243.0          1052           1.191410
# 4   0.30    0.00       0.000000    15.0           273           1.191410
# ..   ...     ...            ...     ...           ...                ...
# 5   4.10    0.00       0.000000    30.0           179           0.726565
# 6   6.00    0.00       0.000000     2.0            55           0.727054
# 7   8.80    0.00       0.000000     3.0           259           0.799074
# 0   3.70    0.00       0.000000    10.0            57           0.659183
# 1   5.10    0.00       0.000000    16.0           104           0.630375
#
#     inTheMoney contractSize currency Ticker   Spot
# 0         True      REGULAR      USD   GGAL  16.35
# 1         True      REGULAR      USD   GGAL  16.35
# 2        False      REGULAR      USD   GGAL  16.35
# 3        False      REGULAR      USD   GGAL  16.35
# 4        False      REGULAR      USD   GGAL  16.35
# ..         ...          ...      ...    ...    ...
# 5         True      REGULAR      USD   GGAL  16.35
# 6         True      REGULAR      USD   GGAL  16.35
# 7         True      REGULAR      USD   GGAL  16.35
# 0        False      REGULAR      USD   GGAL  16.35
# 1         True      REGULAR      USD   GGAL  16.35
#
# [63 rows x 16 columns]

# %%
panel_ociones_GGAL_nyse_clean = obtener_panel_opciones_nyse('GGAL', True)
panel_ociones_GGAL_nyse_clean
# Out:
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
#                 Especie Ticker   Spot CallPut  Strike  TTM  Last  Moneyness  \
# 0   GGAL230818P00010000   GGAL  16.35       P    10.0   13  0.05   1.635000
# 1   GGAL230818C00012500   GGAL  16.35       C    12.5   13  4.60   1.308000
# 2   GGAL230818P00012500   GGAL  16.35       P    12.5   13  0.20   1.308000
# 3   GGAL230818C00015000   GGAL  16.35       C    15.0   13  1.90   1.090000
# 4   GGAL230818P00015000   GGAL  16.35       P    15.0   13  0.85   1.090000
# ..                  ...    ...    ...     ...     ...  ...   ...        ...
# 58  GGAL240719P00015000   GGAL  16.35       P    15.0  349  3.00   1.090000
# 59  GGAL240719C00017500   GGAL  16.35       C    17.5  349  3.40   0.934286
# 60  GGAL240719P00017500   GGAL  16.35       P    17.5  349  4.00   0.934286
# 61  GGAL240719C00022500   GGAL  16.35       C    22.5  349  2.20   0.726667
# 62  GGAL240719C00030000   GGAL  16.35       C    30.0  349  1.20   0.545000
#
#     impliedVolatility   Bid   Ask
# 0            1.507815  0.00  0.15
# 1            2.212895  4.00  5.70
# 2            1.085942  0.10  0.20
# 3            1.166020  2.05  2.35
# 4            1.144536  0.70  0.95
# ..                ...   ...   ...
# 58           0.659183  2.95  3.70
# 59           0.677982  3.40  4.30
# 60           0.630375  4.30  5.10
# 61           0.682132  2.35  2.75
# 62           0.636967  0.85  1.50
#
# [63 rows x 11 columns]

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance

# %%
ticker = 'GGAL'
data = yf.Ticker(ticker)

#Data es un objeto
# data.info contiene informacion (mucha) del activo

data.info
# Out:
# {'address1': 'Teniente General Juan D. PerOn 430',
#  'address2': '25th Floor',
#  'city': 'Buenos Aires',
#  'zip': '1038',
#  'country': 'Argentina',
#  'phone': '54 11 4343 7528',
#  'fax': '54 11 4331 9183',
#  'website': 'https://www.gfgsa.com',
#  'industry': 'Banks—Regional',
#  'industryDisp': 'Banks—Regional',
#  'sector': 'Financial Services',
#  'sectorDisp': 'Финансови услуги',
#  'longBusinessSummary': 'Grupo Financiero Galicia S.A., a financial service holding company, provides various financial products and services to individuals and companies in Argentina. The company operates through Banks, NaranjaX, Insurance, and Other Businesses segments. It also offers personal loans; express and mortgage loans; pledge and credit card loans; credit and debit cards; and online banking services, as well as savings, deposits, and checking accounts related services. In addition, the company offers financing products; consumer finance and digital banking services; electronic check; global custody services; Fima funds; financial and stock market services to individuals, companies, and financial institutions; foreign trade services; and capital market and investment banking products that include debt securities, short-term securities, and financial trusts. Further, it provides robbery, personal accident, life collective, home, life, integral, pet, surety, and technical insurance products. Additionally, the company offers private banking services to high net worth individuals; and operates digital investment platform. Grupo Financiero Galicia S.A. was founded in 1905 and is based in Buenos Aires, Argentina.',
#  'fullTimeEmployees': 8742,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Fabian  Enrique Kon',
#    'title': 'GM & CEO',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Diego H. Rivas',
#    'title': 'Chief Financial & Compliance Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jose  Luis Ronsini',
#    'age': 51,
#    'title': 'Admin. Mang.',
#    'yearBorn': 1971,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Pablo  Eduardo Firvida',
#    'age': 55,
#    'title': 'Investor Relations Officer',
#    'yearBorn': 1967,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adrian  Enrique Pedemonte',
#    'title': 'Head of Market Relations',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bruno  Folino',
#    'title': 'Chief Risk Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 15.68,
#  'open': 15.84,
#  'dayLow': 15.84,
#  'dayHigh': 16.69,
#  'regularMarketPreviousClose': 15.68,
#  'regularMarketOpen': 15.84,
#  'regularMarketDayLow': 15.84,
#  'regularMarketDayHigh': 16.69,
#  'dividendRate': 0.33,
#  'dividendYield': 0.021,
#  'exDividendDate': 1690502400,
#  'payoutRatio': 0.111,
#  'beta': 2.175693,
#  'trailingPE': 13.292683,
#  'forwardPE': 3.9302888,
#  'volume': 868178,
#  'regularMarketVolume': 868178,
#  'averageVolume': 749666,
#  'averageVolume10days': 697150,
#  'averageDailyVolume10Day': 697150,
#  'bid': 16.34,
#  'ask': 16.98,
#  'bidSize': 800,
#  'askSize': 800,
#  'marketCap': 4801897472,
#  'fiftyTwoWeekLow': 7.0,
#  'fiftyTwoWeekHigh': 18.52,
#  'priceToSalesTrailing12Months': 0.006483666,
#  'fiftyDayAverage': 15.7942,
#  'twoHundredDayAverage': 11.95835,
#  'trailingAnnualDividendRate': 26.446,
#  'trailingAnnualDividendYield': 1.686607,
#  'currency': 'USD',
#  'enterpriseValue': 82018426880,
#  'profitMargins': 0.079619996,
#  'floatShares': 81175901,
#  'sharesOutstanding': 147468992,
#  'sharesShort': 1861636,
#  'sharesShortPriorMonth': 2322624,
#  'sharesShortPreviousMonthDate': 1686787200,
#  'dateShortInterest': 1689292800,
#  'sharesPercentSharesOut': 0.0126,
#  'heldPercentInsiders': 0.0,
#  'heldPercentInstitutions': 0.1205,
#  'shortRatio': 1.94,
#  'impliedSharesOutstanding': 0,
#  'bookValue': 5153.11,
#  'priceToBook': 0.0031728414,
#  'lastFiscalYearEnd': 1672444800,
#  'nextFiscalYearEnd': 1703980800,
#  'mostRecentQuarter': 1680220800,
#  'earningsQuarterlyGrowth': 0.708,
#  'netIncomeToCommon': 58971222016,
#  'trailingEps': 1.23,
#  'forwardEps': 4.16,
#  'pegRatio': -0.03,
#  'enterpriseToRevenue': 0.111,
#  '52WeekChange': 1.0260222,
#  'SandP52WeekChange': 0.081634045,
#  'lastDividendValue': 0.161,
#  'lastDividendDate': 1690502400,
#  'exchange': 'NCM',
#  'quoteType': 'EQUITY',
#  'symbol': 'GGAL',
#  'underlyingSymbol': 'GGAL',
#  'shortName': 'Grupo Financiero Galicia S.A.',
#  'longName': 'Grupo Financiero Galicia S.A.',
#  'firstTradeDateEpochUtc': 964531800,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '51f2ae62-177c-3050-9a3c-e83156e0c225',
#  'messageBoardId': 'finmb_1532718',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 16.35,
#  'targetHighPrice': 16.0,
#  'targetLowPrice': 5.01,
#  'targetMeanPrice': 8.86,
#  'targetMedianPrice': 8.1,
#  'recommendationMean': 3.4,
#  'recommendationKey': 'hold',
#  'numberOfAnalystOpinions': 5,
#  'totalCash': 368551690240,
#  'totalCashPerShare': 2499.177,
#  'totalDebt': 448158957568,
#  'totalRevenue': 740614537216,
#  'revenuePerShare': 5022.16,
#  'returnOnAssets': 0.02095,
#  'returnOnEquity': 0.10564999,
#  'grossProfits': 685854000000,
#  'operatingCashflow': -481124614144,
#  'earningsGrowth': 0.707,
#  'revenueGrowth': 0.302,
#  'grossMargins': 0.0,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': 0.11214,
#  'financialCurrency': 'ARS',
#  'trailingPegRatio': None}

# %%
# Spot price

hist = data.history()

spot = hist.tail(1)['Close'].iloc[0]
spot
# Out:
# 16.350000381469727

# %%
# Vencimientos de opciones
vencimientos = data.options

vencimientos
# Out:
# ('2023-08-18', '2023-09-15', '2023-10-20', '2024-01-19', '2024-07-19')

# %%
# Calls y puts
calls = data.option_chain(vencimientos[0])[0]
puts = data.option_chain(vencimientos[0])[1]

puts
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0  GGAL230818P00010000 2023-08-02 17:19:08+00:00    10.0       0.05  0.00
# 1  GGAL230818P00012500 2023-08-04 17:31:24+00:00    12.5       0.20  0.10
# 2  GGAL230818P00015000 2023-08-04 17:51:46+00:00    15.0       0.85  0.70
# 3  GGAL230818P00017500 2023-08-04 19:08:07+00:00    17.5       2.15  2.05
# 4  GGAL230818P00020000 2023-08-02 14:31:03+00:00    20.0       4.22  1.55
# 5  GGAL230818P00025000 2023-06-15 17:09:49+00:00    25.0       9.50  7.00
#
#      ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0   0.15    0.00       0.000000    15.0            69           1.507815
# 1   0.20   -0.05     -19.999998    19.0           368           1.085942
# 2   0.95   -0.20     -19.047613   169.0          1978           1.144536
# 3   2.25   -0.19      -8.119651    11.0           409           1.141606
# 4   4.40    0.00       0.000000     8.0             8           1.479495
# 5  11.10    0.00       0.000000     NaN            10           1.810548
#
#    inTheMoney contractSize currency
# 0       False      REGULAR      USD
# 1       False      REGULAR      USD
# 2       False      REGULAR      USD
# 3        True      REGULAR      USD
# 4        True      REGULAR      USD
# 5        True      REGULAR      USD

# %% [markdown]
# ### Que hace internamente el metodo??

# %%
#Recorro cada vencimiento disponible y voy tomando calls por un lado y puts por otro
for vencimiento in vencimientos[1:]:
        calls = calls.append(data.option_chain(vencimiento)[0])
        puts = puts.append(data.option_chain(vencimiento)[1])

#Uno los puts y los calls
panel_opciones = calls.append(puts)

# Le agrego dos columnas utiles - Ticker y Spot

panel_opciones['Spot'] = hist.tail(1)['Close'].iloc[0]
panel_opciones['Ticker'] = ticker

panel_opciones.head(10)
# Out:
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_24124\3234569746.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0  GGAL230818C00012500 2023-07-28 18:45:49+00:00    12.5       4.60  4.00
# 1  GGAL230818C00015000 2023-08-03 16:11:25+00:00    15.0       1.90  2.05
# 2  GGAL230818C00017500 2023-08-04 17:06:41+00:00    17.5       1.15  0.95
# 3  GGAL230818C00020000 2023-08-04 18:55:41+00:00    20.0       0.40  0.35
# 4  GGAL230818C00022500 2023-08-03 14:34:06+00:00    22.5       0.19  0.05
# 5  GGAL230818C00025000 2023-08-04 14:27:20+00:00    25.0       0.05  0.00
# 0  GGAL230915C00017500 2023-08-03 15:27:08+00:00    17.5       1.10  0.80
# 1  GGAL230915C00020000 2023-08-04 15:05:39+00:00    20.0       0.70  0.75
# 2  GGAL230915C00022500 2023-08-02 14:42:41+00:00    22.5       0.50  0.00
# 3  GGAL230915C00025000 2023-07-27 17:40:04+00:00    25.0       0.43  0.00
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  5.70    0.00       0.000000     1.0            17           2.212895
# 1  2.35    0.00       0.000000     6.0           281           1.166020
# 2  1.20    0.35      43.749992    42.0           508           1.201176
# 3  0.55    0.03       8.108109   243.0          1052           1.191410
# 4  0.30    0.00       0.000000    15.0           273           1.191410
# 5  0.05    0.00       0.000000   165.0          1928           1.023442
# 0  2.30    0.00       0.000000    17.0            38           0.909181
# 1  0.85   -0.04      -5.405408   477.0            28           0.879884
# 2  1.05    0.00       0.000000     1.0             3           0.953125
# 3  0.70    0.00       0.000000     NaN             1           1.005864
#
#    inTheMoney contractSize currency   Spot Ticker
# 0        True      REGULAR      USD  16.35   GGAL
# 1        True      REGULAR      USD  16.35   GGAL
# 2       False      REGULAR      USD  16.35   GGAL
# 3       False      REGULAR      USD  16.35   GGAL
# 4       False      REGULAR      USD  16.35   GGAL
# 5       False      REGULAR      USD  16.35   GGAL
# 0       False      REGULAR      USD  16.35   GGAL
# 1       False      REGULAR      USD  16.35   GGAL
# 2       False      REGULAR      USD  16.35   GGAL
# 3       False      REGULAR      USD  16.35   GGAL

# %% [markdown]
# ## Del panel de Yahoo crudo a otro con informacion customizada (igual que antes)

# %% [markdown]
# #### *) Agrego columnas utiles

# %%
panel_opciones['Moneyness'] = 0.0
panel_opciones['TTM'] = 0
panel_opciones['CallPut'] = ''
panel_opciones = panel_opciones.reset_index()

panel_opciones.head(5)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL230818C00012500 2023-07-28 18:45:49+00:00    12.5       4.60
# 1      1  GGAL230818C00015000 2023-08-03 16:11:25+00:00    15.0       1.90
# 2      2  GGAL230818C00017500 2023-08-04 17:06:41+00:00    17.5       1.15
# 3      3  GGAL230818C00020000 2023-08-04 18:55:41+00:00    20.0       0.40
# 4      4  GGAL230818C00022500 2023-08-03 14:34:06+00:00    22.5       0.19
#
#     bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  4.00  5.70    0.00       0.000000     1.0            17           2.212895
# 1  2.05  2.35    0.00       0.000000     6.0           281           1.166020
# 2  0.95  1.20    0.35      43.749992    42.0           508           1.201176
# 3  0.35  0.55    0.03       8.108109   243.0          1052           1.191410
# 4  0.05  0.30    0.00       0.000000    15.0           273           1.191410
#
#    inTheMoney contractSize currency   Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  16.35   GGAL        0.0    0
# 1        True      REGULAR      USD  16.35   GGAL        0.0    0
# 2       False      REGULAR      USD  16.35   GGAL        0.0    0
# 3       False      REGULAR      USD  16.35   GGAL        0.0    0
# 4       False      REGULAR      USD  16.35   GGAL        0.0    0

# %% [markdown]
# #### *) Recorro las filas (1ra como ejemplo)

# %%
idx = panel_opciones.index.values[0]

# %%
callput = panel_opciones.contractSymbol.values[idx][10:11]
panel_opciones['CallPut'].values[idx] = callput

# %%
year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
month = int(panel_opciones.contractSymbol.values[idx][6:8])
day = int(panel_opciones.contractSymbol.values[idx][8:10])

hoy = datetime.date.today()
expiry_datetime = datetime.date(year, month, day)
ttm = (expiry_datetime - hoy).days

panel_opciones['TTM'].values[idx] = ttm

# %%
panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(2)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL230818C00012500 2023-07-28 18:45:49+00:00    12.5        4.6
# 1      1  GGAL230818C00015000 2023-08-03 16:11:25+00:00    15.0        1.9
#
#     bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  4.00  5.70     0.0            0.0     1.0            17           2.212895
# 1  2.05  2.35     0.0            0.0     6.0           281           1.166020
#
#    inTheMoney contractSize currency   Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  16.35   GGAL      1.308   13       C
# 1        True      REGULAR      USD  16.35   GGAL      0.000    0

# %% [markdown]
# #### *) Recorro las filas (las restantes como ejemplo)

# %%
for idx in list(panel_opciones.index.values[1:]):
        year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
        month = int(panel_opciones.contractSymbol.values[idx][6:8])
        day = int(panel_opciones.contractSymbol.values[idx][8:10])
        
        hoy = datetime.date.today()
        expiry_datetime = datetime.date(year, month, day)
        ttm = (expiry_datetime - hoy).days

        panel_opciones['TTM'].values[idx] = ttm
        callput = panel_opciones.contractSymbol.values[idx][10:11]
        panel_opciones['CallPut'].values[idx] = callput
        
panel_opciones.Moneyness = panel_opciones.Spot/ panel_opciones.strike

# %%
panel_opciones.head(10)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL230818C00012500 2023-07-28 18:45:49+00:00    12.5       4.60
# 1      1  GGAL230818C00015000 2023-08-03 16:11:25+00:00    15.0       1.90
# 2      2  GGAL230818C00017500 2023-08-04 17:06:41+00:00    17.5       1.15
# 3      3  GGAL230818C00020000 2023-08-04 18:55:41+00:00    20.0       0.40
# 4      4  GGAL230818C00022500 2023-08-03 14:34:06+00:00    22.5       0.19
# 5      5  GGAL230818C00025000 2023-08-04 14:27:20+00:00    25.0       0.05
# 6      0  GGAL230915C00017500 2023-08-03 15:27:08+00:00    17.5       1.10
# 7      1  GGAL230915C00020000 2023-08-04 15:05:39+00:00    20.0       0.70
# 8      2  GGAL230915C00022500 2023-08-02 14:42:41+00:00    22.5       0.50
# 9      3  GGAL230915C00025000 2023-07-27 17:40:04+00:00    25.0       0.43
#
#     bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  4.00  5.70    0.00       0.000000     1.0            17           2.212895
# 1  2.05  2.35    0.00       0.000000     6.0           281           1.166020
# 2  0.95  1.20    0.35      43.749992    42.0           508           1.201176
# 3  0.35  0.55    0.03       8.108109   243.0          1052           1.191410
# 4  0.05  0.30    0.00       0.000000    15.0           273           1.191410
# 5  0.00  0.05    0.00       0.000000   165.0          1928           1.023442
# 6  0.80  2.30    0.00       0.000000    17.0            38           0.909181
# 7  0.75  0.85   -0.04      -5.405408   477.0            28           0.879884
# 8  0.00  1.05    0.00       0.000000     1.0             3           0.953125
# 9  0.00  0.70    0.00       0.000000     NaN             1           1.005864
#
#    inTheMoney contractSize currency   Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  16.35   GGAL   1.308000   13       C
# 1        True      REGULAR      USD  16.35   GGAL   1.090000   13       C
# 2       False      REGULAR      USD  16.35   GGAL   0.934286   13       C
# 3       False      REGULAR      USD  16.35   GGAL   0.817500   13       C
# 4       False      REGULAR      USD  16.35   GGAL   0.726667   13       C
# 5       False      REGULAR      USD  16.35   GGAL   0.654000   13       C
# 6       False      REGULAR      USD  16.35   GGAL   0.934286   41       C
# 7       False      REGULAR      USD  16.35   GGAL   0.817500   41       C
# 8       False      REGULAR      USD  16.35   GGAL   0.726667   41       C
# 9       False      REGULAR      USD  16.35   GGAL   0.654000   41       C

# %% [markdown]
# #### Panel Limpio

# %%
panel_opciones = panel_opciones.rename(
            columns={'lastTradeDate': 'Last_Date', 'contractSymbol': 'Especie', 'strike': 'Strike', 'bid': 'Bid',
                     'ask': 'Ask', 'lastPrice': 'Last'}, inplace=False)

panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])

panel_opciones = panel_opciones[['Especie', 'Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Bid','Ask','impliedVolatility','Moneyness']]

# %%
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']
panel_opciones
# Out:
#                 Especie Ticker   Spot CallPut  Strike  TTM  Last   Bid   Ask  \
# 0   GGAL230818P00010000   GGAL  16.35       P    10.0   13  0.05  0.00  0.15
# 1   GGAL230818C00012500   GGAL  16.35       C    12.5   13  4.60  4.00  5.70
# 2   GGAL230818P00012500   GGAL  16.35       P    12.5   13  0.20  0.10  0.20
# 3   GGAL230818C00015000   GGAL  16.35       C    15.0   13  1.90  2.05  2.35
# 4   GGAL230818P00015000   GGAL  16.35       P    15.0   13  0.85  0.70  0.95
# ..                  ...    ...    ...     ...     ...  ...   ...   ...   ...
# 58  GGAL240719P00015000   GGAL  16.35       P    15.0  349  3.00  2.95  3.70
# 59  GGAL240719C00017500   GGAL  16.35       C    17.5  349  3.40  3.40  4.30
# 60  GGAL240719P00017500   GGAL  16.35       P    17.5  349  4.00  4.30  5.10
# 61  GGAL240719C00022500   GGAL  16.35       C    22.5  349  2.20  2.35  2.75
# 62  GGAL240719C00030000   GGAL  16.35       C    30.0  349  1.20  0.85  1.50
#
#     impliedVolatility  Moneyness
# 0            1.507815   1.635000
# 1            2.212895   1.308000
# 2            1.085942   1.308000
# 3            1.166020   1.090000
# 4            1.144536   1.090000
# ..                ...        ...
# 58           0.659183   1.090000
# 59           0.677982   0.934286
# 60           0.630375   0.934286
# 61           0.682132   0.726667
# 62           0.636967   0.545000
#
# [63 rows x 11 columns]

# %% [markdown]
# ## 2) Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# NYSE
panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)

TTMs = list(set(panel_opciones_ggal_nyse_limpio.TTM.values))
TTMs
# Out:
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# [167, 41, 76, 13, 349]

# %%
TTM = 8
panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == "C")].head(10)
# Out:
# Empty DataFrame
# Columns: [Especie, Ticker, Spot, CallPut, Strike, TTM, Last, Moneyness, impliedVolatility, Bid, Ask]
# Index: []

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    ## Last VS (B+A)/2
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %% [markdown]
# ### Para cada strike, grafico los TTM

# %%
Ks = list(set(panel_opciones_ggal_nyse_limpio.Strike.values))

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks:
    TTMs = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Ploteando los datos con un ticker mega liquido

# %%
# NYSE AAPL
ticker = 'TSLA'
panel_opciones_nyse_limpio = obtener_panel_opciones_nyse(ticker, True)

TTMs = list(set(panel_opciones_nyse_limpio.TTM.values))
TTMs.sort()
TTMs
# Out:
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# [6, 13, 20, 27, 34, 41, 76, 104, 132, 167, 223, 321, 412, 531, 685, 867]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[8:11]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[3:6]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[10:15]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[11:17]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
Ks = list(set(panel_opciones_nyse_limpio.Strike.values))
Ks.sort()
len(Ks)
# Out:
# 366

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[45:55]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for K in Ks[100:]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Pasar a Excel

# %%
panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')

panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')


panel_opciones_aapl_nyse_limpio = obtener_panel_opciones_nyse('AAPL', True)
panel_opciones_aapl_nyse_limpio.to_excel('Clase_2_panel_opciones_aapl_nyse_limpio.xls')
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# C:\Users\manue\AppData\Local\Temp\ipykernel_7248\891834467.py:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase2.ipynb Cell 54 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y102sZmlsZQ%3D%3D?line=3'>4</a> panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y102sZmlsZQ%3D%3D?line=4'>5</a> panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\formats\excel.py:888, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884     need_save = False
#     885 else:
#     886     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888     writer = ExcelWriter(  # type: ignore[abstract]
#     889         writer, engine=engine, storage_options=storage_options
#     890     )
#     891     need_save = True
#     893 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\excel\_xlwt.py:39, in XlwtWriter.__init__(self, path, engine, date_format, datetime_format, encoding, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      25 def __init__(
#      26     self,
#      27     path,
#    (...)
#      37 ):
#      38     # Use the xlwt module as the Excel writer.
# ---> 39     import xlwt
#      41     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      43     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlwt'

# %% [markdown]
# ## 3) Payoffs y Estrategias

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Vanilla Call y Put

# %%
def payoff_call(S,K):
    return np.maximum(S-K,0)

def payoff_put(S,K):
    return np.maximum(K-S,0)

# %%
K=50
S = np.linspace(0,100,50)

# %%
#Grafico la call

plt.plot(S,payoff_call(S, K))
plt.show()

# %%
#Grafico la put
plt.plot(S,payoff_put(S, K))
plt.show()

# %% [markdown]
# ### Forward sintetico y Combo

# %%
def payoff_forwardSintetico(S,K):
    return payoff_call(S,K)-payoff_put(S, K)

def payoff_combo(S,K1,K2):
    return payoff_call(S,K2)-payoff_put(S, K1)

# %%
#Grafico el forward sintetico
plt.plot(S,payoff_forwardSintetico(S, K))
plt.show()

# %%
K1 = 35
K2 = 65

# %%
#Grafico el combo
plt.plot(S,payoff_combo(S, K1,K2))
plt.show()

# %% [markdown]
# ### Spreads

# %%
def payoff_BullCS(S,K1,K2):
    return payoff_call(S,K1)-payoff_call(S, K2)

def payoff_BearCS(S,K1,K2):
    return payoff_call(S,K2)-payoff_call(S, K1)

def payoff_BullPS(S,K1,K2):
    return payoff_put(S,K1)-payoff_put(S, K2)


def payoff_BearPS(S,K1,K2):
    return payoff_put(S,K2)-payoff_put(S, K1)

# %%
#Grafico el Bull Call Spread
plt.plot(S,payoff_BullCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Call Spread
plt.plot(S,payoff_BearCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bull Put Spread
plt.plot(S,payoff_BullPS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Put Spread
plt.plot(S,payoff_BearPS(S, K1, K2))
plt.show()

# %% [markdown]
# ### Butterfly spreads

# %%
def payoff_CButterflyS(S,K1,K2,K3):
    return payoff_call(S,K1)-2*payoff_call(S, K2)+payoff_call(S, K3)

def payoff_PButterflyS(S,K1,K2,K3):
    return payoff_put(S,K1)-2*payoff_put(S, K2)+payoff_put(S, K3)

# %%
K1=35
K2=50
K3=65

# %%
#Grafico el Call Buterfly Spread
plt.plot(S,payoff_CButterflyS(S, K1, K2,K3))
plt.show()

# %%
#Grafico el Put Buterfly Spread
plt.plot(S,payoff_PButterflyS(S, K1, K2,K3))
plt.show()

# %% [markdown]
# ### Straddle y Strangle

# %%
def payoff_straddle(S,K):
    return payoff_call(S,K)+payoff_put(S, K)


def payoff_strangle(S,K1,K2):
    return payoff_call(S,K1)+payoff_put(S, K2)

# %%
K1 = 35
K2 = 65

# %%
#Grafico el Strangle
plt.plot(S,payoff_strangle(S, K1,K2))
plt.show()

# %%
#Grafico el Straddle

plt.plot(S,payoff_straddle(S, K))
plt.show()

# %% [markdown]
# ### Estrategia AD hoc - Iron Condor

# %%
def payoff_iron_condor(S,K1,K2,K3,K4):
    return payoff_put(S,K1)-payoff_put(S, K2)-payoff_call(S,K3)+payoff_call(S,K4)

# %%
K1 = 30
K2 = 45
K3 = 55
K4 = 70

# %%
plt.plot(S,payoff_iron_condor(S, K1,K2,K3,K4))
plt.show()
