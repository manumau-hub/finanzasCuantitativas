# %% [markdown]
# # Derivados Financieros 2022 - Clase 2

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance
# ## 2) Plots
# ## 3) Payoffs - Estraegias

# %%
### Importo los modulos
import sys
sys.path.append('..')
from Codigo.data_nyse import *

import yfinance as yf
import datetime

# %% [markdown]
# ## API Yahoo finance

# %% [markdown]
# Modulos necesarios
#
# data_nyse (en webcampus) ;
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# yfinance, (yfinance-0.1.63 - tuve que actualizar reicentemente)
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install
#
#
# urllib.requestatexit
# datetime
# dateutil
#
# import tda
# json
# selenium, webdriver

# %% [markdown]
# ## Queremos emular lo que hicimos para BYMA

# %%
### Metodo para el web scraping
panel_yahoo_GGAL = obtener_opciones_yahoo_finance('GGAL')
panel_yahoo_GGAL
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   panel_opciones = calls.append(puts)
#         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0  GGAL220916C00005000 2022-08-04 16:37:48+00:00     5.0       2.76   2.95
# 1  GGAL220916C00007500 2022-08-24 19:13:34+00:00     7.5       1.20   1.00
# 2  GGAL220916C00010000 2022-08-23 18:32:10+00:00    10.0       0.05   0.00
# 0  GGAL221021C00005000 2022-07-29 19:03:30+00:00     5.0       3.00   3.10
# 1  GGAL221021C00007500 2022-08-24 19:04:09+00:00     7.5       1.30   0.70
# 2  GGAL221021C00010000 2022-08-24 18:14:33+00:00    10.0       0.20   0.20
# 3  GGAL221021C00012500 2022-07-29 14:46:00+00:00    12.5       0.05   0.00
# 4  GGAL221021C00015000 2022-08-08 15:23:35+00:00    15.0       0.05   0.00
# 5  GGAL221021C00017500 2022-04-04 16:46:19+00:00    17.5       0.34   0.00
# 0  GGAL230120C00002500 2021-11-03 15:23:48+00:00     2.5       8.90   4.50
# 1  GGAL230120C00005000 2022-08-18 15:58:34+00:00     5.0       3.32   3.20
# 2  GGAL230120C00007500 2022-08-18 16:33:53+00:00     7.5       1.35   1.05
# 3  GGAL230120C00010000 2022-08-23 18:21:13+00:00    10.0       0.51   0.55
# 4  GGAL230120C00012500 2022-08-24 15:22:54+00:00    12.5       0.17   0.05
# 5  GGAL230120C00015000 2022-07-27 19:41:31+00:00    15.0       0.08   0.00
# 6  GGAL230120C00017500 2022-07-08 14:32:36+00:00    17.5       0.15   0.00
# 7  GGAL230120C00020000 2022-05-25 16:02:22+00:00    20.0       0.05   0.00
# 8  GGAL230120C00022500 2022-03-09 18:38:57+00:00    22.5       0.20   0.05
# 0  GGAL230421C00010000 2022-08-22 17:41:31+00:00    10.0       0.80   0.10
# 0  GGAL240119C00002500 2022-06-15 17:32:18+00:00     2.5       5.50   1.50
# 1  GGAL240119C00005000 2022-08-23 17:50:41+00:00     5.0       4.10   3.50
# 2  GGAL240119C00007500 2022-08-23 17:39:47+00:00     7.5       2.55   1.85
# 3  GGAL240119C00010000 2022-08-11 17:35:43+00:00    10.0       1.40   0.10
# 4  GGAL240119C00012500 2022-08-24 17:55:31+00:00    12.5       1.05   0.50
# 5  GGAL240119C00015000 2022-08-24 15:23:57+00:00    15.0       0.60   0.70
# 6  GGAL240119C00017500 2022-08-24 17:55:31+00:00    17.5       0.50   0.10
# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance

# %%
ticker = 'GGAL'
data = yf.Ticker(ticker)

#Data es un objeto
# data.info contiene informacion (mucha) del activo

data.info
# Out:
# {'zip': '1038',
#  'sector': 'Financial Services',
#  'longBusinessSummary': "Grupo Financiero Galicia S.A., a financial service holding company, provides various financial products and services to individuals and companies in Argentina. The company operates through Banks, NaranjaX, Insurance, and Other Businesses segments. The company's products and services cover savings, current, and checking accounts; personal loans; express and mortgage loans; pledge and credit card loans; credit and debit cards; and online banking services. It also offers financing products and services; consumer finance services; electronic check; global custody services; Fima funds; financial and stock market services to individuals, companies, and financial institutions; foreign trade services; and capital market and investment banking products that include debt securities, short-term securities, bills, and financial trusts. In addition, the company provides robbery, personal accident, life collective, home, life, integral pyme, pet, surety, various risks, and technical insurance products. Further, it offers private banking services to high net worth individuals; and operates digital investment platform. As of December 31, 2021, it had 312 full service banking branches; and 1,991 ATMs and self-service terminals. Grupo Financiero Galicia S.A. was founded in 1905 and is based in Buenos Aires, Argentina.",
#  'city': 'Buenos Aires',
#  'phone': '54 11 4343 7528',
#  'country': 'Argentina',
#  'companyOfficers': [],
#  'website': 'https://www.gfgsa.com',
#  'maxAge': 1,
#  'address1': 'Teniente General Juan D. PerOn 430',
#  'fax': '54 11 4331 9183',
#  'industry': 'Banks—Regional',
#  'address2': '25th Floor',
#  'ebitdaMargins': 0,
#  'profitMargins': 0.11454,
#  'grossMargins': 0,
#  'operatingCashflow': 116351680512,
#  'revenueGrowth': 0.176,
#  'operatingMargins': 0.17093,
#  'ebitda': None,
#  'targetLowPrice': 5,
#  'recommendationKey': 'hold',
#  'grossProfits': 282178293000,
#  'freeCashflow': None,
#  'targetMedianPrice': 8.3,
#  'currentPrice': 8.55,
#  'earningsGrowth': 0.559,
#  'currentRatio': None,
#  'returnOnAssets': 0.02318,
#  'numberOfAnalystOpinions': 4,
#  'targetMeanPrice': 10.73,
#  'debtToEquity': None,
#  'returnOnEquity': 0.123859994,
#  'targetHighPrice': 21.3,
#  'totalCash': 408549457920,
#  'totalDebt': 229529108480,
#  'totalRevenue': 303785869312,
#  'totalCashPerShare': 2770.405,
#  'financialCurrency': 'ARS',
#  'revenuePerShare': 2060,
#  'quickRatio': None,
#  'recommendationMean': 3.5,
#  'exchange': 'NCM',
#  'shortName': 'Grupo Financiero Galicia S.A.',
#  'longName': 'Grupo Financiero Galicia S.A.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'GGAL',
#  'messageBoardId': 'finmb_1532718',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': -0.585,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': -0.16403162,
#  'morningStarRiskRating': None,
#  'forwardEps': 3.49,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 147468992,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 2417.23,
#  'sharesShort': 1782689,
#  'sharesPercentSharesOut': 0.0121,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.09844,
#  'netIncomeToCommon': 34796187648,
#  'trailingEps': 1.62,
#  'lastDividendValue': 0.36,
#  'SandP52WeekChange': -0.08172697,
#  'priceToBook': 0.0035371066,
#  'heldPercentInsiders': 0.12866999,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1648684800,
#  'shortRatio': 2.17,
#  'sharesShortPreviousMonthDate': 1656547200,
#  'floatShares': 81296826,
#  'beta': 2.580341,
#  'enterpriseValue': -177772756992,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': 1652400000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.561,
#  'priceToSalesTrailing12Months': 0.004150489,
#  'dateShortInterest': 1659052800,
#  'pegRatio': -0.06,
#  'ytdReturn': None,
#  'forwardPE': 2.4498568,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 1065502,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 8.46,
#  'regularMarketOpen': 8.4,
#  'twoHundredDayAverage': 9.03535,
#  'trailingAnnualDividendYield': 0.8816785,
#  'payoutRatio': 0.028900001,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 8.59,
#  'navPrice': None,
#  'averageDailyVolume10Day': 509070,
#  'regularMarketPreviousClose': 8.46,
#  'fiftyDayAverage': 7.231,
#  'trailingAnnualDividendRate': 7.459,
#  'open': 8.4,
#  'toCurrency': None,
#  'averageVolume10days': 509070,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': 1620950400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 8.12,
#  'currency': 'USD',
#  'trailingPE': 5.2777777,
#  'regularMarketVolume': 954233,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1260859904,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 696409,
#  'dayLow': 8.12,
#  'ask': 8.6,
#  'askSize': 800,
#  'volume': 954233,
#  'fiftyTwoWeekHigh': 12.75,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 5.75,
#  'bid': 8.35,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 1200,
#  'dayHigh': 8.59,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 8.55,
#  'preMarketPrice': 8.46,
#  'logo_url': 'https://logo.clearbit.com/gfgsa.com'}

# %%
# Spot price

hist = data.history()

spot = hist.tail(1)['Close'].iloc[0]
spot
# Out:
# 8.550000190734863

# %%
# Vencimientos de opciones
vencimientos = data.options

vencimientos
# Out:
# ('2022-09-16', '2022-10-21', '2023-01-20', '2023-04-21', '2024-01-19')

# %%
# Calls y puts
calls = data.option_chain(vencimientos[0])[0]
puts = data.option_chain(vencimientos[0])[1]

puts
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0  GGAL220916P00005000 2022-07-20 18:36:18+00:00     5.0       0.17  0.00
# 1  GGAL220916P00007500 2022-08-19 19:58:08+00:00     7.5       0.33  0.05
# 2  GGAL220916P00010000 2022-07-20 16:28:48+00:00    10.0       4.00  1.40
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  0.40     0.0            0.0     NaN             1           1.859376
# 1  0.75     0.0            0.0    55.0           138           1.003911
# 2  3.00     0.0            0.0    11.0             0           1.437503
#
#    inTheMoney contractSize currency
# 0       False      REGULAR      USD
# 1       False      REGULAR      USD
# 2        True      REGULAR      USD

# %% [markdown]
# ### Que hace internamente el metodo??

# %%
#Recorro cada vencimiento disponible y voy tomando calls por un lado y puts por otro
for vencimiento in vencimientos[1:]:
        calls = calls.append(data.option_chain(vencimiento)[0])
        puts = puts.append(data.option_chain(vencimiento)[1])

#Uno los puts y los calls
panel_opciones = calls.append(puts)

# Le agrego dos columnas utiles - Ticker y Spot

panel_opciones['Spot'] = hist.tail(1)['Close'].iloc[0]
panel_opciones['Ticker'] = ticker

panel_opciones.head(10)
# Out:
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:4: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\3234569746.py:7: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   panel_opciones = calls.append(puts)
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0  GGAL220916C00005000 2022-08-04 16:37:48+00:00     5.0       2.76  2.95
# 1  GGAL220916C00007500 2022-08-24 19:13:34+00:00     7.5       1.20  1.00
# 2  GGAL220916C00010000 2022-08-23 18:32:10+00:00    10.0       0.05  0.00
# 0  GGAL221021C00005000 2022-07-29 19:03:30+00:00     5.0       3.00  3.10
# 1  GGAL221021C00007500 2022-08-24 19:04:09+00:00     7.5       1.30  0.70
# 2  GGAL221021C00010000 2022-08-24 18:14:33+00:00    10.0       0.20  0.20
# 3  GGAL221021C00012500 2022-07-29 14:46:00+00:00    12.5       0.05  0.00
# 4  GGAL221021C00015000 2022-08-08 15:23:35+00:00    15.0       0.05  0.00
# 5  GGAL221021C00017500 2022-04-04 16:46:19+00:00    17.5       0.34  0.00
# 0  GGAL230120C00002500 2021-11-03 15:23:48+00:00     2.5       8.90  4.50
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  3.70    0.00       0.000000     8.0          10.0           1.707033
# 1  1.40    0.25      26.315796    33.0         171.0           0.625004
# 2  0.10    0.00       0.000000     3.0          73.0           0.574223
# 0  3.80    0.00       0.000000     2.0           1.0           1.273441
# 1  1.60    0.10       8.333325    14.0         388.0           0.771487
# 2  0.40    0.00       0.000000   216.0         401.0           0.560551
# 3  0.50    0.00       0.000000    35.0        1033.0           0.867189
# 4  0.75    0.00       0.000000    30.0        1276.0           1.255863
# 5  0.45    0.00       0.000000     6.0          21.0           1.273441
# 0  9.50    0.00       0.000000    20.0           3.0           2.759769
#
#    inTheMoney contractSize currency  Spot Ticker
# 0         1.0      REGULAR      USD  8.55   GGAL
# 1         1.0      REGULAR      USD  8.55   GGAL
# 2         0.0      REGULAR      USD  8.55   GGAL
# 0         1.0      REGULAR      USD  8.55   GGAL
# 1         1.0      REGULAR      USD  8.55   GGAL
# 2         0.0      REGULAR      USD  8.55   GGAL
# 3         0.0      REGULAR      USD  8.55   GGAL
# 4         0.0      REGULAR      USD  8.55   GGAL
# 5         0.0      REGULAR      USD  8.55   GGAL
# 0         1.0      REGULAR      USD  8.55   GGAL

# %% [markdown]
# ## Del panel de Yahoo crudo a otro con informacion customizada (igual que antes)

# %% [markdown]
# #### *) Agrego columnas utiles

# %%
panel_opciones['Moneyness'] = 0.0
panel_opciones['TTM'] = 0
panel_opciones['CallPut'] = ''
panel_opciones = panel_opciones.reset_index()

panel_opciones.head(5)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220916C00005000 2022-08-04 16:37:48+00:00     5.0       2.76
# 1      1  GGAL220916C00007500 2022-08-24 19:13:34+00:00     7.5       1.20
# 2      2  GGAL220916C00010000 2022-08-23 18:32:10+00:00    10.0       0.05
# 3      0  GGAL221021C00005000 2022-07-29 19:03:30+00:00     5.0       3.00
# 4      1  GGAL221021C00007500 2022-08-24 19:04:09+00:00     7.5       1.30
#
#     bid  ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  2.95  3.7    0.00       0.000000     8.0          10.0           1.707033
# 1  1.00  1.4    0.25      26.315796    33.0         171.0           0.625004
# 2  0.00  0.1    0.00       0.000000     3.0          73.0           0.574223
# 3  3.10  3.8    0.00       0.000000     2.0           1.0           1.273441
# 4  0.70  1.6    0.10       8.333325    14.0         388.0           0.771487
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0         1.0      REGULAR      USD  8.55   GGAL        0.0    0
# 1         1.0      REGULAR      USD  8.55   GGAL        0.0    0
# 2         0.0      REGULAR      USD  8.55   GGAL        0.0    0
# 3         1.0      REGULAR      USD  8.55   GGAL        0.0    0
# 4         1.0      REGULAR      USD  8.55   GGAL        0.0    0

# %% [markdown]
# #### *) Recorro las filas (1ra como ejemplo)

# %%
idx = panel_opciones.index.values[0]

# %%
callput = panel_opciones.contractSymbol.values[idx][10:11]
panel_opciones['CallPut'].values[idx] = callput

# %%
year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
month = int(panel_opciones.contractSymbol.values[idx][6:8])
day = int(panel_opciones.contractSymbol.values[idx][8:10])

hoy = datetime.date.today()
expiry_datetime = datetime.date(year, month, day)
ttm = (expiry_datetime - hoy).days

panel_opciones['TTM'].values[idx] = ttm

# %%
panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(2)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220916C00005000 2022-08-04 16:37:48+00:00     5.0       2.76
# 1      1  GGAL220916C00007500 2022-08-24 19:13:34+00:00     7.5       1.20
#
#     bid  ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  2.95  3.7    0.00       0.000000     8.0          10.0           1.707033
# 1  1.00  1.4    0.25      26.315796    33.0         171.0           0.625004
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0         1.0      REGULAR      USD  8.55   GGAL       1.71   23       C
# 1         1.0      REGULAR      USD  8.55   GGAL       0.00    0

# %% [markdown]
# #### *) Recorro las filas (las restantes como ejemplo)

# %%
for idx in list(panel_opciones.index.values[1:]):
        year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
        month = int(panel_opciones.contractSymbol.values[idx][6:8])
        day = int(panel_opciones.contractSymbol.values[idx][8:10])
        
        hoy = datetime.date.today()
        expiry_datetime = datetime.date(year, month, day)
        ttm = (expiry_datetime - hoy).days

        panel_opciones['TTM'].values[idx] = ttm
        callput = panel_opciones.contractSymbol.values[idx][10:11]
        panel_opciones['CallPut'].values[idx] = callput
        
panel_opciones.Moneyness = panel_opciones.Spot/ panel_opciones.strike

# %%
panel_opciones.head(10)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220916C00005000 2022-08-04 16:37:48+00:00     5.0       2.76
# 1      1  GGAL220916C00007500 2022-08-24 19:13:34+00:00     7.5       1.20
# 2      2  GGAL220916C00010000 2022-08-23 18:32:10+00:00    10.0       0.05
# 3      0  GGAL221021C00005000 2022-07-29 19:03:30+00:00     5.0       3.00
# 4      1  GGAL221021C00007500 2022-08-24 19:04:09+00:00     7.5       1.30
# 5      2  GGAL221021C00010000 2022-08-24 18:14:33+00:00    10.0       0.20
# 6      3  GGAL221021C00012500 2022-07-29 14:46:00+00:00    12.5       0.05
# 7      4  GGAL221021C00015000 2022-08-08 15:23:35+00:00    15.0       0.05
# 8      5  GGAL221021C00017500 2022-04-04 16:46:19+00:00    17.5       0.34
# 9      0  GGAL230120C00002500 2021-11-03 15:23:48+00:00     2.5       8.90
#
#     bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  2.95  3.70    0.00       0.000000     8.0          10.0           1.707033
# 1  1.00  1.40    0.25      26.315796    33.0         171.0           0.625004
# 2  0.00  0.10    0.00       0.000000     3.0          73.0           0.574223
# 3  3.10  3.80    0.00       0.000000     2.0           1.0           1.273441
# 4  0.70  1.60    0.10       8.333325    14.0         388.0           0.771487
# 5  0.20  0.40    0.00       0.000000   216.0         401.0           0.560551
# 6  0.00  0.50    0.00       0.000000    35.0        1033.0           0.867189
# 7  0.00  0.75    0.00       0.000000    30.0        1276.0           1.255863
# 8  0.00  0.45    0.00       0.000000     6.0          21.0           1.273441
# 9  4.50  9.50    0.00       0.000000    20.0           3.0           2.759769
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0         1.0      REGULAR      USD  8.55   GGAL   1.710000   23       C
# 1         1.0      REGULAR      USD  8.55   GGAL   1.140000   23       C
# 2         0.0      REGULAR      USD  8.55   GGAL   0.855000   23       C
# 3         1.0      REGULAR      USD  8.55   GGAL   1.710000   58       C
# 4         1.0      REGULAR      USD  8.55   GGAL   1.140000   58       C
# 5         0.0      REGULAR      USD  8.55   GGAL   0.855000   58       C
# 6         0.0      REGULAR      USD  8.55   GGAL   0.684000   58       C
# 7         0.0      REGULAR      USD  8.55   GGAL   0.570000   58       C
# 8         0.0      REGULAR      USD  8.55   GGAL   0.488571   58       C
# 9         1.0      REGULAR      USD  8.55   GGAL   3.420000  149       C

# %% [markdown]
# #### Panel Limpio

# %%
panel_opciones = panel_opciones.rename(
            columns={'lastTradeDate': 'Last_Date', 'contractSymbol': 'Especie', 'strike': 'Strike', 'bid': 'Bid',
                     'ask': 'Ask', 'lastPrice': 'Last'}, inplace=False)

panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])

panel_opciones = panel_opciones[['Especie', 'Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Bid','Ask','impliedVolatility','Moneyness']]

# %%
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']
panel_opciones
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last    Bid  \
# 0   GGAL220916C00005000   GGAL  8.55       C     5.0   23   2.76   2.95
# 1   GGAL220916P00005000   GGAL  8.55       P     5.0   23   0.17   0.00
# 2   GGAL220916C00007500   GGAL  8.55       C     7.5   23   1.20   1.00
# 3   GGAL220916P00007500   GGAL  8.55       P     7.5   23   0.33   0.05
# 4   GGAL220916C00010000   GGAL  8.55       C    10.0   23   0.05   0.00
# 5   GGAL220916P00010000   GGAL  8.55       P    10.0   23   4.00   1.40
# 6   GGAL221021C00005000   GGAL  8.55       C     5.0   58   3.00   3.10
# 7   GGAL221021P00005000   GGAL  8.55       P     5.0   58   0.10   0.00
# 8   GGAL221021C00007500   GGAL  8.55       C     7.5   58   1.30   0.70
# 9   GGAL221021P00007500   GGAL  8.55       P     7.5   58   0.36   0.25
# 10  GGAL221021C00010000   GGAL  8.55       C    10.0   58   0.20   0.20
# 11  GGAL221021P00010000   GGAL  8.55       P    10.0   58   1.85   1.45
# 12  GGAL221021C00012500   GGAL  8.55       C    12.5   58   0.05   0.00
# 13  GGAL221021C00015000   GGAL  8.55       C    15.0   58   0.05   0.00
# 14  GGAL221021C00017500   GGAL  8.55       C    17.5   58   0.34   0.00
# 15  GGAL230120C00002500   GGAL  8.55       C     2.5  149   8.90   4.50
# 16  GGAL230120P00002500   GGAL  8.55       P     2.5  149   0.10   0.00
# 17  GGAL230120C00005000   GGAL  8.55       C     5.0  149   3.32   3.20
# 18  GGAL230120P00005000   GGAL  8.55       P     5.0  149   0.15   0.00
# 19  GGAL230120C00007500   GGAL  8.55       C     7.5  149   1.35   1.05
# 20  GGAL230120P00007500   GGAL  8.55       P     7.5  149   0.65   0.55
# 21  GGAL230120C00010000   GGAL  8.55       C    10.0  149   0.51   0.55
# 22  GGAL230120P00010000   GGAL  8.55       P    10.0  149   2.00   1.85
# 23  GGAL230120C00012500   GGAL  8.55       C    12.5  149   0.17   0.05
# 24  GGAL230120P00012500   GGAL  8.55       P    12.5  149   5.50   5.20
# 25  GGAL230120C00015000   GGAL  8.55       C    15.0  149   0.08   0.00
# 26  GGAL230120P00015000   GGAL  8.55       P    15.0  149   6.51   6.10
# 27  GGAL230120C00017500   GGAL  8.55       C    17.5  149   0.15   0.00
# 28  GGAL230120P00017500   GGAL  8.55       P    17.5  149   7.80   7.40
# 29  GGAL230120C00020000   GGAL  8.55       C    20.0  149   0.05   0.00
# 30  GGAL230120P00020000   GGAL  8.55       P    20.0  149  13.93  10.50
# 31  GGAL230120C00022500   GGAL  8.55       C    22.5  149   0.20   0.05
# 32  GGAL230421C00010000   GGAL  8.55       C    10.0  240   0.80   0.10
# 33  GGAL240119C00002500   GGAL  8.55       C     2.5  513   5.50   1.50
# 34  GGAL240119C00005000   GGAL  8.55       C     5.0  513   4.10   3.50
# 35  GGAL240119P00005000   GGAL  8.55       P     5.0  513   0.75   0.00
# 36  GGAL240119C00007500   GGAL  8.55       C     7.5  513   2.55   1.85
# 37  GGAL240119P00007500   GGAL  8.55       P     7.5  513   1.65   0.15
# 38  GGAL240119C00010000   GGAL  8.55       C    10.0  513   1.40   0.10
# 39  GGAL240119P00010000   GGAL  8.55       P    10.0  513   2.90   1.00
# 40  GGAL240119C00012500   GGAL  8.55       C    12.5  513   1.05   0.50
# 41  GGAL240119C00015000   GGAL  8.55       C    15.0  513   0.60   0.70
# 42  GGAL240119P00015000   GGAL  8.55       P    15.0  513   8.30   4.50
# 43  GGAL240119C00017500   GGAL  8.55       C    17.5  513   0.50   0.10
# 44  GGAL240119C00020000   GGAL  8.55       C    20.0  513   1.15   0.05
# 45  GGAL240119C00022500   GGAL  8.55       C    22.5  513   0.75   0.30
#
#       Ask  impliedVolatility  Moneyness
# 0    3.70           1.707033   1.710000
# 1    0.40           1.859376   1.710000
# 2    1.40           0.625004   1.140000
# 3    0.75           1.003911   1.140000
# 4    0.10           0.574223   0.855000
# 5    3.00           1.437503   0.855000
# 6    3.80           1.273441   1.710000
# 7    0.20           0.976563   1.710000
# 8    1.60           0.771487   1.140000
# 9    0.60           0.662113   1.140000
# 10   0.40           0.560551   0.855000
# 11   2.25           0.644535   0.855000
# 12   0.50           0.867189   0.684000
# 13   0.75           1.255863   0.570000
# 14   0.45           1.273441   0.488571
# 15   9.50           2.759769   3.420000
# 16   0.50           1.613283   3.420000
# 17   3.90           0.900392   1.710000
# 18   0.75           0.923829   1.710000
# 19   2.60           0.603520   1.140000
# 20   0.90           0.577153   1.140000
# 21   0.95           0.575200   0.855000
# 22   2.00           0.479497   0.855000
# 23   0.20           0.507817   0.684000
# 24   7.60           1.622072   0.684000
# 25   0.25           0.585942   0.570000
# 26   7.00           0.558598   0.570000
# 27   0.25           0.699222   0.488571
# 28   8.90           0.000010   0.488571
# 29   0.25           0.789065   0.427500
# 30  11.50           0.671878   0.427500
# 31   0.40           0.980469   0.380000
# 32   2.05           0.572270   0.855000
# 33   6.50           1.062505   3.420000
# 34   4.80           0.606449   1.710000
# 35   4.10           1.233402   1.710000
# 36   4.10           0.651859   1.140000
# 37   2.80           0.523931   1.140000
# 38   4.20           0.658695   0.855000
# 39   4.30           0.838869   0.855000
# 40   1.50           0.514165   0.684000
# 41   0.90           0.558110   0.570000
# 42   9.50           1.129399   0.570000
# 43   0.95           0.547856   0.488571
# 44   4.70           1.104497   0.427500
# 45   4.10           1.115727   0.380000

# %% [markdown]
# ## 2) Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# NYSE
panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)

TTMs = list(set(panel_opciones_ggal_nyse_limpio.TTM.values))
TTMs
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   panel_opciones = calls.append(puts)
# [513, 240, 149, 23, 58]

# %%
TTM = 8
panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == "C")].head(10)
# Out:
# Empty DataFrame
# Columns: [Especie, Ticker, Spot, CallPut, Strike, TTM, Last, Moneyness, impliedVolatility, Bid, Ask]
# Index: []

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    ## Last VS (B+A)/2
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %% [markdown]
# ### Para cada strike, grafico los TTM

# %%
Ks = list(set(panel_opciones_ggal_nyse_limpio.Strike.values))

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks:
    TTMs = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Ploteando los datos con un ticker mega liquido

# %%
# NYSE AAPL
ticker = 'TSLA'
panel_opciones_nyse_limpio = obtener_panel_opciones_nyse(ticker, True)

TTMs = list(set(panel_opciones_nyse_limpio.TTM.values))
TTMs.sort()
TTMs
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# [2, 9, 16, 23, 30, 37, 58, 86, 114, 149, 205, 240, 296, 387, 513, 569, 667]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[8:11]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[3:6]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[10:15]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[11:17]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
Ks = list(set(panel_opciones_nyse_limpio.Strike.values))
Ks.sort()
len(Ks)
# Out:
# 365

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[45:55]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for K in Ks[100:]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Pasar a Excel

# %%
panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')

panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')


panel_opciones_aapl_nyse_limpio = obtener_panel_opciones_nyse('AAPL', True)
panel_opciones_aapl_nyse_limpio.to_excel('Clase_2_panel_opciones_aapl_nyse_limpio.xls')
# Out:
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\..\Codigo\data_nyse.py:25: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   panel_opciones = calls.append(puts)
# C:\Users\manue\AppData\Local\Temp\ipykernel_19196\891834467.py:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase2.ipynb Cell 54 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y104sZmlsZQ%3D%3D?line=1'>2</a> panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y104sZmlsZQ%3D%3D?line=3'>4</a> panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y104sZmlsZQ%3D%3D?line=4'>5</a> panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\formats\excel.py:888, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884     need_save = False
#     885 else:
#     886     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888     writer = ExcelWriter(  # type: ignore[abstract]
#     889         writer, engine=engine, storage_options=storage_options
#     890     )
#     891     need_save = True
#     893 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\excel\_xlwt.py:39, in XlwtWriter.__init__(self, path, engine, date_format, datetime_format, encoding, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      25 def __init__(
#      26     self,
#      27     path,
#    (...)
#      37 ):
#      38     # Use the xlwt module as the Excel writer.
# ---> 39     import xlwt
#      41     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      43     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlwt'

# %% [markdown]
# ## 3) Payoffs y Estrategias

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Vanilla Call y Put

# %%
def payoff_call(S,K):
    return np.maximum(S-K,0)

def payoff_put(S,K):
    return np.maximum(K-S,0)

# %%
K=50
S = np.linspace(0,100,50)

# %%
#Grafico la call

plt.plot(S,payoff_call(S, K))
plt.show()

# %%
#Grafico la put
plt.plot(S,payoff_put(S, K))
plt.show()

# %% [markdown]
# ### Forward sintetico y Combo

# %%
def payoff_forwardSintetico(S,K):
    return payoff_call(S,K)-payoff_put(S, K)

def payoff_combo(S,K1,K2):
    return payoff_call(S,K2)-payoff_put(S, K1)

# %%
#Grafico el forward sintetico
plt.plot(S,payoff_forwardSintetico(S, K))
plt.show()

# %%
K1 = 35
K2 = 65

# %%
#Grafico el combo
plt.plot(S,payoff_combo(S, K1,K2))
plt.show()

# %% [markdown]
# ### Spreads

# %%
def payoff_BullCS(S,K1,K2):
    return payoff_call(S,K1)-payoff_call(S, K2)

def payoff_BearCS(S,K1,K2):
    return payoff_call(S,K2)-payoff_call(S, K1)

def payoff_BullPS(S,K1,K2):
    return payoff_put(S,K1)-payoff_put(S, K2)


def payoff_BearPS(S,K1,K2):
    return payoff_put(S,K2)-payoff_put(S, K1)

# %%
#Grafico el Bull Call Spread
plt.plot(S,payoff_BullCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Call Spread
plt.plot(S,payoff_BearCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bull Put Spread
plt.plot(S,payoff_BullPS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Put Spread
plt.plot(S,payoff_BearPS(S, K1, K2))
plt.show()

# %% [markdown]
# ### Butterfly spreads

# %%
def payoff_CButterflyS(S,K1,K2,K3):
    return payoff_call(S,K1)-2*payoff_call(S, K2)+payoff_call(S, K3)

def payoff_PButterflyS(S,K1,K2,K3):
    return payoff_put(S,K1)-2*payoff_put(S, K2)+payoff_put(S, K3)

# %%
K1=35
K2=50
K3=65

# %%
#Grafico el Call Buterfly Spread
plt.plot(S,payoff_CButterflyS(S, K1, K2,K3))
plt.show()

# %%
#Grafico el Put Buterfly Spread
plt.plot(S,payoff_PButterflyS(S, K1, K2,K3))
plt.show()

# %% [markdown]
# ### Straddle y Strangle

# %%
def payoff_straddle(S,K):
    return payoff_call(S,K)+payoff_put(S, K)


def payoff_strangle(S,K1,K2):
    return payoff_call(S,K1)+payoff_put(S, K2)

# %%
K1 = 35
K2 = 65

# %%
#Grafico el Strangle
plt.plot(S,payoff_strangle(S, K1,K2))
plt.show()

# %%
#Grafico el Straddle

plt.plot(S,payoff_straddle(S, K))
plt.show()

# %% [markdown]
# ### Estrategia AD hoc - Iron Condor

# %%
def payoff_iron_condor(S,K1,K2,K3,K4):
    return payoff_put(S,K1)-payoff_put(S, K2)-payoff_call(S,K3)+payoff_call(S,K4)

# %%
K1 = 30
K2 = 45
K3 = 55
K4 = 70

# %%
plt.plot(S,payoff_iron_condor(S, K1,K2,K3,K4))
plt.show()

# %%
#usando el script con los metodos
import payoffs
payoffs.payoff_call(120,50)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\manue\OneDrive\Documents\finanzasCuantitativas\Notebooks\Derivados_Financieros_Clase2.ipynb Cell 87 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y150sZmlsZQ%3D%3D?line=0'>1</a> #usando el script con los metodos
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y150sZmlsZQ%3D%3D?line=1'>2</a> import payoffs
#       <a href='vscode-notebook-cell:/c%3A/Users/manue/OneDrive/Documents/finanzasCuantitativas/Notebooks/Derivados_Financieros_Clase2.ipynb#Y150sZmlsZQ%3D%3D?line=2'>3</a> payoffs.payoff_call(120,50)
#
# ModuleNotFoundError: No module named 'payoffs'
