# %% [markdown]
# # Vanilla Pricing
#
# Precio de opciones call y put con Black-Scholes, binomial y Monte Carlo.

# %%
import sys
sys.path.insert(0, '../..')

from Codigo.pricing import opcion_europea_bs, opcion_europea_bin, opcion_europea_mc

S, K, T, r, sigma, div = 100, 100, 1, 0.05, 0.25, 0
pasos = 1000

p_bs = opcion_europea_bs('C', S, K, T, r, sigma, div)
p_bin = opcion_europea_bin('C', S, K, T, r, sigma, div, pasos)
p_mc = opcion_europea_mc('C', S, K, T, r, sigma, div, pasos)

print(f'BS: {p_bs:.4f}')
print(f'Binomial: {p_bin:.4f}')
print(f'Monte Carlo: {p_mc:.4f}')
