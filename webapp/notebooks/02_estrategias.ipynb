# %% [markdown]
# # Estrategias
#
# Pricing de estrategias por composicion (Bull Call Spread, Straddle, etc.).

# %%
import sys
sys.path.insert(0, '../..')

from Codigo.pricing import precio_estrategia_nombre
from Codigo.analytics import payoff_BullCS
from Codigo.utils.plots import plot_payoff
import matplotlib.pyplot as plt

S, T, r, sigma, div = 100, 1, 0.05, 0.25, 0
K1, K2 = 90, 110

precio = precio_estrategia_nombre('bull_call_spread', S, T, r, sigma, div, K1=K1, K2=K2)
print(f'Bull Call Spread precio: {precio:.4f}')

fig, ax = plot_payoff(payoff_BullCS, K1=K1, K2=K2)
plt.show()
