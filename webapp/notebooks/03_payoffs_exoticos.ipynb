# %% [markdown]
# # Payoffs Exoticos
#
# Digitales, Asian y Barrier.

# %%
import sys
sys.path.insert(0, '../..')

from Codigo.analytics import payoff_digital_call, payoff_asian_call, payoff_barrier_up_in_call
from Codigo.utils.plots import plot_payoff
import matplotlib.pyplot as plt

# Digital
fig, ax = plot_payoff(payoff_digital_call, K=100, Q=10)
ax.set_title('Digital Call')
plt.show()

# Asian (eje x = S_avg)
fig, ax = plot_payoff(payoff_asian_call, K=100)
ax.set_title('Asian Call')
plt.show()

# Barrier (barrier hit = True)
fig, ax = plot_payoff(payoff_barrier_up_in_call, K=100, B=120, barrier_hit=True)
ax.set_title('Up-and-In Call (barrier hit)')
plt.show()
