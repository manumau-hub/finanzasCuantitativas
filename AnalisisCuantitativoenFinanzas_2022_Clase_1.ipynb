# %% [markdown]
# # Analisis Cuantitativo en Finanzas 2022 Clase 1

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance
# ## 2) Plots
# ## 3) Payoffs - Estraegias

# %%
### Importo los modulos

from data_nyse import *

import yfinance as yf
import datetime

# %% [markdown]
# ## API Yahoo finance

# %% [markdown]
# Modulos necesarios
#
# data_nyse (en webcampus) ;
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# yfinance, (yfinance-0.1.63 - tuve que actualizar reicentemente)
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install
#
#
# urllib.requestatexit
# datetime
# dateutil
#
# import tda
# json
# selenium, webdriver

# %% [markdown]
# ## Queremos obtener datos de mercado

# %%
### Metodo para el web scraping
panel_yahoo_GGAL = obtener_opciones_yahoo_finance('GGAL')
# Out:
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)

# %%
panel_yahoo_GGAL
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0  GGAL220520C00007500 2022-04-27 16:36:05+00:00     7.5       1.70   0.80
# 1  GGAL220520C00010000 2022-05-10 16:46:36+00:00    10.0       0.05   0.05
# 2  GGAL220520C00012500 2022-05-09 19:58:37+00:00    12.5       0.05   0.00
# 0  GGAL220617C00010000 2022-05-10 16:54:05+00:00    10.0       0.15   0.15
# 1  GGAL220617C00012500 2022-04-22 19:51:04+00:00    12.5       0.10   0.00
# 0  GGAL220715C00007500 2022-03-10 18:12:10+00:00     7.5       2.97   2.65
# 1  GGAL220715C00010000 2022-05-06 15:30:08+00:00    10.0       0.45   0.20
# 2  GGAL220715C00012500 2022-04-25 18:35:14+00:00    12.5       0.10   0.00
# 3  GGAL220715C00015000 2022-04-22 14:22:47+00:00    15.0       0.05   0.00
# 0  GGAL221021C00007500 2022-03-25 13:31:52+00:00     7.5       3.90   1.70
# 1  GGAL221021C00010000 2022-05-10 15:09:46+00:00    10.0       0.75   0.65
# 2  GGAL221021C00012500 2022-05-06 15:11:46+00:00    12.5       0.40   0.10
# 3  GGAL221021C00015000 2022-04-20 19:50:42+00:00    15.0       0.35   0.10
# 4  GGAL221021C00017500 2022-04-04 16:46:19+00:00    17.5       0.34   0.00
# 0  GGAL230120C00002500 2021-11-03 15:23:48+00:00     2.5       8.90   4.50
# 1  GGAL230120C00005000 2021-11-23 15:01:10+00:00     5.0       5.00   3.50
# 2  GGAL230120C00007500 2022-04-28 19:36:12+00:00     7.5       2.75   1.95
# 3  GGAL230120C00010000 2022-05-05 17:29:13+00:00    10.0       1.20   1.00
# 4  GGAL230120C00012500 2022-05-10 18:14:22+00:00    12.5       0.68   0.50
# 5  GGAL230120C00015000 2022-04-20 14:29:57+00:00    15.0       0.65   0.25
# 6  GGAL230120C00017500 2022-05-10 14:19:10+00:00    17.5       0.20   0.15
# 7  GGAL230120C00020000 2022-03-11 19:17:33+00:00    20.0       0.30   0.00
# 8  GGAL230120C00022500 2022-03-09 18:38:57+00:00    22.5       0.20   0.05
# 0  GGAL240119C00002500 2022-02-09 14:35:11+00:00     2.5       7.04   0.00
# 1  GGAL240119C00005000 2021-11-29 16:22:53+00:00     5.0       4.80   3.10
# 2  GGAL240119C00007500 2022-04-26 17:59:48+00:00     7.5       3.50   1.30
# 3  GGAL240119C00010000 2022-04-21 13:55:24+00:00    10.0       1.40   1.00
# 4  GGAL240119C00012500 2022-03-22 16:58:41+00:00    12.5       2.50   0.65
# 5  GGAL240119C00015000 2022-05-09 16:19:21+00:00    15.0       1.15   0.75
# 6  GGAL240119C00017500 2022-05-09 19:49:45+00:00    17.5       0.85   0.50
# 7  GGAL240119C00020000 2022-02-18 19:04:35+00:00    20.0       1.15   0.05
# 8  GGAL240119C00022500 2022-04-22 19:08:46+00:00    22.5       0.75   0.00
# 0  GGAL220520P00010000 2022-05-10 16:47:17+00:00    10.0       1.55   1.45
# 1  GGAL220520P00012500 2022-03-25 19:39:45+00:00    12.5       2.20   2.90
# 0  GGAL220617P00007500 2022-05-02 13:35:44+00:00     7.5       0.30   0.25
# 1  GGAL220617P00010000 2022-05-10 13:34:21+00:00    10.0       1.60   1.45
# 0  GGAL220715P00005000 2022-03-08 15:12:58+00:00     5.0       0.10   0.00
# 1  GGAL220715P00007500 2022-05-05 19:40:57+00:00     7.5       0.45   0.35
# 2  GGAL220715P00010000 2022-05-09 13:42:49+00:00    10.0       1.75   1.70
# 3  GGAL220715P00012500 2022-05-04 19:30:24+00:00    12.5       3.70   3.70
# 4  GGAL220715P00015000 2022-01-04 20:55:07+00:00    15.0       5.80   5.60
# 5  GGAL220715P00020000 2021-12-13 05:08:10+00:00    20.0      10.60  10.10
# 0  GGAL221021P00007500 2022-04-28 18:35:10+00:00     7.5       0.70   0.65
# 1  GGAL221021P00010000 2022-05-10 16:47:17+00:00    10.0       1.95   2.15
# 0  GGAL230120P00002500 2021-11-10 11:54:19+00:00     2.5       0.12   0.00
# 1  GGAL230120P00005000 2022-04-19 15:28:50+00:00     5.0       0.25   0.05
# 2  GGAL230120P00007500 2022-05-10 16:32:39+00:00     7.5       1.15   0.95
# 3  GGAL230120P00010000 2022-04-28 19:32:18+00:00    10.0       2.35   2.10
# 4  GGAL230120P00012500 2022-03-09 20:31:35+00:00    12.5       3.80   3.30
# 5  GGAL230120P00015000 2021-11-10 11:54:19+00:00    15.0       6.51   6.10
# 6  GGAL230120P00017500 2022-04-18 17:31:48+00:00    17.5       7.80   8.30
# 7  GGAL230120P00020000 2021-11-10 11:54:19+00:00    20.0      13.93  10.50
# 0  GGAL240119P00005000 2021-10-21 15:38:42+00:00     5.0       0.60   0.55
# 1  GGAL240119P00007500 2022-05-10 15:05:17+00:00     7.5       1.95   0.95
# 2  GGAL240119P00010000 2022-04-19 16:26:43+00:00    10.0       2.81   1.00
# 3  GGAL240119P00015000 2022-01-18 18:50:25+00:00    15.0       8.30   4.50
#
#      ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0   2.65    0.00       0.000000     1.0            10           1.585940
# 1   0.10   -0.05     -50.000000   161.0           872           0.648441
# 2   0.05    0.00       0.000000     1.0           277           1.078130
# 0   0.25   -0.20     -57.142853     8.0           111           0.550786
# 1   1.00    0.00       0.000000    40.0            55           1.281254
# 0   3.70    0.00       0.000000     1.0           196           1.793946
# 1   0.45    0.00       0.000000     1.0           765           0.568364
# 2   0.95    0.00       0.000000     1.0           478           0.957032
# 3   0.95    0.00       0.000000     6.0           529           1.212895
# 0   2.55    0.00       0.000000     5.0             5           0.618168
# 1   0.90   -0.10     -11.764708     3.0            74           0.504888
# 2   0.55    0.00       0.000000     1.0           908           0.528325
# 3   0.30    0.00       0.000000   651.0          1276           0.595707
# 4   0.45    0.00       0.000000     6.0            21           0.730471
# 0   9.50    0.00       0.000000    20.0             3           1.773439
# 1   6.10    0.00       0.000000   100.0           286           1.103520
# 2   2.50    0.00       0.000000    10.0           228           0.537114
# 3   1.30    0.00       0.000000    39.0          1817           0.532720
# 4   0.75    0.08      13.333329     8.0          1886           0.549809
# 5   0.60    0.00       0.000000     1.0          1588           0.597660
# 6   0.25    0.00       0.000000     2.0           774           0.569340
# 7   0.50    0.00       0.000000    85.0          1358           0.678714
# 8   0.40    0.00       0.000000    30.0          2413           0.726565
# 0   0.00    0.00       0.000000     5.0            11           0.000010
# 1   8.00    0.00       0.000000     1.0             5           0.999023
# 2   4.90    0.00       0.000000     2.0            10           0.570317
# 3   3.40    0.00       0.000000     3.0            81           0.571782
# 4   4.10    0.00       0.000000    32.0            59           0.743655
# 5   1.45    0.00       0.000000     4.0          1175           0.557133
# 6   1.00    0.05       6.250001     1.0           211           0.541508
# 7   4.70    0.00       0.000000     1.0            12           0.972168
# 8   3.40    0.00       0.000000    10.0            17           0.874513
# 0   2.35   -0.05      -3.125005     1.0           478           1.914063
# 1   3.60    0.00       0.000000     5.0             5           0.000010
# 0   0.35    0.00       0.000000     1.0             7           0.753909
# 1   2.00    0.05       3.225811     2.0             2           0.859376
# 0   0.90    0.00       0.000000   100.0           128           1.535159
# 1   0.55    0.00       0.000000   100.0           623           0.707034
# 2   2.00    0.00       0.000000    16.0           360           0.741214
# 3   4.30    0.00       0.000000     1.0           313           0.851564
# 4   6.10    0.00       0.000000     5.0            35           0.000010
# 5  12.00    0.00       0.000000     NaN             0           1.897461
# 0   1.10    0.00       0.000000     2.0             8           0.668949
# 1   2.55   -0.05      -2.499998     1.0            53           0.684573
# 0   1.00    0.00       0.000000     1.0             1           1.589846
# 1   0.55    0.00       0.000000    10.0            58           0.675784
# 2   1.25    0.15      14.999998     4.0          1058           0.627445
# 3   3.00    0.00       0.000000    10.0           480           0.617680
# 4   3.60    0.00       0.000000     1.0            21           0.000010
# 5   7.00    0.00       0.000000     1.0             2           0.586918
# 6   9.70    0.00       0.000000     3.0            12           0.660160
# 7  11.50    0.00       0.000000     2.0             0           0.740237
# 0   1.25    0.00       0.000000     NaN            10           0.689456
# 1   2.50    0.05       2.631583     2.0            33           0.563969
# 2   6.00    0.00       0.000000     2.0            14           0.605961
# 3   9.50    0.00       0.000000     NaN             9           1.055181
#
#    inTheMoney contractSize currency Ticker  Spot
# 0        True      REGULAR      USD   GGAL  8.85
# 1       False      REGULAR      USD   GGAL  8.85
# 2       False      REGULAR      USD   GGAL  8.85
# 0       False      REGULAR      USD   GGAL  8.85
# 1       False      REGULAR      USD   GGAL  8.85
# 0        True      REGULAR      USD   GGAL  8.85
# 1       False      REGULAR      USD   GGAL  8.85
# 2       False      REGULAR      USD   GGAL  8.85
# 3       False      REGULAR      USD   GGAL  8.85
# 0        True      REGULAR      USD   GGAL  8.85
# 1       False      REGULAR      USD   GGAL  8.85
# 2       False      REGULAR      USD   GGAL  8.85
# 3       False      REGULAR      USD   GGAL  8.85
# 4       False      REGULAR      USD   GGAL  8.85
# 0        True      REGULAR      USD   GGAL  8.85
# 1        True      REGULAR      USD   GGAL  8.85
# 2        True      REGULAR      USD   GGAL  8.85
# 3       False      REGULAR      USD   GGAL  8.85
# 4       False      REGULAR      USD   GGAL  8.85
# 5       False      REGULAR      USD   GGAL  8.85
# 6       False      REGULAR      USD   GGAL  8.85
# 7       False      REGULAR      USD   GGAL  8.85
# 8       False      REGULAR      USD   GGAL  8.85
# 0        True      REGULAR      USD   GGAL  8.85
# 1        True      REGULAR      USD   GGAL  8.85
# 2        True      REGULAR      USD   GGAL  8.85
# 3       False      REGULAR      USD   GGAL  8.85
# 4       False      REGULAR      USD   GGAL  8.85
# 5       False      REGULAR      USD   GGAL  8.85
# 6       False      REGULAR      USD   GGAL  8.85
# 7       False      REGULAR      USD   GGAL  8.85
# 8       False      REGULAR      USD   GGAL  8.85
# 0        True      REGULAR      USD   GGAL  8.85
# 1        True      REGULAR      USD   GGAL  8.85
# 0       False      REGULAR      USD   GGAL  8.85
# 1        True      REGULAR      USD   GGAL  8.85
# 0       False      REGULAR      USD   GGAL  8.85
# 1       False      REGULAR      USD   GGAL  8.85
# 2        True      REGULAR      USD   GGAL  8.85
# 3        True      REGULAR      USD   GGAL  8.85
# 4        True      REGULAR      USD   GGAL  8.85
# 5        True      REGULAR      USD   GGAL  8.85
# 0       False      REGULAR      USD   GGAL  8.85
# 1        True      REGULAR      USD   GGAL  8.85
# 0       False      REGULAR      USD   GGAL  8.85
# 1       False      REGULAR      USD   GGAL  8.85
# 2       False      REGULAR      USD   GGAL  8.85
# 3        True      REGULAR      USD   GGAL  8.85
# 4        True      REGULAR      USD   GGAL  8.85
# 5        True      REGULAR      USD   GGAL  8.85
# 6        True      REGULAR      USD   GGAL  8.85
# 7        True      REGULAR      USD   GGAL  8.85
# 0       False      REGULAR      USD   GGAL  8.85
# 1       False      REGULAR      USD   GGAL  8.85
# 2        True      REGULAR      USD   GGAL  8.85
# 3        True      REGULAR      USD   GGAL  8.85

# %%
panel_ociones_GGAL_nyse_clean = obtener_panel_opciones_nyse('GGAL', True)
# Out:
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)

# %%
panel_ociones_GGAL_nyse_clean
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last  Moneyness  \
# 0   GGAL220520C00007500   GGAL  8.85       C     7.5   10   1.70   1.180000
# 1   GGAL220520C00010000   GGAL  8.85       C    10.0   10   0.05   0.885000
# 2   GGAL220520P00010000   GGAL  8.85       P    10.0   10   1.55   0.885000
# 3   GGAL220520C00012500   GGAL  8.85       C    12.5   10   0.05   0.708000
# 4   GGAL220520P00012500   GGAL  8.85       P    12.5   10   2.20   0.708000
# 5   GGAL220617P00007500   GGAL  8.85       P     7.5   38   0.30   1.180000
# 6   GGAL220617C00010000   GGAL  8.85       C    10.0   38   0.15   0.885000
# 7   GGAL220617P00010000   GGAL  8.85       P    10.0   38   1.60   0.885000
# 8   GGAL220617C00012500   GGAL  8.85       C    12.5   38   0.10   0.708000
# 9   GGAL220715P00005000   GGAL  8.85       P     5.0   66   0.10   1.770000
# 10  GGAL220715C00007500   GGAL  8.85       C     7.5   66   2.97   1.180000
# 11  GGAL220715P00007500   GGAL  8.85       P     7.5   66   0.45   1.180000
# 12  GGAL220715C00010000   GGAL  8.85       C    10.0   66   0.45   0.885000
# 13  GGAL220715P00010000   GGAL  8.85       P    10.0   66   1.75   0.885000
# 14  GGAL220715C00012500   GGAL  8.85       C    12.5   66   0.10   0.708000
# 15  GGAL220715P00012500   GGAL  8.85       P    12.5   66   3.70   0.708000
# 16  GGAL220715C00015000   GGAL  8.85       C    15.0   66   0.05   0.590000
# 17  GGAL220715P00015000   GGAL  8.85       P    15.0   66   5.80   0.590000
# 18  GGAL220715P00020000   GGAL  8.85       P    20.0   66  10.60   0.442500
# 19  GGAL221021C00007500   GGAL  8.85       C     7.5  164   3.90   1.180000
# 20  GGAL221021P00007500   GGAL  8.85       P     7.5  164   0.70   1.180000
# 21  GGAL221021C00010000   GGAL  8.85       C    10.0  164   0.75   0.885000
# 22  GGAL221021P00010000   GGAL  8.85       P    10.0  164   1.95   0.885000
# 23  GGAL221021C00012500   GGAL  8.85       C    12.5  164   0.40   0.708000
# 24  GGAL221021C00015000   GGAL  8.85       C    15.0  164   0.35   0.590000
# 25  GGAL221021C00017500   GGAL  8.85       C    17.5  164   0.34   0.505714
# 26  GGAL230120C00002500   GGAL  8.85       C     2.5  255   8.90   3.540000
# 27  GGAL230120P00002500   GGAL  8.85       P     2.5  255   0.12   3.540000
# 28  GGAL230120C00005000   GGAL  8.85       C     5.0  255   5.00   1.770000
# 29  GGAL230120P00005000   GGAL  8.85       P     5.0  255   0.25   1.770000
# 30  GGAL230120C00007500   GGAL  8.85       C     7.5  255   2.75   1.180000
# 31  GGAL230120P00007500   GGAL  8.85       P     7.5  255   1.15   1.180000
# 32  GGAL230120C00010000   GGAL  8.85       C    10.0  255   1.20   0.885000
# 33  GGAL230120P00010000   GGAL  8.85       P    10.0  255   2.35   0.885000
# 34  GGAL230120C00012500   GGAL  8.85       C    12.5  255   0.68   0.708000
# 35  GGAL230120P00012500   GGAL  8.85       P    12.5  255   3.80   0.708000
# 36  GGAL230120C00015000   GGAL  8.85       C    15.0  255   0.65   0.590000
# 37  GGAL230120P00015000   GGAL  8.85       P    15.0  255   6.51   0.590000
# 38  GGAL230120C00017500   GGAL  8.85       C    17.5  255   0.20   0.505714
# 39  GGAL230120P00017500   GGAL  8.85       P    17.5  255   7.80   0.505714
# 40  GGAL230120C00020000   GGAL  8.85       C    20.0  255   0.30   0.442500
# 41  GGAL230120P00020000   GGAL  8.85       P    20.0  255  13.93   0.442500
# 42  GGAL230120C00022500   GGAL  8.85       C    22.5  255   0.20   0.393333
# 43  GGAL240119C00002500   GGAL  8.85       C     2.5  619   7.04   3.540000
# 44  GGAL240119C00005000   GGAL  8.85       C     5.0  619   4.80   1.770000
# 45  GGAL240119P00005000   GGAL  8.85       P     5.0  619   0.60   1.770000
# 46  GGAL240119C00007500   GGAL  8.85       C     7.5  619   3.50   1.180000
# 47  GGAL240119P00007500   GGAL  8.85       P     7.5  619   1.95   1.180000
# 48  GGAL240119C00010000   GGAL  8.85       C    10.0  619   1.40   0.885000
# 49  GGAL240119P00010000   GGAL  8.85       P    10.0  619   2.81   0.885000
# 50  GGAL240119C00012500   GGAL  8.85       C    12.5  619   2.50   0.708000
# 51  GGAL240119C00015000   GGAL  8.85       C    15.0  619   1.15   0.590000
# 52  GGAL240119P00015000   GGAL  8.85       P    15.0  619   8.30   0.590000
# 53  GGAL240119C00017500   GGAL  8.85       C    17.5  619   0.85   0.505714
# 54  GGAL240119C00020000   GGAL  8.85       C    20.0  619   1.15   0.442500
# 55  GGAL240119C00022500   GGAL  8.85       C    22.5  619   0.75   0.393333
#
#     impliedVolatility    Bid    Ask
# 0            1.585940   0.80   2.65
# 1            0.648441   0.05   0.10
# 2            1.914063   1.45   2.35
# 3            1.078130   0.00   0.05
# 4            0.000010   2.90   3.60
# 5            0.753909   0.25   0.35
# 6            0.550786   0.15   0.25
# 7            0.859376   1.45   2.00
# 8            1.281254   0.00   1.00
# 9            1.535159   0.00   0.90
# 10           1.793946   2.65   3.70
# 11           0.707034   0.35   0.55
# 12           0.568364   0.20   0.45
# 13           0.741214   1.70   2.00
# 14           0.957032   0.00   0.95
# 15           0.851564   3.70   4.30
# 16           1.212895   0.00   0.95
# 17           0.000010   5.60   6.10
# 18           1.897461  10.10  12.00
# 19           0.618168   1.70   2.55
# 20           0.668949   0.65   1.10
# 21           0.504888   0.65   0.90
# 22           0.684573   2.15   2.55
# 23           0.528325   0.10   0.55
# 24           0.595707   0.10   0.30
# 25           0.730471   0.00   0.45
# 26           1.773439   4.50   9.50
# 27           1.589846   0.00   1.00
# 28           1.103520   3.50   6.10
# 29           0.675784   0.05   0.55
# 30           0.537114   1.95   2.50
# 31           0.627445   0.95   1.25
# 32           0.532720   1.00   1.30
# 33           0.617680   2.10   3.00
# 34           0.549809   0.50   0.75
# 35           0.000010   3.30   3.60
# 36           0.597660   0.25   0.60
# 37           0.586918   6.10   7.00
# 38           0.569340   0.15   0.25
# 39           0.660160   8.30   9.70
# 40           0.678714   0.00   0.50
# 41           0.740237  10.50  11.50
# 42           0.726565   0.05   0.40
# 43           0.000010   0.00   0.00
# 44           0.999023   3.10   8.00
# 45           0.689456   0.55   1.25
# 46           0.570317   1.30   4.90
# 47           0.563969   0.95   2.50
# 48           0.571782   1.00   3.40
# 49           0.605961   1.00   6.00
# 50           0.743655   0.65   4.10
# 51           0.557133   0.75   1.45
# 52           1.055181   4.50   9.50
# 53           0.541508   0.50   1.00
# 54           0.972168   0.05   4.70
# 55           0.874513   0.00   3.40

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance

# %%
ticker = 'GGAL'
data = yf.Ticker(ticker)

#Data es un objeto
# data.info contiene informacion (mucha) del activo

data.info
# Out:
# {'zip': '1038',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 8714,
#  'longBusinessSummary': "Grupo Financiero Galicia S.A., a financial service holding company, provides various financial products and services to individuals and companies in Argentina. The company operates through Banks, NaranjaX, Insurance, and Other Businesses segments. The company's products and services cover savings, current, and checking accounts; personal loans; express and mortgage loans; pledge and credit card loans; credit and debit cards; and online banking services. It also offers financing products and services; consumer finance services; electronic check; global custody services; Fima funds; financial and stock market services to individuals, companies, and financial institutions; foreign trade services; and capital market and investment banking products that include debt securities, short-term securities, bills, and financial trusts. In addition, the company provides robbery, personal accident, life collective, home, life, integral pyme, pet, surety, various risks, and technical insurance products. Further, it offers private banking services to high net worth individuals; and operates digital investment platform. As of December 31, 2021, it had 312 full service banking branches; and 1,991 ATMs and self-service terminals. Grupo Financiero Galicia S.A. was founded in 1905 and is based in Buenos Aires, Argentina.",
#  'city': 'Buenos Aires',
#  'phone': '54 11 4343 7528',
#  'country': 'Argentina',
#  'companyOfficers': [],
#  'website': 'https://www.gfgsa.com',
#  'maxAge': 1,
#  'address1': 'Teniente General Juan D. Perón 430',
#  'fax': '54 11 4331 9183',
#  'industry': 'Banks—Regional',
#  'address2': '25th Floor',
#  'ebitdaMargins': 0,
#  'profitMargins': 0.113450006,
#  'grossMargins': 0,
#  'operatingCashflow': 268257034240,
#  'revenueGrowth': 0.188,
#  'operatingMargins': 0.17704001,
#  'ebitda': None,
#  'targetLowPrice': 8,
#  'recommendationKey': 'underperform',
#  'grossProfits': 282178293000,
#  'freeCashflow': None,
#  'targetMedianPrice': 8.2,
#  'currentPrice': 8.85,
#  'earningsGrowth': 0.405,
#  'currentRatio': None,
#  'returnOnAssets': 0.02009,
#  'numberOfAnalystOpinions': 5,
#  'targetMeanPrice': 8.9,
#  'debtToEquity': None,
#  'returnOnEquity': 0.11472,
#  'targetHighPrice': 11.9,
#  'totalCash': 493487095808,
#  'totalDebt': 215808737280,
#  'totalRevenue': 290237841408,
#  'totalCashPerShare': 3346.374,
#  'financialCurrency': 'ARS',
#  'revenuePerShare': 1968.13,
#  'quickRatio': None,
#  'recommendationMean': 3.7,
#  'exchange': 'NCM',
#  'shortName': 'Grupo Financiero Galicia S.A.',
#  'longName': 'Grupo Financiero Galicia S.A.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'GGAL',
#  'messageBoardId': 'finmb_1532718',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': -0.952,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': 0.10573244,
#  'morningStarRiskRating': None,
#  'forwardEps': 2.92,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 147468992,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 2051.73,
#  'sharesShort': 1338843,
#  'sharesPercentSharesOut': 0.0091,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.1027,
#  'netIncomeToCommon': 32928522240,
#  'trailingEps': 1.92,
#  'lastDividendValue': 0.064,
#  'SandP52WeekChange': -0.038741827,
#  'priceToBook': 0.004313433,
#  'heldPercentInsiders': 0.12866999,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1640908800,
#  'shortRatio': 2.5,
#  'sharesShortPreviousMonthDate': 1647302400,
#  'floatShares': 81296826,
#  'beta': 2.537505,
#  'enterpriseValue': -276337852416,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': 1620950400,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.404,
#  'priceToSalesTrailing12Months': 0.004496659,
#  'dateShortInterest': 1649894400,
#  'pegRatio': -0.07,
#  'ytdReturn': None,
#  'forwardPE': 3.030822,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 984025,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 8.68,
#  'regularMarketOpen': 8.84,
#  'twoHundredDayAverage': 9.8113,
#  'trailingAnnualDividendYield': 0,
#  'payoutRatio': 0.028900001,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 8.9773,
#  'navPrice': None,
#  'averageDailyVolume10Day': 515620,
#  'regularMarketPreviousClose': 8.68,
#  'fiftyDayAverage': 9.9222,
#  'trailingAnnualDividendRate': 0,
#  'open': 8.84,
#  'toCurrency': None,
#  'averageVolume10days': 515620,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 0.06,
#  'exDividendDate': 1620950400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 8.63,
#  'currency': 'USD',
#  'trailingPE': 4.6093755,
#  'regularMarketVolume': 265394,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1305100672,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 596391,
#  'dayLow': 8.63,
#  'ask': 8.81,
#  'askSize': 800,
#  'volume': 265394,
#  'fiftyTwoWeekHigh': 12.75,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 7.59,
#  'bid': 8.78,
#  'tradeable': False,
#  'dividendYield': 0.0072000003,
#  'bidSize': 1000,
#  'dayHigh': 8.9773,
#  'regularMarketPrice': 8.85,
#  'preMarketPrice': 8.5604,
#  'logo_url': 'https://logo.clearbit.com/gfgsa.com'}

# %%
# Spot price

hist = data.history()

spot = hist.tail(1)['Close'].iloc[0]
spot
# Out:
# 8.850000381469727

# %%
# Vencimientos de opciones
vencimientos = data.options

vencimientos
# Out:
# ('2022-05-20',
#  '2022-06-17',
#  '2022-07-15',
#  '2022-10-21',
#  '2023-01-20',
#  '2024-01-19')

# %%
# Calls y puts
calls = data.option_chain(vencimientos[0])[0]
puts = data.option_chain(vencimientos[0])[1]

puts
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0  GGAL220520P00010000 2022-05-10 16:47:17+00:00    10.0       1.55  1.45
# 1  GGAL220520P00012500 2022-03-25 19:39:45+00:00    12.5       2.20  2.90
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  2.35   -0.05      -3.125005       1           478           1.914063
# 1  3.60    0.00       0.000000       5             5           0.000010
#
#    inTheMoney contractSize currency
# 0        True      REGULAR      USD
# 1        True      REGULAR      USD

# %% [markdown]
# ### Que hace internamente el metodo??

# %%
#Recorro cada vencimiento disponible y voy tomando calls por un lado y puts por otro
for vencimiento in vencimientos[1:]:
        calls = calls.append(data.option_chain(vencimiento)[0])
        puts = puts.append(data.option_chain(vencimiento)[1])

#Uno los puts y los calls
panel_opciones = calls.append(puts)

# Le agrego dos columnas utiles - Ticker y Spot

panel_opciones['Spot'] = hist.tail(1)['Close'].iloc[0]
panel_opciones['Ticker'] = ticker

panel_opciones.head(10)
# Out:
# <ipython-input-10-eaaf21a927ea>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# <ipython-input-10-eaaf21a927ea>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# <ipython-input-10-eaaf21a927ea>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# <ipython-input-10-eaaf21a927ea>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# <ipython-input-10-eaaf21a927ea>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# <ipython-input-10-eaaf21a927ea>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# <ipython-input-10-eaaf21a927ea>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# <ipython-input-10-eaaf21a927ea>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# <ipython-input-10-eaaf21a927ea>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# <ipython-input-10-eaaf21a927ea>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# <ipython-input-10-eaaf21a927ea>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0  GGAL220520C00007500 2022-04-27 16:36:05+00:00     7.5       1.70  0.80
# 1  GGAL220520C00010000 2022-05-10 16:46:36+00:00    10.0       0.05  0.05
# 2  GGAL220520C00012500 2022-05-09 19:58:37+00:00    12.5       0.05  0.00
# 0  GGAL220617C00010000 2022-05-10 16:54:05+00:00    10.0       0.15  0.15
# 1  GGAL220617C00012500 2022-04-22 19:51:04+00:00    12.5       0.10  0.00
# 0  GGAL220715C00007500 2022-03-10 18:12:10+00:00     7.5       2.97  2.65
# 1  GGAL220715C00010000 2022-05-06 15:30:08+00:00    10.0       0.45  0.20
# 2  GGAL220715C00012500 2022-04-25 18:35:14+00:00    12.5       0.10  0.00
# 3  GGAL220715C00015000 2022-04-22 14:22:47+00:00    15.0       0.05  0.00
# 0  GGAL221021C00007500 2022-03-25 13:31:52+00:00     7.5       3.90  1.70
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  2.65    0.00       0.000000     1.0            10           1.585940
# 1  0.10   -0.05     -50.000000   161.0           872           0.648441
# 2  0.05    0.00       0.000000     1.0           277           1.078130
# 0  0.25   -0.20     -57.142853     8.0           111           0.550786
# 1  1.00    0.00       0.000000    40.0            55           1.281254
# 0  3.70    0.00       0.000000     1.0           196           1.793946
# 1  0.45    0.00       0.000000     1.0           765           0.568364
# 2  0.95    0.00       0.000000     1.0           478           0.957032
# 3  0.95    0.00       0.000000     6.0           529           1.212895
# 0  2.55    0.00       0.000000     5.0             5           0.618168
#
#    inTheMoney contractSize currency  Spot Ticker
# 0        True      REGULAR      USD  8.85   GGAL
# 1       False      REGULAR      USD  8.85   GGAL
# 2       False      REGULAR      USD  8.85   GGAL
# 0       False      REGULAR      USD  8.85   GGAL
# 1       False      REGULAR      USD  8.85   GGAL
# 0        True      REGULAR      USD  8.85   GGAL
# 1       False      REGULAR      USD  8.85   GGAL
# 2       False      REGULAR      USD  8.85   GGAL
# 3       False      REGULAR      USD  8.85   GGAL
# 0        True      REGULAR      USD  8.85   GGAL

# %% [markdown]
# ## Del panel de Yahoo crudo a otro con informacion customizada (igual que antes)

# %% [markdown]
# #### *) Agrego columnas utiles

# %%
panel_opciones['Moneyness'] = 0.0
panel_opciones['TTM'] = 0
panel_opciones['CallPut'] = ''
panel_opciones = panel_opciones.reset_index()

panel_opciones.head(5)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220520C00007500 2022-04-27 16:36:05+00:00     7.5       1.70
# 1      1  GGAL220520C00010000 2022-05-10 16:46:36+00:00    10.0       0.05
# 2      2  GGAL220520C00012500 2022-05-09 19:58:37+00:00    12.5       0.05
# 3      0  GGAL220617C00010000 2022-05-10 16:54:05+00:00    10.0       0.15
# 4      1  GGAL220617C00012500 2022-04-22 19:51:04+00:00    12.5       0.10
#
#     bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  0.80  2.65    0.00       0.000000     1.0            10           1.585940
# 1  0.05  0.10   -0.05     -50.000000   161.0           872           0.648441
# 2  0.00  0.05    0.00       0.000000     1.0           277           1.078130
# 3  0.15  0.25   -0.20     -57.142853     8.0           111           0.550786
# 4  0.00  1.00    0.00       0.000000    40.0            55           1.281254
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.85   GGAL        0.0    0
# 1       False      REGULAR      USD  8.85   GGAL        0.0    0
# 2       False      REGULAR      USD  8.85   GGAL        0.0    0
# 3       False      REGULAR      USD  8.85   GGAL        0.0    0
# 4       False      REGULAR      USD  8.85   GGAL        0.0    0

# %% [markdown]
# #### *) Recorro las filas (1ra como ejemplo)

# %%
idx = panel_opciones.index.values[0]

# %%
callput = panel_opciones.contractSymbol.values[idx][10:11]
panel_opciones['CallPut'].values[idx] = callput

# %%
year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
month = int(panel_opciones.contractSymbol.values[idx][6:8])
day = int(panel_opciones.contractSymbol.values[idx][8:10])

hoy = datetime.date.today()
expiry_datetime = datetime.date(year, month, day)
ttm = (expiry_datetime - hoy).days

panel_opciones['TTM'].values[idx] = ttm

# %%
panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(2)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220520C00007500 2022-04-27 16:36:05+00:00     7.5       1.70
# 1      1  GGAL220520C00010000 2022-05-10 16:46:36+00:00    10.0       0.05
#
#     bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  0.80  2.65    0.00            0.0     1.0            10           1.585940
# 1  0.05  0.10   -0.05          -50.0   161.0           872           0.648441
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.85   GGAL       1.18   10       C
# 1       False      REGULAR      USD  8.85   GGAL       0.00    0

# %% [markdown]
# #### *) Recorro las filas (las restantes como ejemplo)

# %%
for idx in list(panel_opciones.index.values[1:]):
        year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
        month = int(panel_opciones.contractSymbol.values[idx][6:8])
        day = int(panel_opciones.contractSymbol.values[idx][8:10])
        
        hoy = datetime.date.today()
        expiry_datetime = datetime.date(year, month, day)
        ttm = (expiry_datetime - hoy).days

        panel_opciones['TTM'].values[idx] = ttm
        callput = panel_opciones.contractSymbol.values[idx][10:11]
        panel_opciones['CallPut'].values[idx] = callput
        
panel_opciones.Moneyness = panel_opciones.Spot/ panel_opciones.strike

# %%
panel_opciones.head(10)
# Out:
#    index       contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      0  GGAL220520C00007500 2022-04-27 16:36:05+00:00     7.5       1.70
# 1      1  GGAL220520C00010000 2022-05-10 16:46:36+00:00    10.0       0.05
# 2      2  GGAL220520C00012500 2022-05-09 19:58:37+00:00    12.5       0.05
# 3      0  GGAL220617C00010000 2022-05-10 16:54:05+00:00    10.0       0.15
# 4      1  GGAL220617C00012500 2022-04-22 19:51:04+00:00    12.5       0.10
# 5      0  GGAL220715C00007500 2022-03-10 18:12:10+00:00     7.5       2.97
# 6      1  GGAL220715C00010000 2022-05-06 15:30:08+00:00    10.0       0.45
# 7      2  GGAL220715C00012500 2022-04-25 18:35:14+00:00    12.5       0.10
# 8      3  GGAL220715C00015000 2022-04-22 14:22:47+00:00    15.0       0.05
# 9      0  GGAL221021C00007500 2022-03-25 13:31:52+00:00     7.5       3.90
#
#     bid   ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  0.80  2.65    0.00       0.000000     1.0            10           1.585940
# 1  0.05  0.10   -0.05     -50.000000   161.0           872           0.648441
# 2  0.00  0.05    0.00       0.000000     1.0           277           1.078130
# 3  0.15  0.25   -0.20     -57.142853     8.0           111           0.550786
# 4  0.00  1.00    0.00       0.000000    40.0            55           1.281254
# 5  2.65  3.70    0.00       0.000000     1.0           196           1.793946
# 6  0.20  0.45    0.00       0.000000     1.0           765           0.568364
# 7  0.00  0.95    0.00       0.000000     1.0           478           0.957032
# 8  0.00  0.95    0.00       0.000000     6.0           529           1.212895
# 9  1.70  2.55    0.00       0.000000     5.0             5           0.618168
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.85   GGAL      1.180   10       C
# 1       False      REGULAR      USD  8.85   GGAL      0.885   10       C
# 2       False      REGULAR      USD  8.85   GGAL      0.708   10       C
# 3       False      REGULAR      USD  8.85   GGAL      0.885   38       C
# 4       False      REGULAR      USD  8.85   GGAL      0.708   38       C
# 5        True      REGULAR      USD  8.85   GGAL      1.180   66       C
# 6       False      REGULAR      USD  8.85   GGAL      0.885   66       C
# 7       False      REGULAR      USD  8.85   GGAL      0.708   66       C
# 8       False      REGULAR      USD  8.85   GGAL      0.590   66       C
# 9        True      REGULAR      USD  8.85   GGAL      1.180  164       C

# %% [markdown]
# #### Panel Limpio

# %%
panel_opciones = panel_opciones.rename(
            columns={'lastTradeDate': 'Last_Date', 'contractSymbol': 'Especie', 'strike': 'Strike', 'bid': 'Bid',
                     'ask': 'Ask', 'lastPrice': 'Last'}, inplace=False)

panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])

panel_opciones = panel_opciones[['Especie', 'Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Bid','Ask','impliedVolatility','Moneyness']]

# %%
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']
panel_opciones
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last    Bid  \
# 0   GGAL220520C00007500   GGAL  8.85       C     7.5   10   1.70   0.80
# 1   GGAL220520C00010000   GGAL  8.85       C    10.0   10   0.05   0.05
# 2   GGAL220520P00010000   GGAL  8.85       P    10.0   10   1.55   1.45
# 3   GGAL220520C00012500   GGAL  8.85       C    12.5   10   0.05   0.00
# 4   GGAL220520P00012500   GGAL  8.85       P    12.5   10   2.20   2.90
# 5   GGAL220617P00007500   GGAL  8.85       P     7.5   38   0.30   0.25
# 6   GGAL220617C00010000   GGAL  8.85       C    10.0   38   0.15   0.15
# 7   GGAL220617P00010000   GGAL  8.85       P    10.0   38   1.60   1.45
# 8   GGAL220617C00012500   GGAL  8.85       C    12.5   38   0.10   0.00
# 9   GGAL220715P00005000   GGAL  8.85       P     5.0   66   0.10   0.00
# 10  GGAL220715C00007500   GGAL  8.85       C     7.5   66   2.97   2.65
# 11  GGAL220715P00007500   GGAL  8.85       P     7.5   66   0.45   0.35
# 12  GGAL220715C00010000   GGAL  8.85       C    10.0   66   0.45   0.20
# 13  GGAL220715P00010000   GGAL  8.85       P    10.0   66   1.75   1.70
# 14  GGAL220715C00012500   GGAL  8.85       C    12.5   66   0.10   0.00
# 15  GGAL220715P00012500   GGAL  8.85       P    12.5   66   3.70   3.70
# 16  GGAL220715C00015000   GGAL  8.85       C    15.0   66   0.05   0.00
# 17  GGAL220715P00015000   GGAL  8.85       P    15.0   66   5.80   5.60
# 18  GGAL220715P00020000   GGAL  8.85       P    20.0   66  10.60  10.10
# 19  GGAL221021C00007500   GGAL  8.85       C     7.5  164   3.90   1.70
# 20  GGAL221021P00007500   GGAL  8.85       P     7.5  164   0.70   0.65
# 21  GGAL221021C00010000   GGAL  8.85       C    10.0  164   0.75   0.65
# 22  GGAL221021P00010000   GGAL  8.85       P    10.0  164   1.95   2.15
# 23  GGAL221021C00012500   GGAL  8.85       C    12.5  164   0.40   0.10
# 24  GGAL221021C00015000   GGAL  8.85       C    15.0  164   0.35   0.10
# 25  GGAL221021C00017500   GGAL  8.85       C    17.5  164   0.34   0.00
# 26  GGAL230120C00002500   GGAL  8.85       C     2.5  255   8.90   4.50
# 27  GGAL230120P00002500   GGAL  8.85       P     2.5  255   0.12   0.00
# 28  GGAL230120C00005000   GGAL  8.85       C     5.0  255   5.00   3.50
# 29  GGAL230120P00005000   GGAL  8.85       P     5.0  255   0.25   0.05
# 30  GGAL230120C00007500   GGAL  8.85       C     7.5  255   2.75   1.95
# 31  GGAL230120P00007500   GGAL  8.85       P     7.5  255   1.15   0.95
# 32  GGAL230120C00010000   GGAL  8.85       C    10.0  255   1.20   1.00
# 33  GGAL230120P00010000   GGAL  8.85       P    10.0  255   2.35   2.10
# 34  GGAL230120C00012500   GGAL  8.85       C    12.5  255   0.68   0.50
# 35  GGAL230120P00012500   GGAL  8.85       P    12.5  255   3.80   3.30
# 36  GGAL230120C00015000   GGAL  8.85       C    15.0  255   0.65   0.25
# 37  GGAL230120P00015000   GGAL  8.85       P    15.0  255   6.51   6.10
# 38  GGAL230120C00017500   GGAL  8.85       C    17.5  255   0.20   0.15
# 39  GGAL230120P00017500   GGAL  8.85       P    17.5  255   7.80   8.30
# 40  GGAL230120C00020000   GGAL  8.85       C    20.0  255   0.30   0.00
# 41  GGAL230120P00020000   GGAL  8.85       P    20.0  255  13.93  10.50
# 42  GGAL230120C00022500   GGAL  8.85       C    22.5  255   0.20   0.05
# 43  GGAL240119C00002500   GGAL  8.85       C     2.5  619   7.04   0.00
# 44  GGAL240119C00005000   GGAL  8.85       C     5.0  619   4.80   3.10
# 45  GGAL240119P00005000   GGAL  8.85       P     5.0  619   0.60   0.55
# 46  GGAL240119C00007500   GGAL  8.85       C     7.5  619   3.50   1.30
# 47  GGAL240119P00007500   GGAL  8.85       P     7.5  619   1.95   0.95
# 48  GGAL240119C00010000   GGAL  8.85       C    10.0  619   1.40   1.00
# 49  GGAL240119P00010000   GGAL  8.85       P    10.0  619   2.81   1.00
# 50  GGAL240119C00012500   GGAL  8.85       C    12.5  619   2.50   0.65
# 51  GGAL240119C00015000   GGAL  8.85       C    15.0  619   1.15   0.75
# 52  GGAL240119P00015000   GGAL  8.85       P    15.0  619   8.30   4.50
# 53  GGAL240119C00017500   GGAL  8.85       C    17.5  619   0.85   0.50
# 54  GGAL240119C00020000   GGAL  8.85       C    20.0  619   1.15   0.05
# 55  GGAL240119C00022500   GGAL  8.85       C    22.5  619   0.75   0.00
#
#       Ask  impliedVolatility  Moneyness
# 0    2.65           1.585940   1.180000
# 1    0.10           0.648441   0.885000
# 2    2.35           1.914063   0.885000
# 3    0.05           1.078130   0.708000
# 4    3.60           0.000010   0.708000
# 5    0.35           0.753909   1.180000
# 6    0.25           0.550786   0.885000
# 7    2.00           0.859376   0.885000
# 8    1.00           1.281254   0.708000
# 9    0.90           1.535159   1.770000
# 10   3.70           1.793946   1.180000
# 11   0.55           0.707034   1.180000
# 12   0.45           0.568364   0.885000
# 13   2.00           0.741214   0.885000
# 14   0.95           0.957032   0.708000
# 15   4.30           0.851564   0.708000
# 16   0.95           1.212895   0.590000
# 17   6.10           0.000010   0.590000
# 18  12.00           1.897461   0.442500
# 19   2.55           0.618168   1.180000
# 20   1.10           0.668949   1.180000
# 21   0.90           0.504888   0.885000
# 22   2.55           0.684573   0.885000
# 23   0.55           0.528325   0.708000
# 24   0.30           0.595707   0.590000
# 25   0.45           0.730471   0.505714
# 26   9.50           1.773439   3.540000
# 27   1.00           1.589846   3.540000
# 28   6.10           1.103520   1.770000
# 29   0.55           0.673831   1.770000
# 30   2.50           0.537114   1.180000
# 31   1.25           0.625980   1.180000
# 32   1.30           0.532720   0.885000
# 33   3.00           0.616215   0.885000
# 34   0.75           0.549809   0.708000
# 35   3.60           0.000010   0.708000
# 36   0.60           0.597660   0.590000
# 37   7.00           0.583012   0.590000
# 38   0.25           0.569340   0.505714
# 39   9.70           0.655277   0.505714
# 40   0.50           0.678714   0.442500
# 41  11.50           0.735354   0.442500
# 42   0.40           0.726565   0.393333
# 43   0.00           0.000010   3.540000
# 44   8.00           0.999023   1.770000
# 45   1.25           0.689456   1.770000
# 46   4.90           0.570317   1.180000
# 47   2.50           0.563969   1.180000
# 48   3.40           0.571782   0.885000
# 49   6.00           0.605961   0.885000
# 50   4.10           0.743655   0.708000
# 51   1.45           0.557133   0.590000
# 52   9.50           1.055181   0.590000
# 53   1.00           0.541508   0.505714
# 54   4.70           0.972168   0.442500
# 55   3.40           0.874513   0.393333

# %% [markdown]
# ## 2) Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# NYSE
panel_opciones_limpio = obtener_panel_opciones_nyse('TSLA', True)
# Out:
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)

# %%
TTMs = list(set(panel_opciones_limpio.TTM.values))
TTMs.sort()

TTMs
# Out:
# [3,
#  10,
#  17,
#  24,
#  31,
#  38,
#  45,
#  66,
#  101,
#  129,
#  164,
#  192,
#  220,
#  255,
#  311,
#  402,
#  493,
#  619,
#  773]

# %%
TTM = 17
panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == "C")].head(10)
# Out:
#                  Especie Ticker        Spot CallPut  Strike  TTM    Last  \
# 712  TSLA220527C00500000   TSLA  807.549988       C   500.0   17  327.58
# 717  TSLA220527C00550000   TSLA  807.549988       C   550.0   17  315.03
# 719  TSLA220527C00560000   TSLA  807.549988       C   560.0   17  354.65
# 721  TSLA220527C00570000   TSLA  807.549988       C   570.0   17  225.45
# 723  TSLA220527C00580000   TSLA  807.549988       C   580.0   17  299.40
# 726  TSLA220527C00600000   TSLA  807.549988       C   600.0   17  212.00
# 730  TSLA220527C00630000   TSLA  807.549988       C   630.0   17  260.55
# 733  TSLA220527C00650000   TSLA  807.549988       C   650.0   17  171.52
# 735  TSLA220527C00660000   TSLA  807.549988       C   660.0   17  244.53
# 738  TSLA220527C00680000   TSLA  807.549988       C   680.0   17  134.68
#
#      Moneyness  impliedVolatility     Bid     Ask
# 712   1.615100           0.967285  305.90  308.30
# 717   1.468273           1.060552  258.75  261.05
# 719   1.442054           0.993164  248.25  250.75
# 721   1.416754           1.010747  239.05  241.90
# 723   1.392328           0.641605  222.65  231.00
# 726   1.345917           0.850221  208.75  210.80
# 730   1.281825           0.925660  183.10  186.20
# 733   1.242385           0.856142  163.70  166.85
# 735   1.223561           0.829592  155.00  156.80
# 738   1.187574           0.845674  139.05  141.35

# %%
TTMs
# Out:
# [3,
#  10,
#  17,
#  24,
#  31,
#  38,
#  45,
#  66,
#  101,
#  129,
#  164,
#  192,
#  220,
#  255,
#  311,
#  402,
#  493,
#  619,
#  773]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[0:4]:
    Ks = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Last.values
    ## Last VS (B+A)/2
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs[0:5]:
    Ks = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %% [markdown]
# ### Para cada strike, grafico los TTM

# %%
Ks = list(set(panel_opciones_limpio.Strike.values))
Ks.sort()

# %%
panel_opciones_limpio.head(10)
# Out:
#                Especie Ticker        Spot CallPut  Strike  TTM    Last  \
# 0  TSLA220513C00200000   TSLA  807.549988       C   200.0    3  603.05
# 1  TSLA220513P00200000   TSLA  807.549988       P   200.0    3    0.01
# 2  TSLA220513C00250000   TSLA  807.549988       C   250.0    3  555.30
# 3  TSLA220513P00250000   TSLA  807.549988       P   250.0    3    0.01
# 4  TSLA220513C00300000   TSLA  807.549988       C   300.0    3  507.00
# 5  TSLA220513P00300000   TSLA  807.549988       P   300.0    3    0.01
# 6  TSLA220513C00350000   TSLA  807.549988       C   350.0    3  450.65
# 7  TSLA220513P00350000   TSLA  807.549988       P   350.0    3    0.01
# 8  TSLA220513P00400000   TSLA  807.549988       P   400.0    3    0.01
# 9  TSLA220513C00450000   TSLA  807.549988       C   450.0    3  425.15
#
#    Moneyness  impliedVolatility     Bid     Ask
# 0   4.037750           0.000010  604.00  606.30
# 1   4.037750           3.625001    0.00    0.01
# 2   3.230200           4.593754  556.10  557.65
# 3   3.230200           3.062502    0.00    0.01
# 4   2.691833           0.000010  503.65  506.05
# 5   2.691833           2.750003    0.00    0.02
# 6   2.307286           0.000010  453.75  455.75
# 7   2.307286           2.218754    0.00    0.01
# 8   2.018875           2.031255    0.01    0.02
# 9   1.794556           0.000010  352.65  354.50

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[260:280]:
    TTMs = panel_opciones_limpio[(panel_opciones_limpio.Strike == K) & (panel_opciones_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_limpio[(panel_opciones_limpio.Strike == K) & (panel_opciones_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Volatilidad implicita

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[0:4]:
    Ks = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Strike.values
    volatilidades = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].impliedVolatility.values
    ## Last VS (B+A)/2
    plt.plot(Ks, volatilidades,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Volatilidad Implicita')
plt.title('Volatilidad Implicita del Call con respecto al strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[0:4]:
    Ks = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].Strike.values
    volatilidades = panel_opciones_limpio[(panel_opciones_limpio.TTM == TTM) & (panel_opciones_limpio.CallPut == CP)].impliedVolatility.values
    ## Last VS (B+A)/2
    plt.plot(Ks, volatilidades,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Volatilidad Implicita')
plt.title('Volatilidad Implicita del Put con respecto al strike')
    
plt.show()

# %% [markdown]
# ## Pasar a Excel

# %%
panel_opciones_crudo = obtener_panel_opciones_nyse('GGAL', False)
panel_opciones_crudo.to_excel('Clase_1_panel_opciones_crudo.xls')

panel_opciones_limpio = obtener_panel_opciones_nyse('TSLA', True)
panel_opciones_limpio.to_excel('Clase_1_panel_opciones_limpio.xls')
# Out:
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calls = calls.append(data.option_chain(vencimiento)[0])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   puts = puts.append(data.option_chain(vencimiento)[1])
# C:\Users\manue\Google Drive\Docencia Posgrado\2016-2022 Analisis Cuantitativo en Finanzas\2022\Python\data_nyse.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   panel_opciones = calls.append(puts)
# <ipython-input-31-f30c5bd27bc1>:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   panel_opciones_crudo.to_excel('Clase_1_panel_opciones_crudo.xls')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-f30c5bd27bc1> in <module>
#       1 panel_opciones_crudo = obtener_panel_opciones_nyse('GGAL', False)
# ----> 2 panel_opciones_crudo.to_excel('Clase_1_panel_opciones_crudo.xls')
#       3
#       4 panel_opciones_limpio = obtener_panel_opciones_nyse('TSLA', True)
#       5 panel_opciones_limpio.to_excel('Clase_1_panel_opciones_limpio.xls')
#
# ~\.julia\conda\3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2343             inf_rep=inf_rep,
#    2344         )
# -> 2345         formatter.write(
#    2346             excel_writer,
#    2347             sheet_name=sheet_name,
#
# ~\.julia\conda\3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     892
#     893         try:
# --> 894             writer.write_cells(
#     895                 formatted_cells,
#     896                 sheet_name,
#
# ~\.julia\conda\3\lib\site-packages\pandas\io\excel\_xlwt.py in write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#      85         style_dict: dict[str, XFStyle] = {}
#      86
# ---> 87         for cell in cells:
#      88             val, fmt = self._value_with_fmt(cell.val)
#      89
#
# ~\.julia\conda\3\lib\site-packages\pandas\io\formats\excel.py in get_formatted_cells(self)
#     830     def get_formatted_cells(self) -> Iterable[ExcelCell]:
#     831         for cell in itertools.chain(self._format_header(), self._format_body()):
# --> 832             cell.val = self._format_value(cell.val)
#     833             yield cell
#     834
#
# ~\.julia\conda\3\lib\site-packages\pandas\io\formats\excel.py in _format_value(self, val)
#     545                 val = float(self.float_format % val)
#     546         if getattr(val, "tzinfo", None) is not None:
# --> 547             raise ValueError(
#     548                 "Excel does not support datetimes with "
#     549                 "timezones. Please ensure that datetimes "
#
# ValueError: Excel does not support datetimes with timezones. Please ensure that datetimes are timezone unaware before writing to Excel.

# %% [markdown]
# ## 3) Payoffs y Estrategias

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Vanilla Call y Put

# %%
def payoff_call(S,K):
    return np.maximum(S-K,0)

def payoff_put(S,K):
    return np.maximum(K-S,0)

# %%
K=50
S = np.linspace(0,100,50)

# %%
#Grafico la call

plt.plot(S,payoff_call(S, K))
plt.show()

# %%
#Grafico la put
plt.plot(S,payoff_put(S, K))
plt.show()

# %% [markdown]
# ### Forward sintetico y Combo

# %%
def payoff_forwardSintetico(S,K):
    return payoff_call(S,K)-payoff_put(S, K)

def payoff_combo(S,K1,K2):
    return payoff_call(S,K2)-payoff_put(S, K1)

# %%
#Grafico el forward sintetico
plt.plot(S,payoff_forwardSintetico(S, K))
plt.show()

# %%
K1 = 35
K2 = 65

# %%
#Grafico el combo
plt.plot(S,payoff_combo(S, K1,K2))
plt.show()

# %% [markdown]
# ### Spreads

# %%
def payoff_BullCS(S,K1,K2):
    return payoff_call(S,K1)-payoff_call(S, K2)

def payoff_BearCS(S,K1,K2):
    return payoff_call(S,K2)-payoff_call(S, K1)

def payoff_BullPS(S,K1,K2):
    return payoff_put(S,K1)-payoff_put(S, K2)


def payoff_BearPS(S,K1,K2):
    return payoff_put(S,K2)-payoff_put(S, K1)

# %%
#Grafico el Bull Call Spread
plt.plot(S,payoff_BullCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Call Spread
plt.plot(S,payoff_BearCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bull Put Spread
plt.plot(S,payoff_BullPS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Put Spread
plt.plot(S,payoff_BearPS(S, K1, K2))
plt.show()

# %% [markdown]
# ### Butterfly spreads

# %%
def payoff_CButterflyS(S,K1,K2,K3):
    return payoff_call(S,K1)-2*payoff_call(S, K2)+payoff_call(S, K3)

def payoff_PButterflyS(S,K1,K2,K3):
    return payoff_put(S,K1)-2*payoff_put(S, K2)+payoff_put(S, K3)

# %%
K1=35
K2=50
K3=65

# %%
#Grafico el Call Buterfly Spread
plt.plot(S,payoff_CButterflyS(S, K1, K2,K3))
plt.show()

# %%
#Grafico el Put Buterfly Spread
plt.plot(S,payoff_PButterflyS(S, K1, K2,K3))
plt.show()

# %% [markdown]
# ### Straddle y Strangle

# %%
def payoff_straddle(S,K):
    return payoff_call(S,K)+payoff_put(S, K)


def payoff_strangle(S,K1,K2):
    return payoff_call(S,K1)+payoff_put(S, K2)

# %%
K1 = 35
K2 = 65

# %%
#Grafico el Strangle
plt.plot(S,payoff_strangle(S, K1,K2))
plt.show()

# %%
#Grafico el Straddle

plt.plot(S,payoff_straddle(S, K))
plt.show()

# %% [markdown]
# ### Estrategia AD hoc - Iron Condor

# %%
def payoff_iron_condor(S,K1,K2,K3,K4):
    return payoff_put(S,K1)-payoff_put(S, K2)-payoff_call(S,K3)+payoff_call(S,K4)

# %%
K1 = 30
K2 = 45
K3 = 55
K4 = 70

# %%
plt.plot(S,payoff_iron_condor(S, K1,K2,K3,K4))
plt.show()

# %%
#usando el script con los metodos
import payoffs
payoffs.payoff_call(120,50)
